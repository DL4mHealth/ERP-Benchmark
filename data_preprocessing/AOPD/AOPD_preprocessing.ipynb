# %%
import os
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.utils import shuffle
from scipy.signal import resample
import matplotlib.pyplot as plt
import warnings
import mne
from mne.preprocessing import ICA
warnings.filterwarnings("ignore")
try:
    from mne_icalabel import label_components
except Exception:
    label_components = None

# %%
SAMPLE_RATE = 200  # fs
# SAMPLE_LEN = 1.0   # sample seconds
# OVERLAPPING = 0.8  # overlapping seconds
sub_folder_path = str(SAMPLE_RATE) + 'Hz'
sub_folder_path
# Out:
# '200Hz'

# %%
root = "AOPD/"
participants_path = os.path.join(root, 'participants.tsv')
participants = pd.read_csv(participants_path, sep='\t')
participants
# Out:
#    participant_id  Original_ID Group sess1_Med sess2_Med     sex  age
# 0         sub-001          804    PD        ON       OFF    Male   75
# 1         sub-002          805    PD        ON       OFF    Male   79
# 2         sub-003         8060   CTL       NaN     no s2  Female   83
# 3         sub-004          806    PD       OFF        ON  Female   79
# 4         sub-005         8070   CTL       NaN     no s2  Female   67
# 5         sub-006          807    PD       OFF        ON  Female   72
# 6         sub-007          808    PD       OFF        ON    Male   68
# 7         sub-008          809    PD        ON       OFF    Male   71
# 8         sub-009          810    PD        ON       OFF    Male   68
# 9         sub-010          811    PD        ON       OFF    Male   68
# 10        sub-011          813    PD       OFF        ON    Male   83
# 11        sub-012          814    PD        ON       OFF    Male   61
# 12        sub-013          815    PD        ON       OFF    Male   55
# 13        sub-014          816    PD       OFF        ON  Female   49
# 14        sub-015          817    PD       OFF        ON    Male   71
# 15        sub-016          818    PD        ON       OFF  Female   74
# 16        sub-017          819    PD       OFF        ON    Male   76
# 17        sub-018          820    PD        ON       OFF    Male   72
# 18        sub-019          821    PD        ON       OFF  Female   49
# 19        sub-020          822    PD        ON       OFF    Male   70
# 20        sub-021          823    PD       OFF        ON  Female   64
# 21        sub-022          824    PD       OFF        ON    Male   78
# 22        sub-023          825    PD        ON       OFF  Female   77
# 23        sub-024          826    PD        ON       OFF    Male   66
# 24        sub-025          827    PD       OFF        ON    Male   68
# 25        sub-026          828    PD       OFF        ON  Female   76
# 26        sub-027          829    PD       OFF        ON  Female   73
# 27        sub-028          890   CTL       NaN     no s2  Female   66
# 28        sub-029          891   CTL       NaN     no s2    Male   80
# 29        sub-030          892   CTL       NaN     no s2  Female   64
# 30        sub-031          893   CTL       NaN     no s2  Female   64
# 31        sub-032          895   CTL       NaN     no s2    Male   69
# 32        sub-033          896   CTL       NaN     no s2    Male   58
# 33        sub-034          897   CTL       NaN     no s2    Male   70
# 34        sub-035          898   CTL       NaN     no s2    Male   64
# 35        sub-036          899   CTL       NaN     no s2    Male   52
# 36        sub-037          900   CTL       NaN     no s2    Male   84
# 37        sub-038          901   CTL       NaN     no s2  Female   69
# 38        sub-039          902   CTL       NaN     no s2    Male   83
# 39        sub-040          903   CTL       NaN     no s2    Male   83
# 40        sub-041          904   CTL       NaN     no s2    Male   73
# 41        sub-042          905   CTL       NaN     no s2  Female   58
# 42        sub-043          906   CTL       NaN     no s2    Male   77
# 43        sub-044          907   CTL       NaN     no s2  Female   65
# 44        sub-045          909   CTL       NaN     no s2    Male   64
# 45        sub-046          910   CTL       NaN     no s2    Male   75
# 46        sub-047          911   CTL       NaN     no s2    Male   73
# 47        sub-048          912   CTL       NaN     no s2    Male   75
# 48        sub-049          913   CTL       NaN     no s2    Male   69
# 49        sub-050          914   CTL       NaN     no s2  Female   48

# %%
bad_channel_list, sampling_freq_list, data_shape_list = [], [], []

for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub)
        for ses in os.listdir(sub_path):  # Iterate over all ses-xx folders
            ses_path = os.path.join(sub_path, ses, 'eeg')  
            if os.path.exists(ses_path):
                for file in os.listdir(ses_path):
                    if file.endswith('.set'):
                        file_path = os.path.join(ses_path, file)

                        print(f"Reading EEG file: {file_path}")
                        raw = mne.io.read_raw_eeglab(file_path, preload=True)

                        # Get bad channels
                        bad_channel = raw.info['bads']
                        bad_channel_list.append(bad_channel)

                        # Get sampling rate
                        sampling_freq = raw.info['sfreq']
                        sampling_freq_list.append(sampling_freq)

                        # Get data dimensions
                        data = raw.get_data()
                        data_shape = data.shape
                        data_shape_list.append(data_shape)
# Out:
# Reading EEG file: AOPD/sub-001\ses-01\eeg\sub-001_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-001\ses-01\eeg\sub-001_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 294099  =      0.000 ...   588.198 secs...
# Reading EEG file: AOPD/sub-001\ses-02\eeg\sub-001_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-001\ses-02\eeg\sub-001_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 272524  =      0.000 ...   545.048 secs...
# Reading EEG file: AOPD/sub-002\ses-01\eeg\sub-002_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-002\ses-01\eeg\sub-002_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 319524  =      0.000 ...   639.048 secs...
# Reading EEG file: AOPD/sub-002\ses-02\eeg\sub-002_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-002\ses-02\eeg\sub-002_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 280724  =      0.000 ...   561.448 secs...
# Reading EEG file: AOPD/sub-003\ses-01\eeg\sub-003_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-003\ses-01\eeg\sub-003_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 341299  =      0.000 ...   682.598 secs...
# Reading EEG file: AOPD/sub-004\ses-01\eeg\sub-004_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-004\ses-01\eeg\sub-004_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 332024  =      0.000 ...   664.048 secs...
# Reading EEG file: AOPD/sub-004\ses-02\eeg\sub-004_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-004\ses-02\eeg\sub-004_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 346674  =      0.000 ...   693.348 secs...
# Reading EEG file: AOPD/sub-005\ses-01\eeg\sub-005_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-005\ses-01\eeg\sub-005_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 214449  =      0.000 ...   428.898 secs...
# Reading EEG file: AOPD/sub-006\ses-01\eeg\sub-006_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-006\ses-01\eeg\sub-006_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 314424  =      0.000 ...   628.848 secs...
# Reading EEG file: AOPD/sub-006\ses-02\eeg\sub-006_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-006\ses-02\eeg\sub-006_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 485849  =      0.000 ...   971.698 secs...
# Reading EEG file: AOPD/sub-007\ses-01\eeg\sub-007_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-007\ses-01\eeg\sub-007_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 303699  =      0.000 ...   607.398 secs...
# Reading EEG file: AOPD/sub-007\ses-02\eeg\sub-007_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-007\ses-02\eeg\sub-007_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 373224  =      0.000 ...   746.448 secs...
# Reading EEG file: AOPD/sub-008\ses-01\eeg\sub-008_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-008\ses-01\eeg\sub-008_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 355349  =      0.000 ...   710.698 secs...
# Reading EEG file: AOPD/sub-008\ses-02\eeg\sub-008_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-008\ses-02\eeg\sub-008_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 288174  =      0.000 ...   576.348 secs...
# Reading EEG file: AOPD/sub-009\ses-01\eeg\sub-009_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-009\ses-01\eeg\sub-009_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 238324  =      0.000 ...   476.648 secs...
# Reading EEG file: AOPD/sub-009\ses-02\eeg\sub-009_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-009\ses-02\eeg\sub-009_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 290824  =      0.000 ...   581.648 secs...
# Reading EEG file: AOPD/sub-010\ses-01\eeg\sub-010_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-010\ses-01\eeg\sub-010_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 283649  =      0.000 ...   567.298 secs...
# Reading EEG file: AOPD/sub-010\ses-02\eeg\sub-010_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-010\ses-02\eeg\sub-010_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 279749  =      0.000 ...   559.498 secs...
# Reading EEG file: AOPD/sub-011\ses-01\eeg\sub-011_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-011\ses-01\eeg\sub-011_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 292599  =      0.000 ...   585.198 secs...
# Reading EEG file: AOPD/sub-011\ses-02\eeg\sub-011_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-011\ses-02\eeg\sub-011_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 293499  =      0.000 ...   586.998 secs...
# Reading EEG file: AOPD/sub-012\ses-01\eeg\sub-012_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-012\ses-01\eeg\sub-012_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 300674  =      0.000 ...   601.348 secs...
# Reading EEG file: AOPD/sub-012\ses-02\eeg\sub-012_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-012\ses-02\eeg\sub-012_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 310649  =      0.000 ...   621.298 secs...
# Reading EEG file: AOPD/sub-013\ses-01\eeg\sub-013_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-013\ses-01\eeg\sub-013_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 293324  =      0.000 ...   586.648 secs...
# Reading EEG file: AOPD/sub-013\ses-02\eeg\sub-013_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-013\ses-02\eeg\sub-013_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 276899  =      0.000 ...   553.798 secs...
# Reading EEG file: AOPD/sub-014\ses-01\eeg\sub-014_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-014\ses-01\eeg\sub-014_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 291049  =      0.000 ...   582.098 secs...
# Reading EEG file: AOPD/sub-014\ses-02\eeg\sub-014_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-014\ses-02\eeg\sub-014_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 313299  =      0.000 ...   626.598 secs...
# Reading EEG file: AOPD/sub-015\ses-01\eeg\sub-015_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-015\ses-01\eeg\sub-015_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 295299  =      0.000 ...   590.598 secs...
# Reading EEG file: AOPD/sub-015\ses-02\eeg\sub-015_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-015\ses-02\eeg\sub-015_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 306724  =      0.000 ...   613.448 secs...
# Reading EEG file: AOPD/sub-016\ses-01\eeg\sub-016_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-016\ses-01\eeg\sub-016_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 310474  =      0.000 ...   620.948 secs...
# Reading EEG file: AOPD/sub-016\ses-02\eeg\sub-016_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-016\ses-02\eeg\sub-016_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 362599  =      0.000 ...   725.198 secs...
# Reading EEG file: AOPD/sub-017\ses-01\eeg\sub-017_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-017\ses-01\eeg\sub-017_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 336299  =      0.000 ...   672.598 secs...
# Reading EEG file: AOPD/sub-017\ses-02\eeg\sub-017_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-017\ses-02\eeg\sub-017_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 291149  =      0.000 ...   582.298 secs...
# Reading EEG file: AOPD/sub-018\ses-01\eeg\sub-018_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-018\ses-01\eeg\sub-018_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 293349  =      0.000 ...   586.698 secs...
# Reading EEG file: AOPD/sub-018\ses-02\eeg\sub-018_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-018\ses-02\eeg\sub-018_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 281749  =      0.000 ...   563.498 secs...
# Reading EEG file: AOPD/sub-019\ses-01\eeg\sub-019_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-019\ses-01\eeg\sub-019_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 432074  =      0.000 ...   864.148 secs...
# Reading EEG file: AOPD/sub-019\ses-02\eeg\sub-019_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-019\ses-02\eeg\sub-019_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 288874  =      0.000 ...   577.748 secs...
# Reading EEG file: AOPD/sub-020\ses-01\eeg\sub-020_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-020\ses-01\eeg\sub-020_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 304474  =      0.000 ...   608.948 secs...
# Reading EEG file: AOPD/sub-020\ses-02\eeg\sub-020_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-020\ses-02\eeg\sub-020_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 285199  =      0.000 ...   570.398 secs...
# Reading EEG file: AOPD/sub-021\ses-01\eeg\sub-021_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-021\ses-01\eeg\sub-021_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 275724  =      0.000 ...   551.448 secs...
# Reading EEG file: AOPD/sub-021\ses-02\eeg\sub-021_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-021\ses-02\eeg\sub-021_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 277299  =      0.000 ...   554.598 secs...
# Reading EEG file: AOPD/sub-022\ses-01\eeg\sub-022_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-022\ses-01\eeg\sub-022_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 330574  =      0.000 ...   661.148 secs...
# Reading EEG file: AOPD/sub-022\ses-02\eeg\sub-022_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-022\ses-02\eeg\sub-022_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 435049  =      0.000 ...   870.098 secs...
# Reading EEG file: AOPD/sub-023\ses-01\eeg\sub-023_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-023\ses-01\eeg\sub-023_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 259474  =      0.000 ...   518.948 secs...
# Reading EEG file: AOPD/sub-023\ses-02\eeg\sub-023_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-023\ses-02\eeg\sub-023_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 253524  =      0.000 ...   507.048 secs...
# Reading EEG file: AOPD/sub-024\ses-01\eeg\sub-024_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-024\ses-01\eeg\sub-024_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 259099  =      0.000 ...   518.198 secs...
# Reading EEG file: AOPD/sub-024\ses-02\eeg\sub-024_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-024\ses-02\eeg\sub-024_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 266449  =      0.000 ...   532.898 secs...
# Reading EEG file: AOPD/sub-025\ses-01\eeg\sub-025_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-025\ses-01\eeg\sub-025_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 303099  =      0.000 ...   606.198 secs...
# Reading EEG file: AOPD/sub-025\ses-02\eeg\sub-025_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-025\ses-02\eeg\sub-025_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 312624  =      0.000 ...   625.248 secs...
# Reading EEG file: AOPD/sub-026\ses-01\eeg\sub-026_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-026\ses-01\eeg\sub-026_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 290624  =      0.000 ...   581.248 secs...
# Reading EEG file: AOPD/sub-026\ses-02\eeg\sub-026_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-026\ses-02\eeg\sub-026_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 333574  =      0.000 ...   667.148 secs...
# Reading EEG file: AOPD/sub-027\ses-01\eeg\sub-027_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-027\ses-01\eeg\sub-027_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 324199  =      0.000 ...   648.398 secs...
# Reading EEG file: AOPD/sub-027\ses-02\eeg\sub-027_ses-02_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-027\ses-02\eeg\sub-027_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 311424  =      0.000 ...   622.848 secs...
# Reading EEG file: AOPD/sub-028\ses-01\eeg\sub-028_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-028\ses-01\eeg\sub-028_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 278124  =      0.000 ...   556.248 secs...
# Reading EEG file: AOPD/sub-029\ses-01\eeg\sub-029_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-029\ses-01\eeg\sub-029_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 280274  =      0.000 ...   560.548 secs...
# Reading EEG file: AOPD/sub-030\ses-01\eeg\sub-030_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-030\ses-01\eeg\sub-030_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 303974  =      0.000 ...   607.948 secs...
# Reading EEG file: AOPD/sub-031\ses-01\eeg\sub-031_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-031\ses-01\eeg\sub-031_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 331824  =      0.000 ...   663.648 secs...
# Reading EEG file: AOPD/sub-032\ses-01\eeg\sub-032_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-032\ses-01\eeg\sub-032_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 328024  =      0.000 ...   656.048 secs...
# Reading EEG file: AOPD/sub-033\ses-01\eeg\sub-033_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-033\ses-01\eeg\sub-033_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 464449  =      0.000 ...   928.898 secs...
# Reading EEG file: AOPD/sub-034\ses-01\eeg\sub-034_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-034\ses-01\eeg\sub-034_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 319374  =      0.000 ...   638.748 secs...
# Reading EEG file: AOPD/sub-035\ses-01\eeg\sub-035_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-035\ses-01\eeg\sub-035_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 319499  =      0.000 ...   638.998 secs...
# Reading EEG file: AOPD/sub-036\ses-01\eeg\sub-036_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-036\ses-01\eeg\sub-036_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 303124  =      0.000 ...   606.248 secs...
# Reading EEG file: AOPD/sub-037\ses-01\eeg\sub-037_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-037\ses-01\eeg\sub-037_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 274949  =      0.000 ...   549.898 secs...
# Reading EEG file: AOPD/sub-038\ses-01\eeg\sub-038_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-038\ses-01\eeg\sub-038_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 265549  =      0.000 ...   531.098 secs...
# Reading EEG file: AOPD/sub-039\ses-01\eeg\sub-039_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-039\ses-01\eeg\sub-039_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 346249  =      0.000 ...   692.498 secs...
# Reading EEG file: AOPD/sub-040\ses-01\eeg\sub-040_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-040\ses-01\eeg\sub-040_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 312249  =      0.000 ...   624.498 secs...
# Reading EEG file: AOPD/sub-041\ses-01\eeg\sub-041_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-041\ses-01\eeg\sub-041_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 268624  =      0.000 ...   537.248 secs...
# Reading EEG file: AOPD/sub-042\ses-01\eeg\sub-042_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-042\ses-01\eeg\sub-042_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 314374  =      0.000 ...   628.748 secs...
# Reading EEG file: AOPD/sub-043\ses-01\eeg\sub-043_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-043\ses-01\eeg\sub-043_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 285199  =      0.000 ...   570.398 secs...
# Reading EEG file: AOPD/sub-044\ses-01\eeg\sub-044_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-044\ses-01\eeg\sub-044_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 278474  =      0.000 ...   556.948 secs...
# Reading EEG file: AOPD/sub-045\ses-01\eeg\sub-045_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-045\ses-01\eeg\sub-045_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 273724  =      0.000 ...   547.448 secs...
# Reading EEG file: AOPD/sub-046\ses-01\eeg\sub-046_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-046\ses-01\eeg\sub-046_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 284874  =      0.000 ...   569.748 secs...
# Reading EEG file: AOPD/sub-047\ses-01\eeg\sub-047_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-047\ses-01\eeg\sub-047_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 257249  =      0.000 ...   514.498 secs...
# Reading EEG file: AOPD/sub-048\ses-01\eeg\sub-048_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-048\ses-01\eeg\sub-048_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 302399  =      0.000 ...   604.798 secs...
# Reading EEG file: AOPD/sub-049\ses-01\eeg\sub-049_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-049\ses-01\eeg\sub-049_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 269924  =      0.000 ...   539.848 secs...
# Reading EEG file: AOPD/sub-050\ses-01\eeg\sub-050_ses-01_task-Rest_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-050\ses-01\eeg\sub-050_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 297699  =      0.000 ...   595.398 secs...

# %%
from collections import Counter

print(bad_channel_list)
print(data_shape_list[0])
print("Channel number counter:", Counter(i[0] for i in data_shape_list))
print("Sampling rate counter:", Counter(sampling_freq_list))
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# (67, 294100)
# Channel number counter: Counter({67: 75})
# Sampling rate counter: Counter({500.0: 75})

# %%
common_channels = []

for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub)
        for ses in os.listdir(sub_path):  
            ses_path = os.path.join(sub_path, ses, 'eeg')
            if os.path.exists(ses_path):
                for file in os.listdir(ses_path):
                    if '.set' in file:
                        file_path = os.path.join(ses_path, file)

                        raw = mne.io.read_raw_eeglab(file_path, preload=True)
                        current_channels = set(raw.info['ch_names'])
                        if not common_channels:
                            common_channels = current_channels
                        else:
                            common_channels &= current_channels
common_channels = list(common_channels)
print(common_channels)
print("Common channels number: ", len(common_channels))
# Out:
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-001\ses-01\eeg\sub-001_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 294099  =      0.000 ...   588.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-001\ses-02\eeg\sub-001_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 272524  =      0.000 ...   545.048 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-002\ses-01\eeg\sub-002_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 319524  =      0.000 ...   639.048 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-002\ses-02\eeg\sub-002_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 280724  =      0.000 ...   561.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-003\ses-01\eeg\sub-003_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 341299  =      0.000 ...   682.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-004\ses-01\eeg\sub-004_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 332024  =      0.000 ...   664.048 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-004\ses-02\eeg\sub-004_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 346674  =      0.000 ...   693.348 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-005\ses-01\eeg\sub-005_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 214449  =      0.000 ...   428.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-006\ses-01\eeg\sub-006_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 314424  =      0.000 ...   628.848 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-006\ses-02\eeg\sub-006_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 485849  =      0.000 ...   971.698 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-007\ses-01\eeg\sub-007_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 303699  =      0.000 ...   607.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-007\ses-02\eeg\sub-007_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 373224  =      0.000 ...   746.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-008\ses-01\eeg\sub-008_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 355349  =      0.000 ...   710.698 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-008\ses-02\eeg\sub-008_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 288174  =      0.000 ...   576.348 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-009\ses-01\eeg\sub-009_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 238324  =      0.000 ...   476.648 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-009\ses-02\eeg\sub-009_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 290824  =      0.000 ...   581.648 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-010\ses-01\eeg\sub-010_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 283649  =      0.000 ...   567.298 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-010\ses-02\eeg\sub-010_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 279749  =      0.000 ...   559.498 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-011\ses-01\eeg\sub-011_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 292599  =      0.000 ...   585.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-011\ses-02\eeg\sub-011_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 293499  =      0.000 ...   586.998 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-012\ses-01\eeg\sub-012_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 300674  =      0.000 ...   601.348 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-012\ses-02\eeg\sub-012_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 310649  =      0.000 ...   621.298 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-013\ses-01\eeg\sub-013_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 293324  =      0.000 ...   586.648 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-013\ses-02\eeg\sub-013_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 276899  =      0.000 ...   553.798 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-014\ses-01\eeg\sub-014_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 291049  =      0.000 ...   582.098 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-014\ses-02\eeg\sub-014_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 313299  =      0.000 ...   626.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-015\ses-01\eeg\sub-015_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 295299  =      0.000 ...   590.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-015\ses-02\eeg\sub-015_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 306724  =      0.000 ...   613.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-016\ses-01\eeg\sub-016_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 310474  =      0.000 ...   620.948 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-016\ses-02\eeg\sub-016_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 362599  =      0.000 ...   725.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-017\ses-01\eeg\sub-017_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 336299  =      0.000 ...   672.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-017\ses-02\eeg\sub-017_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 291149  =      0.000 ...   582.298 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-018\ses-01\eeg\sub-018_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 293349  =      0.000 ...   586.698 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-018\ses-02\eeg\sub-018_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 281749  =      0.000 ...   563.498 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-019\ses-01\eeg\sub-019_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 432074  =      0.000 ...   864.148 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-019\ses-02\eeg\sub-019_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 288874  =      0.000 ...   577.748 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-020\ses-01\eeg\sub-020_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 304474  =      0.000 ...   608.948 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-020\ses-02\eeg\sub-020_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 285199  =      0.000 ...   570.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-021\ses-01\eeg\sub-021_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 275724  =      0.000 ...   551.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-021\ses-02\eeg\sub-021_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 277299  =      0.000 ...   554.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-022\ses-01\eeg\sub-022_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 330574  =      0.000 ...   661.148 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-022\ses-02\eeg\sub-022_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 435049  =      0.000 ...   870.098 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-023\ses-01\eeg\sub-023_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 259474  =      0.000 ...   518.948 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-023\ses-02\eeg\sub-023_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 253524  =      0.000 ...   507.048 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-024\ses-01\eeg\sub-024_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 259099  =      0.000 ...   518.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-024\ses-02\eeg\sub-024_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 266449  =      0.000 ...   532.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-025\ses-01\eeg\sub-025_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 303099  =      0.000 ...   606.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-025\ses-02\eeg\sub-025_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 312624  =      0.000 ...   625.248 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-026\ses-01\eeg\sub-026_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 290624  =      0.000 ...   581.248 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-026\ses-02\eeg\sub-026_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 333574  =      0.000 ...   667.148 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-027\ses-01\eeg\sub-027_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 324199  =      0.000 ...   648.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-027\ses-02\eeg\sub-027_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 311424  =      0.000 ...   622.848 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-028\ses-01\eeg\sub-028_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 278124  =      0.000 ...   556.248 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-029\ses-01\eeg\sub-029_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 280274  =      0.000 ...   560.548 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-030\ses-01\eeg\sub-030_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 303974  =      0.000 ...   607.948 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-031\ses-01\eeg\sub-031_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 331824  =      0.000 ...   663.648 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-032\ses-01\eeg\sub-032_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 328024  =      0.000 ...   656.048 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-033\ses-01\eeg\sub-033_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 464449  =      0.000 ...   928.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-034\ses-01\eeg\sub-034_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 319374  =      0.000 ...   638.748 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-035\ses-01\eeg\sub-035_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 319499  =      0.000 ...   638.998 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-036\ses-01\eeg\sub-036_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 303124  =      0.000 ...   606.248 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-037\ses-01\eeg\sub-037_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 274949  =      0.000 ...   549.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-038\ses-01\eeg\sub-038_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 265549  =      0.000 ...   531.098 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-039\ses-01\eeg\sub-039_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 346249  =      0.000 ...   692.498 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-040\ses-01\eeg\sub-040_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 312249  =      0.000 ...   624.498 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-041\ses-01\eeg\sub-041_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 268624  =      0.000 ...   537.248 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-042\ses-01\eeg\sub-042_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 314374  =      0.000 ...   628.748 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-043\ses-01\eeg\sub-043_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 285199  =      0.000 ...   570.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-044\ses-01\eeg\sub-044_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 278474  =      0.000 ...   556.948 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-045\ses-01\eeg\sub-045_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 273724  =      0.000 ...   547.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-046\ses-01\eeg\sub-046_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 284874  =      0.000 ...   569.748 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-047\ses-01\eeg\sub-047_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 257249  =      0.000 ...   514.498 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-048\ses-01\eeg\sub-048_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 302399  =      0.000 ...   604.798 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-049\ses-01\eeg\sub-049_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 269924  =      0.000 ...   539.848 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-050\ses-01\eeg\sub-050_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 297699  =      0.000 ...   595.398 secs...
# ['F2', 'P5', 'P8', 'TP10', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'FT9', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'TP9', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'FT10', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# Common channels number:  67

# %%
## Data preprocessing and segmentation
feature_path = 'Processed/' + sub_folder_path + '/AOPD/Feature'
if not os.path.exists(feature_path):
    os.makedirs(feature_path)

label_path = 'Processed/' + sub_folder_path + '/AOPD/Label'
if not os.path.exists(label_path):
    os.makedirs(label_path)

# %%
def data_preprocessing(
    raw: mne.io.Raw,
    common_channels: list,
    sample_rate: int = 250,
    notch_freq: float = 60.0,
    l_freq: float = 0.5,
    h_freq: float = 40.0,
    do_bad_interp: bool = True,
    verbose: bool = True,
):
    """
    Preprocessing steps：
      1) Choose common channels and reorder
      2) Set Montage
      3) Notch filter (before bandpass)
      4) Bandpass filter (default 0.1–30 Hz)
      5) Interpolate bad channels (if do_bad_interp is True)
      6) Re-reference to average
      7) ICA (on 1 Hz high-pass copy, auto exclude with ICLabel if available)
      8) Downsample to sample_rate
    """

    # 1. Remove unreliable electrodes
    bad_electrodes = {"FT9", "FT10", "TP9", "TP10"}
    keep = [ch for ch in common_channels if ch in raw.ch_names and ch not in bad_electrodes]
    raw.pick_channels(keep)
    raw.reorder_channels(keep)
    if verbose:
        print(f"✔ Step 1: Picked & reordered channels (excluding {bad_electrodes}): {keep}")

    # 2. Set Montage
    raw.drop_channels(['X', 'Y', 'Z', 'VEOG'])

    # 2. Set standard montage
    raw.set_montage(mne.channels.make_standard_montage('standard_1020'))
    if verbose:
        print("✔ Step 2: Montage set to 'standard_1020'.")

    # 3. Notch filter
    if notch_freq is not None:
        raw.notch_filter(freqs=[notch_freq], picks="eeg", verbose=False)
        if verbose:
            print(f"✔ Step 3: Notch filter applied @ {notch_freq} Hz")

    # 4. Bandpass filter
    raw.filter(l_freq=l_freq, h_freq=h_freq, picks="eeg", verbose=False)
    if verbose:
        print(f"✔ Step 4: Band-pass filtered ({l_freq}–{h_freq} Hz)")

    # 5. Interpolate bad channels
    if do_bad_interp and raw.info.get("bads"):
        raw.interpolate_bads(reset_bads=True, verbose=False)
        if verbose:
            print(f"✔ Step 5: Interpolated bads: {raw.info.get('bads', [])}")
    else:
        if verbose:
            print("ℹ Step 5: No bads to interpolate")

    # 6. Re-reference to average
    raw.set_eeg_reference("average", verbose=False)
    if verbose:
        print("✔ Step 6: Average reference applied")

    # 7) ICA (fit ICLabel on 1 Hz high-pass filtered copy, then apply to original)
    raw_for_ica = raw.copy().filter(l_freq=1.0, h_freq=None, picks="eeg", verbose=False)
    ica = ICA(n_components=None, method="fastica", random_state=97, max_iter="auto")
    ica.fit(raw_for_ica)

    excluded = []

    if 'label_components' in globals() and label_components is not None:
        try:
            ic_labels = label_components(raw_for_ica, ica, method="iclabel")
            labels = ic_labels["labels"]
            probs = ic_labels["y_pred_proba"]  # (n_components, n_classes)
            thresholds = {
                "eye blink": 0.7,
                "muscle artifact": 0.6,
                "heart beat": 0.5,
                "line noise": 0.8,
                "channel noise": 0.9,
            }
            for i, lab in enumerate(labels):
                if lab in thresholds:
                    p = probs[i].max() if probs is not None else 1.0
                    if p >= thresholds[lab]:
                        excluded.append(i)
        except Exception as e:
            if verbose:
                print(f"⚠ ICLabel failed: {e}")
    else:
        if verbose:
            print("ℹ ICLabel not available; fitted ICA but no auto exclusion")

    if excluded:
        ica.exclude = sorted(set(excluded))
        raw = ica.apply(raw.copy())
        if verbose:
            print(f"✔ Step 7: ICA applied. Excluded components: {ica.exclude}")
    else:
        if verbose:
            print("ℹ Step 7: No ICA components excluded")

    # 8. Resample
    if raw.info["sfreq"] != sample_rate:
        raw.resample(sample_rate, npad="auto", verbose=False)
        if verbose:
            print(f"✔ Step 8: Resampled to {sample_rate} Hz")

    return raw

# %%
def epoch_and_make_xy(
    raw: mne.io.Raw,
    events_tsv_path: str,
    tmin: float = -0.2,
    tmax: float = 0.8,
    baseline=(-0.2, 0),
    task_id: int = 1,
    subject_id: int = 1,
    disease_id: int = 1,
):
    """
    Epoching & Constructing X, y for the Oddball Dataset
    - Extract stimulus onsets from events.tsv and align with trials
    - Epoch window: [-0.2, 0.8] seconds
    - baseline: [-0.2, 0] seconds
    - y = [task_id, stimulus_type, subject_id, session_id, disease_id]
    """
    # Read stimulus events from events.tsv
    ev = pd.read_csv(events_tsv_path, sep="\t")

    # Keep only events with event codes starting with 'S' followed by a number
    ev = ev[ev["value"].astype(str).str.match(r"^S\s*\d+$")].copy()
    ev["code"] = ev["value"].str.extract(r"(\d+)").astype(int)

    # Stimulus type mapping
    stim_map = {200: 0, 201: 1, 202: 2}   # S200=target, S201=standard, S202=novel
    ev["stimulus"] = ev["code"].map(stim_map).fillna(3).astype(int)  # Others are categorized as irrelevant
    ev = ev[ev['stimulus'].isin([0, 1, 2])].reset_index(drop=True)   # only use oddball tasks trials

    # onset → sample 
    sfreq = raw.info["sfreq"]
    stim_samples = np.round(ev["onset"].values * sfreq).astype(int)
    events = np.c_[stim_samples,
                   np.zeros_like(stim_samples),
                   np.ones_like(stim_samples).astype(int)]

    # Epoching
    picks = mne.pick_types(raw.info, eeg=True, eog=False, exclude="bads")
    epochs = mne.Epochs(
        raw, events, event_id=dict(cue=1),
        tmin=tmin, tmax=tmax,
        baseline=baseline, picks=picks,
        proj=False, preload=True, reject=None, verbose=False
    )

    # Ensure uniform (epoch) duration
    target_len = int((tmax - tmin) * sfreq)
    data = epochs.get_data()  # (N, C, T)
    if data.shape[-1] > target_len:
        data = data[..., :target_len]
    elif data.shape[-1] < target_len:
        pad = target_len - data.shape[-1]
        data = np.pad(data, ((0, 0), (0, 0), (0, pad)), mode="edge")

    # Reshape to (N, T, C) 
    X = np.transpose(data, (0, 2, 1))
    
    if len(data) == 0:
        print("⚠ Warning: No valid epochs found — returning None.")
        return None, None
    if len(ev) != len(data):
        print(f"⚠ Warning: Event count mismatch — ev: {len(ev)}, epochs: {len(data)}")
    
    ev = ev.iloc[:len(data)]  # truncate to match epoch count
    # Create label array y with structure: [task_id, stimulus_type, subject_id, session_id, disease_id]
    stimulus = ev["stimulus"].values.astype(int)
    y = np.column_stack([
        np.full_like(stimulus, task_id),
        stimulus,
        np.full_like(stimulus, subject_id),
        np.full_like(stimulus, disease_id),
    ])

    return X, y

# %%
# Iterate over subjects/sessions 
for sub in os.listdir(root):
    if 'sub-' in sub:
        subject_id = int((sub.split('-')[-1]).split('.')[0])
        disease_id = participants.loc[participants['participant_id'] == sub, 'Group'].values[0]
        if disease_id == 'CTL':
            disease_id = 0
        elif disease_id == 'PD':
            disease_id = 1
        sub_path = os.path.join(root, sub)
        for ses in os.listdir(sub_path):
            if 'ses-' in ses:
                session_id = int((ses.split('-')[-1]).split('.')[0])
                eeg_path = os.path.join(sub_path, ses, 'eeg/')
                if not os.path.exists(eeg_path):
                    continue  # Skip if 'eeg' folder does not exist

                print(f"Current subject: {sub}, session: {ses}")

                # look for set and events file
                set_file_path, events_file_path = None, None
                for file in os.listdir(eeg_path):
                    if file.endswith('.set'):
                        set_file_path = os.path.join(eeg_path, file)
                    if file.endswith('events.tsv'):
                        events_file_path = os.path.join(eeg_path, file)

                if set_file_path is None:
                    raise FileNotFoundError(f".set file not found in: {eeg_path}")
                if events_file_path is None:
                    raise FileNotFoundError(f"events.tsv not found in: {eeg_path}")

                print("Find the EEG file:", set_file_path)
                print("Find the event file:", events_file_path)
                
                # load eeg data and preprocess
                print("Start preprocessing EEG data...")

                raw = mne.io.read_raw_eeglab(set_file_path, preload=True)
                raw = data_preprocessing(raw, common_channels, SAMPLE_RATE, notch_freq=60, l_freq=0.5, h_freq=40, verbose=True)

                #  Skip if None is returned
                if raw is None:
                    print(f"⚠ Skipping {sub}, {ses}")
                    continue

                print()

                print(f"Subject ID: {subject_id}, Disease ID: {disease_id}")
                print("Start epoching and making X, y...")

                # Epoch and construct X, y (as required by the paper: -0.2 to 0.8 s, baseline -0.2 to 0 s)
                print(raw.get_data().shape)
                X, y = epoch_and_make_xy(
                    raw, events_file_path,
                    tmin=-0.2, tmax=0.8, baseline=(-0.2, 0),
                    task_id=1, subject_id=subject_id, disease_id=disease_id
                )

                print(f"X shape: {X.shape}, y shape: {y.shape}")  
                # X: (N, SAMPLE_RATE * (tmax - tmin), C)
                # y: (N, 5) = [task_id, stimulus_type, subject_id, disease_id]

                # save X, y to npy files
                np.save(feature_path + f'/feature_{subject_id:03d}.npy', X)
                np.save(label_path + f'/label_{subject_id:03d}.npy', y)

                print("------------------------------------------------\n")
# Out:
# Current subject: sub-001, session: ses-01
# Find the EEG file: AOPD/sub-001\ses-01\eeg/sub-001_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-001\ses-01\eeg/sub-001_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-001\ses-01\eeg\sub-001_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 294099  =      0.000 ...   588.198 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 13.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 12 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 3, 4, 6, 8, 11, 12, 15, 20, 23, 36]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 1, Disease ID: 1
# Start epoching and making X, y...
# (59, 117640)
# X shape: (195, 200, 59), y shape: (195, 4)
# ------------------------------------------------
#
# Current subject: sub-001, session: ses-02
# Find the EEG file: AOPD/sub-001\ses-02\eeg/sub-001_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-001\ses-02\eeg/sub-001_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-001\ses-02\eeg\sub-001_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 272524  =      0.000 ...   545.048 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 10.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 14 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 5, 6, 7, 10, 11, 13, 15, 17, 28, 31, 39, 47]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 1, Disease ID: 1
# Start epoching and making X, y...
# (59, 109010)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-002, session: ses-01
# Find the EEG file: AOPD/sub-002\ses-01\eeg/sub-002_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-002\ses-01\eeg/sub-002_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-002\ses-01\eeg\sub-002_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 319524  =      0.000 ...   639.048 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 11.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 7 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 3, 16, 23, 30, 37, 43]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 2, Disease ID: 1
# Start epoching and making X, y...
# (59, 127810)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-002, session: ses-02
# Find the EEG file: AOPD/sub-002\ses-02\eeg/sub-002_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-002\ses-02\eeg/sub-002_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-002\ses-02\eeg\sub-002_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 280724  =      0.000 ...   561.448 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 9.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 9 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 8, 11, 14, 15, 16, 18, 22, 24]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 2, Disease ID: 1
# Start epoching and making X, y...
# (59, 112290)
# X shape: (195, 200, 59), y shape: (195, 4)
# ------------------------------------------------
#
# Current subject: sub-003, session: ses-01
# Find the EEG file: AOPD/sub-003\ses-01\eeg/sub-003_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-003\ses-01\eeg/sub-003_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-003\ses-01\eeg\sub-003_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 341299  =      0.000 ...   682.598 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 16.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 7 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 13, 14, 22, 35, 51]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 3, Disease ID: 0
# Start epoching and making X, y...
# (59, 136520)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-004, session: ses-01
# Find the EEG file: AOPD/sub-004\ses-01\eeg/sub-004_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-004\ses-01\eeg/sub-004_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-004\ses-01\eeg\sub-004_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 332024  =      0.000 ...   664.048 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 14.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 5 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 3, 13, 20, 23]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 4, Disease ID: 1
# Start epoching and making X, y...
# (59, 132810)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-004, session: ses-02
# Find the EEG file: AOPD/sub-004\ses-02\eeg/sub-004_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-004\ses-02\eeg/sub-004_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-004\ses-02\eeg\sub-004_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 346674  =      0.000 ...   693.348 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 199.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 7 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 5, 19, 25, 30, 32]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 4, Disease ID: 1
# Start epoching and making X, y...
# (59, 138670)
# X shape: (194, 200, 59), y shape: (194, 4)
# ------------------------------------------------
#
# Current subject: sub-005, session: ses-01
# Find the EEG file: AOPD/sub-005\ses-01\eeg/sub-005_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-005\ses-01\eeg/sub-005_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-005\ses-01\eeg\sub-005_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 214449  =      0.000 ...   428.898 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 9.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 8 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 5, 7, 12, 26, 29]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 5, Disease ID: 0
# Start epoching and making X, y...
# (59, 85780)
# X shape: (199, 200, 59), y shape: (199, 4)
# ------------------------------------------------
#
# Current subject: sub-006, session: ses-01
# Find the EEG file: AOPD/sub-006\ses-01\eeg/sub-006_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-006\ses-01\eeg/sub-006_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-006\ses-01\eeg\sub-006_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 314424  =      0.000 ...   628.848 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 10.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 9 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 11, 15, 27, 30, 37, 49]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 6, Disease ID: 1
# Start epoching and making X, y...
# (59, 125770)
# X shape: (199, 200, 59), y shape: (199, 4)
# ------------------------------------------------
#
# Current subject: sub-006, session: ses-02
# Find the EEG file: AOPD/sub-006\ses-02\eeg/sub-006_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-006\ses-02\eeg/sub-006_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-006\ses-02\eeg\sub-006_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 485849  =      0.000 ...   971.698 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 44 components
# Fitting ICA took 15.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (44 components)
#     Zeroing out 8 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [1, 6, 7, 12, 19, 20, 32, 39]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 6, Disease ID: 1
# Start epoching and making X, y...
# (59, 194340)
# X shape: (198, 200, 59), y shape: (198, 4)
# ------------------------------------------------
#
# Current subject: sub-007, session: ses-01
# Find the EEG file: AOPD/sub-007\ses-01\eeg/sub-007_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-007\ses-01\eeg/sub-007_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-007\ses-01\eeg\sub-007_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 303699  =      0.000 ...   607.398 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 174.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 4, 5, 8, 10, 12, 13, 15, 24, 29]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 7, Disease ID: 1
# Start epoching and making X, y...
# (59, 121480)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-007, session: ses-02
# Find the EEG file: AOPD/sub-007\ses-02\eeg/sub-007_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-007\ses-02\eeg/sub-007_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-007\ses-02\eeg\sub-007_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 373224  =      0.000 ...   746.448 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 14.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 9, 12, 15, 18, 19, 36, 51]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 7, Disease ID: 1
# Start epoching and making X, y...
# (59, 149290)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-008, session: ses-01
# Find the EEG file: AOPD/sub-008\ses-01\eeg/sub-008_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-008\ses-01\eeg/sub-008_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-008\ses-01\eeg\sub-008_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 355349  =      0.000 ...   710.698 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 14.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 3 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 5]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 8, Disease ID: 1
# Start epoching and making X, y...
# (59, 142140)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-008, session: ses-02
# Find the EEG file: AOPD/sub-008\ses-02\eeg/sub-008_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-008\ses-02\eeg/sub-008_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-008\ses-02\eeg\sub-008_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 288174  =      0.000 ...   576.348 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 14.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 6 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 3, 4, 7, 22]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 8, Disease ID: 1
# Start epoching and making X, y...
# (59, 115270)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-009, session: ses-01
# Find the EEG file: AOPD/sub-009\ses-01\eeg/sub-009_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-009\ses-01\eeg/sub-009_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-009\ses-01\eeg\sub-009_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 238324  =      0.000 ...   476.648 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 6.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 4 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 20, 35]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 9, Disease ID: 1
# Start epoching and making X, y...
# (59, 95330)
# X shape: (63, 200, 59), y shape: (63, 4)
# ------------------------------------------------
#
# Current subject: sub-009, session: ses-02
# Find the EEG file: AOPD/sub-009\ses-02\eeg/sub-009_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-009\ses-02\eeg/sub-009_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-009\ses-02\eeg\sub-009_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 290824  =      0.000 ...   581.648 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 6.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 4 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 40]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 9, Disease ID: 1
# Start epoching and making X, y...
# (59, 116330)
# X shape: (198, 200, 59), y shape: (198, 4)
# ------------------------------------------------
#
# Current subject: sub-010, session: ses-01
# Find the EEG file: AOPD/sub-010\ses-01\eeg/sub-010_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-010\ses-01\eeg/sub-010_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-010\ses-01\eeg\sub-010_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 283649  =      0.000 ...   567.298 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 51.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 12 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 6, 15, 16, 19, 20, 23, 29, 38, 42, 44]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 10, Disease ID: 1
# Start epoching and making X, y...
# (59, 113460)
# X shape: (196, 200, 59), y shape: (196, 4)
# ------------------------------------------------
#
# Current subject: sub-010, session: ses-02
# Find the EEG file: AOPD/sub-010\ses-02\eeg/sub-010_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-010\ses-02\eeg/sub-010_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-010\ses-02\eeg\sub-010_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 279749  =      0.000 ...   559.498 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 7.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 12 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 11, 14, 20, 21, 26, 29, 31, 32, 45, 49]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 10, Disease ID: 1
# Start epoching and making X, y...
# (59, 111900)
# X shape: (196, 200, 59), y shape: (196, 4)
# ------------------------------------------------
#
# Current subject: sub-011, session: ses-01
# Find the EEG file: AOPD/sub-011\ses-01\eeg/sub-011_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-011\ses-01\eeg/sub-011_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-011\ses-01\eeg\sub-011_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 292599  =      0.000 ...   585.198 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 8.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 7 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 14, 21, 30, 35, 52]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 11, Disease ID: 1
# Start epoching and making X, y...
# (59, 117040)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-011, session: ses-02
# Find the EEG file: AOPD/sub-011\ses-02\eeg/sub-011_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-011\ses-02\eeg/sub-011_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-011\ses-02\eeg\sub-011_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 293499  =      0.000 ...   586.998 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 7.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 8 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 8, 9, 13, 21, 25, 33]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 11, Disease ID: 1
# Start epoching and making X, y...
# (59, 117400)
# X shape: (200, 200, 59), y shape: (200, 4)
# ------------------------------------------------
#
# Current subject: sub-012, session: ses-01
# Find the EEG file: AOPD/sub-012\ses-01\eeg/sub-012_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-012\ses-01\eeg/sub-012_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-012\ses-01\eeg\sub-012_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 300674  =      0.000 ...   601.348 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 7.3s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 6 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 6, 12, 36, 40]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 12, Disease ID: 1
# Start epoching and making X, y...
# (59, 120270)
# X shape: (196, 200, 59), y shape: (196, 4)
# ------------------------------------------------
#
# Current subject: sub-012, session: ses-02
# Find the EEG file: AOPD/sub-012\ses-02\eeg/sub-012_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-012\ses-02\eeg/sub-012_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-012\ses-02\eeg\sub-012_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 310649  =      0.000 ...   621.298 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 7.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 2 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 12, Disease ID: 1
# Start epoching and making X, y...
# (59, 124260)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-013, session: ses-01
# Find the EEG file: AOPD/sub-013\ses-01\eeg/sub-013_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-013\ses-01\eeg/sub-013_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-013\ses-01\eeg\sub-013_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 293324  =      0.000 ...   586.648 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 6.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 4 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 4, 41]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 13, Disease ID: 1
# Start epoching and making X, y...
# (59, 117330)
# X shape: (200, 200, 59), y shape: (200, 4)
# ------------------------------------------------
#
# Current subject: sub-013, session: ses-02
# Find the EEG file: AOPD/sub-013\ses-02\eeg/sub-013_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-013\ses-02\eeg/sub-013_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-013\ses-02\eeg\sub-013_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 276899  =      0.000 ...   553.798 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 6.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 7 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 6, 11, 15, 35, 38, 52]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 13, Disease ID: 1
# Start epoching and making X, y...
# (59, 110760)
# X shape: (196, 200, 59), y shape: (196, 4)
# ------------------------------------------------
#
# Current subject: sub-014, session: ses-01
# Find the EEG file: AOPD/sub-014\ses-01\eeg/sub-014_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-014\ses-01\eeg/sub-014_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-014\ses-01\eeg\sub-014_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 291049  =      0.000 ...   582.098 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 10.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 14 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 3, 6, 12, 15, 22, 25, 29, 31, 35, 41, 46, 50]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 14, Disease ID: 1
# Start epoching and making X, y...
# (59, 116420)
# X shape: (198, 200, 59), y shape: (198, 4)
# ------------------------------------------------
#
# Current subject: sub-014, session: ses-02
# Find the EEG file: AOPD/sub-014\ses-02\eeg/sub-014_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-014\ses-02\eeg/sub-014_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-014\ses-02\eeg\sub-014_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 313299  =      0.000 ...   626.598 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 16.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 14 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 3, 5, 8, 11, 12, 17, 23, 24, 27, 33, 35, 45]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 14, Disease ID: 1
# Start epoching and making X, y...
# (59, 125320)
# X shape: (192, 200, 59), y shape: (192, 4)
# ------------------------------------------------
#
# Current subject: sub-015, session: ses-01
# Find the EEG file: AOPD/sub-015\ses-01\eeg/sub-015_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-015\ses-01\eeg/sub-015_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-015\ses-01\eeg\sub-015_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 295299  =      0.000 ...   590.598 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 10.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 9 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 10, 17, 18, 23, 31, 36, 41]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 15, Disease ID: 1
# Start epoching and making X, y...
# (59, 118120)
# X shape: (195, 200, 59), y shape: (195, 4)
# ------------------------------------------------
#
# Current subject: sub-015, session: ses-02
# Find the EEG file: AOPD/sub-015\ses-02\eeg/sub-015_ses-02_task-Rest_eeg.set
# Find the event file: AOPD/sub-015\ses-02\eeg/sub-015_ses-02_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-015\ses-02\eeg\sub-015_ses-02_task-Rest_eeg.fdt
# Reading 0 ... 306724  =      0.000 ...   613.448 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 11.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 8 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 14, 15, 25, 30, 36, 44]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 15, Disease ID: 1
# Start epoching and making X, y...
# (59, 122690)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-016, session: ses-01
# Find the EEG file: AOPD/sub-016\ses-01\eeg/sub-016_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-016\ses-01\eeg/sub-016_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-016\ses-01\eeg\sub-016_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 310474  =      0.000 ...   620.948 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ...
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 6.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 9 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 9, 12, 16, 21, 30, 38, 43]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 41, Disease ID: 0
# Start epoching and making X, y...
# (59, 107450)
# X shape: (195, 200, 59), y shape: (195, 4)
# ------------------------------------------------
#
# Current subject: sub-042, session: ses-01
# Find the EEG file: AOPD/sub-042\ses-01\eeg/sub-042_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-042\ses-01\eeg/sub-042_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-042\ses-01\eeg\sub-042_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 314374  =      0.000 ...   628.748 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 11.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 12 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 3, 8, 9, 24, 25, 30, 33, 36, 40, 43]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 42, Disease ID: 0
# Start epoching and making X, y...
# (59, 125750)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-043, session: ses-01
# Find the EEG file: AOPD/sub-043\ses-01\eeg/sub-043_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-043\ses-01\eeg/sub-043_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-043\ses-01\eeg\sub-043_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 285199  =      0.000 ...   570.398 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 7.3s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 6, 7, 14, 15, 19, 44, 53]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 43, Disease ID: 0
# Start epoching and making X, y...
# (59, 114080)
# X shape: (195, 200, 59), y shape: (195, 4)
# ------------------------------------------------
#
# Current subject: sub-044, session: ses-01
# Find the EEG file: AOPD/sub-044\ses-01\eeg/sub-044_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-044\ses-01\eeg/sub-044_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-044\ses-01\eeg\sub-044_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 278474  =      0.000 ...   556.948 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 8.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 6 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [5, 8, 9, 29, 42, 43]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 44, Disease ID: 0
# Start epoching and making X, y...
# (59, 111390)
# X shape: (197, 200, 59), y shape: (197, 4)
# ------------------------------------------------
#
# Current subject: sub-045, session: ses-01
# Find the EEG file: AOPD/sub-045\ses-01\eeg/sub-045_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-045\ses-01\eeg/sub-045_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-045\ses-01\eeg\sub-045_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 273724  =      0.000 ...   547.448 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 12.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [1, 2, 4, 6, 7, 9, 19, 25, 26, 43, 46]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 45, Disease ID: 0
# Start epoching and making X, y...
# (59, 109490)
# X shape: (193, 200, 59), y shape: (193, 4)
# ------------------------------------------------
#
# Current subject: sub-046, session: ses-01
# Find the EEG file: AOPD/sub-046\ses-01\eeg/sub-046_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-046\ses-01\eeg/sub-046_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-046\ses-01\eeg\sub-046_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 284874  =      0.000 ...   569.748 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 8.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 28 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 4, 5, 6, 7, 9, 12, 14, 15, 16, 17, 18, 19, 23, 27, 28, 29, 30, 31, 32, 33, 35, 37, 39, 41, 54]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 46, Disease ID: 0
# Start epoching and making X, y...
# (59, 113950)
# X shape: (196, 200, 59), y shape: (196, 4)
# ------------------------------------------------
#
# Current subject: sub-047, session: ses-01
# Find the EEG file: AOPD/sub-047\ses-01\eeg/sub-047_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-047\ses-01\eeg/sub-047_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-047\ses-01\eeg\sub-047_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 257249  =      0.000 ...   514.498 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 7.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 13 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 3, 4, 7, 8, 9, 14, 18, 23, 24, 32, 33]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 47, Disease ID: 0
# Start epoching and making X, y...
# (59, 102900)
# X shape: (198, 200, 59), y shape: (198, 4)
# ------------------------------------------------
#
# Current subject: sub-048, session: ses-01
# Find the EEG file: AOPD/sub-048\ses-01\eeg/sub-048_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-048\ses-01\eeg/sub-048_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-048\ses-01\eeg\sub-048_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 302399  =      0.000 ...   604.798 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 10.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 13 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 5, 7, 9, 11, 17, 21, 24, 25, 31, 39]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 48, Disease ID: 0
# Start epoching and making X, y...
# (59, 120960)
# X shape: (195, 200, 59), y shape: (195, 4)
# ------------------------------------------------
#
# Current subject: sub-049, session: ses-01
# Find the EEG file: AOPD/sub-049\ses-01\eeg/sub-049_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-049\ses-01\eeg/sub-049_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-049\ses-01\eeg\sub-049_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 269924  =      0.000 ...   539.848 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 8.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 4, 9, 12, 18, 23, 30, 49]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 49, Disease ID: 0
# Start epoching and making X, y...
# (59, 107970)
# X shape: (199, 200, 59), y shape: (199, 4)
# ------------------------------------------------
#
# Current subject: sub-050, session: ses-01
# Find the EEG file: AOPD/sub-050\ses-01\eeg/sub-050_ses-01_task-Rest_eeg.set
# Find the event file: AOPD/sub-050\ses-01\eeg/sub-050_ses-01_task-Rest_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\AOPD\AOPD\sub-050\ses-01\eeg\sub-050_ses-01_task-Rest_eeg.fdt
# Reading 0 ... 297699  =      0.000 ...   595.398 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'FT9', 'TP9', 'TP10', 'FT10'}): ['F2', 'P5', 'P8', 'CP4', 'F8', 'CP1', 'Z', 'F4', 'F1', 'Oz', 'CP5', 'POz', 'X', 'T8', 'FT7', 'Fp2', 'PO3', 'F7', 'FC1', 'F3', 'CP6', 'C1', 'PO7', 'VEOG', 'C3', 'FCz', 'PO4', 'C6', 'Fp1', 'Y', 'C4', 'P3', 'CP2', 'FC5', 'AFz', 'TP7', 'Fz', 'Pz', 'CP3', 'PO8', 'FT8', 'AF7', 'P2', 'Cz', 'FC6', 'O1', 'C5', 'FC2', 'FC4', 'P7', 'AF4', 'FC3', 'AF3', 'O2', 'P6', 'F6', 'P4', 'TP8', 'AF8', 'C2', 'P1', 'T7', 'F5']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 11.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 4, 10, 11, 12, 16, 20, 54]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 50, Disease ID: 0
# Start epoching and making X, y...
# (59, 119080)
# X shape: (198, 200, 59), y shape: (198, 4)
# ------------------------------------------------

# %% [markdown]
# ## Load and check the processed data

# %%
# Test the saved npy file
# example
import re

total_samples = 0
for feature_file, label_file in zip(os.listdir(feature_path), os.listdir(label_path)):
    sub_id = int(re.search(r'\d+', feature_file).group())
    feature_file_path = os.path.join(feature_path, feature_file)
    label_file_path = os.path.join(label_path, label_file)
    X = np.load(feature_file_path)
    y = np.load(label_file_path)
    print(f"Subject {sub_id}: X shape: {X.shape}, y shape: {y.shape}")
    if X.shape[0] != y.shape[0]:
        raise(f"Subject {sub_id} data and label length mismatch: " 
                f"{X.shape[0]} vs {y.shape[0]}")
    total_samples += np.load(feature_file_path).shape[0]
    sub_id += 1
print("\nTotal number of trials:", total_samples)
# Out:
# Subject 1: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 2: X shape: (195, 200, 59), y shape: (195, 4)
# Subject 3: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 4: X shape: (194, 200, 59), y shape: (194, 4)
# Subject 5: X shape: (199, 200, 59), y shape: (199, 4)
# Subject 6: X shape: (198, 200, 59), y shape: (198, 4)
# Subject 7: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 8: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 9: X shape: (198, 200, 59), y shape: (198, 4)
# Subject 10: X shape: (196, 200, 59), y shape: (196, 4)
# Subject 11: X shape: (200, 200, 59), y shape: (200, 4)
# Subject 12: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 13: X shape: (196, 200, 59), y shape: (196, 4)
# Subject 14: X shape: (192, 200, 59), y shape: (192, 4)
# Subject 15: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 16: X shape: (195, 200, 59), y shape: (195, 4)
# Subject 17: X shape: (198, 200, 59), y shape: (198, 4)
# Subject 18: X shape: (196, 200, 59), y shape: (196, 4)
# Subject 19: X shape: (200, 200, 59), y shape: (200, 4)
# Subject 20: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 21: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 22: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 23: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 24: X shape: (192, 200, 59), y shape: (192, 4)
# Subject 25: X shape: (195, 200, 59), y shape: (195, 4)
# Subject 26: X shape: (196, 200, 59), y shape: (196, 4)
# Subject 27: X shape: (198, 200, 59), y shape: (198, 4)
# Subject 28: X shape: (196, 200, 59), y shape: (196, 4)
# Subject 29: X shape: (196, 200, 59), y shape: (196, 4)
# Subject 30: X shape: (195, 200, 59), y shape: (195, 4)
# Subject 31: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 32: X shape: (200, 200, 59), y shape: (200, 4)
# Subject 33: X shape: (196, 200, 59), y shape: (196, 4)
# Subject 34: X shape: (195, 200, 59), y shape: (195, 4)
# Subject 35: X shape: (195, 200, 59), y shape: (195, 4)
# Subject 36: X shape: (200, 200, 59), y shape: (200, 4)
# Subject 37: X shape: (198, 200, 59), y shape: (198, 4)
# Subject 38: X shape: (198, 200, 59), y shape: (198, 4)
# Subject 39: X shape: (196, 200, 59), y shape: (196, 4)
# Subject 40: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 41: X shape: (195, 200, 59), y shape: (195, 4)
# Subject 42: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 43: X shape: (195, 200, 59), y shape: (195, 4)
# Subject 44: X shape: (197, 200, 59), y shape: (197, 4)
# Subject 45: X shape: (193, 200, 59), y shape: (193, 4)
# Subject 46: X shape: (196, 200, 59), y shape: (196, 4)
# Subject 47: X shape: (198, 200, 59), y shape: (198, 4)
# Subject 48: X shape: (195, 200, 59), y shape: (195, 4)
# Subject 49: X shape: (199, 200, 59), y shape: (199, 4)
# Subject 50: X shape: (198, 200, 59), y shape: (198, 4)
#
# Total number of trials: 9830
