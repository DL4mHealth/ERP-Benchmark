# %%
import os
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.utils import shuffle
from scipy.signal import resample
import matplotlib.pyplot as plt
import warnings
import mne
from mne.preprocessing import ICA
warnings.filterwarnings("ignore")
try:
    from mne_icalabel import label_components
except Exception:
    label_components = None

# %%
SAMPLE_RATE = 200  # fs
# SAMPLE_LEN = 1.0   # sample seconds
# OVERLAPPING = 0.8  # overlapping seconds
sub_folder_path = str(SAMPLE_RATE) + 'Hz'
sub_folder_path
# Out:
# '200Hz'

# %%
root = "mTBI-ODD/"
participants_path = os.path.join(root, 'participants.tsv')
participants = pd.read_csv(participants_path, sep='\t')
participants
# Out:
#    participant_id  Original_ID       URSI  sex  age  Group
# 0         sub-001         3044  M87102477    1   23      0
# 1         sub-002         3009  M87104171    0   30      1
# 2         sub-003         3042  M87104582    0   19      0
# 3         sub-004         3074  M87106278    0   19      0
# 4         sub-005         3076  M87107075    0   22      0
# ..            ...          ...        ...  ...  ...    ...
# 91        sub-092        86461  M87186461    1   38      2
# 92        sub-093        86772  M87186772    0   28      2
# 93        sub-094        93385  M87193385    1   45      2
# 94        sub-095        94391  M87194391    0   52      2
# 95        sub-096        97750  M87197750    0   26      2
#
# [96 rows x 6 columns]

# %%
bad_channel_list, sampling_freq_list, data_shape_list = [], [], []

bad_files = [
    # data loading error
    ("sub-042", "ses-02"),
    ("sub-033", "ses-02"),
    ("sub-012", "ses-02"),
    ("sub-031", "ses-03"),
    
    # no standard target events (might be caused by wrong event name)
    ("sub-040", "ses-01"),
    ("sub-060", "ses-01"),
]

# %%
for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub)
        for ses in os.listdir(sub_path):  # Iterate over all ses-xx folders
            ses_path = os.path.join(sub_path, ses, 'eeg')  
            if os.path.exists(ses_path):
                for file in os.listdir(ses_path):
                    if file.endswith('.set'):
                        file_path = os.path.join(ses_path, file)

                        # Skip known problematic files
                        if any(subj in file_path and sess in file_path for subj, sess in bad_files):
                            print(f"Skipping bad file: {file_path}")
                            continue

                        print(f"Reading EEG file: {file_path}")
                        raw = mne.io.read_raw_eeglab(file_path, preload=True)

                        # Get bad channels
                        bad_channel = raw.info['bads']
                        bad_channel_list.append(bad_channel)

                        # Get sampling rate
                        sampling_freq = raw.info['sfreq']
                        sampling_freq_list.append(sampling_freq)

                        # Get data dimensions
                        data = raw.get_data()
                        data_shape = data.shape
                        data_shape_list.append(data_shape)
# Out:
# Reading EEG file: mTBI-ODD/sub-001\ses-01\eeg\sub-001_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-001\ses-01\eeg\sub-001_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 482524  =      0.000 ...   965.048 secs...
# Reading EEG file: mTBI-ODD/sub-002\ses-01\eeg\sub-002_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-002\ses-01\eeg\sub-002_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 761649  =      0.000 ...  1523.298 secs...
# Reading EEG file: mTBI-ODD/sub-002\ses-02\eeg\sub-002_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-002\ses-02\eeg\sub-002_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 526624  =      0.000 ...  1053.248 secs...
# Reading EEG file: mTBI-ODD/sub-003\ses-01\eeg\sub-003_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-003\ses-01\eeg\sub-003_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 
ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-081\ses-01\eeg\sub-081_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 476649  =      0.000 ...   953.298 secs...
# Reading EEG file: mTBI-ODD/sub-082\ses-01\eeg\sub-082_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-082\ses-01\eeg\sub-082_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 629299  =      0.000 ...  1258.598 secs...
# Reading EEG file: mTBI-ODD/sub-083\ses-01\eeg\sub-083_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-083\ses-01\eeg\sub-083_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 464249  =      0.000 ...   928.498 secs...
# Reading EEG file: mTBI-ODD/sub-084\ses-01\eeg\sub-084_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-084\ses-01\eeg\sub-084_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 693549  =      0.000 ...  1387.098 secs...
# Reading EEG file: mTBI-ODD/sub-085\ses-01\eeg\sub-085_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-085\ses-01\eeg\sub-085_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 448724  =      0.000 ...   897.448 secs...
# Reading EEG file: mTBI-ODD/sub-086\ses-01\eeg\sub-086_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-086\ses-01\eeg\sub-086_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 460274  =      0.000 ...   920.548 secs...
# Reading EEG file: mTBI-ODD/sub-087\ses-01\eeg\sub-087_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-087\ses-01\eeg\sub-087_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 476774  =      0.000 ...   953.548 secs...
# Reading EEG file: mTBI-ODD/sub-088\ses-01\eeg\sub-088_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-088\ses-01\eeg\sub-088_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 327299  =      0.000 ...   654.598 secs...
# Reading EEG file: mTBI-ODD/sub-089\ses-01\eeg\sub-089_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-089\ses-01\eeg\sub-089_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 479874  =      0.000 ...   959.748 secs...
# Reading EEG file: mTBI-ODD/sub-090\ses-01\eeg\sub-090_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-090\ses-01\eeg\sub-090_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 470099  =      0.000 ...   940.198 secs...
# Reading EEG file: mTBI-ODD/sub-091\ses-01\eeg\sub-091_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-091\ses-01\eeg\sub-091_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 484699  =      0.000 ...   969.398 secs...
# Reading EEG file: mTBI-ODD/sub-092\ses-01\eeg\sub-092_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-092\ses-01\eeg\sub-092_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 481149  =      0.000 ...   962.298 secs...
# Reading EEG file: mTBI-ODD/sub-093\ses-01\eeg\sub-093_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-093\ses-01\eeg\sub-093_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 485774  =      0.000 ...   971.548 secs...
# Reading EEG file: mTBI-ODD/sub-094\ses-01\eeg\sub-094_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-094\ses-01\eeg\sub-094_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 482324  =      0.000 ...   964.648 secs...
# Reading EEG file: mTBI-ODD/sub-095\ses-01\eeg\sub-095_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-095\ses-01\eeg\sub-095_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 489724  =      0.000 ...   979.448 secs...
# Reading EEG file: mTBI-ODD/sub-096\ses-01\eeg\sub-096_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-096\ses-01\eeg\sub-096_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 878174  =      0.000 ...  1756.348 secs...

# %%
from collections import Counter

print(bad_channel_list)
print(data_shape_list[0])
print("Channel number counter:", Counter(i[0] for i in data_shape_list))
print("Sampling rate counter:", Counter(sampling_freq_list))
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# (65, 482525)
# Channel number counter: Counter({65: 188, 64: 8})
# Sampling rate counter: Counter({500.0: 196})

# %%
common_channels = []

for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub)
        for ses in os.listdir(sub_path):  
            ses_path = os.path.join(sub_path, ses, 'eeg')
            if os.path.exists(ses_path):
                for file in os.listdir(ses_path):
                    if '.set' in file:
                        file_path = os.path.join(ses_path, file)

                        # Skip error files
                        if any(subj in file_path and sess in file_path for subj, sess in bad_files):
                            print(f"Skipping bad file: {file_path}")
                            continue

                        raw = mne.io.read_raw_eeglab(file_path, preload=True)
                        current_channels = set(raw.info['ch_names'])
                        if not common_channels:
                            common_channels = current_channels
                        else:
                            common_channels &= current_channels
common_channels = list(common_channels)
print(common_channels)
print("Common channels number: ", len(common_channels))
# Out:
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-001\ses-01\eeg\sub-001_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 482524  =      0.000 ...   965.048 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-002\ses-01\eeg\sub-002_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 761649  =      0.000 ...  1523.298 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-002\ses-02\eeg\sub-002_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 526624  =      0.000 ...  1053.248 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-003\ses-01\eeg\sub-003_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 481349  =      0.000 ...   962.698 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-004\ses-01\eeg\sub-004_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 468424  =      0.000 ...   936.848 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-004\ses-02\eeg\sub-004_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 505899  =      0.000 ...  1011.798 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-005\ses-01\eeg\sub-005_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 469024  =      0.000 ...   938.048 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-006\ses-01\eeg\sub-006_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 484999  =      0.000 ...   969.998 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-006\ses-02\eeg\sub-006_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 467849  =      0.000 ...   935.698 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-006\ses-03\eeg\sub-006_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 452599  =      0.000 ...   905.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-007\ses-01\eeg\sub-007_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 640099  =      0.000 ...  1280.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-007\ses-02\eeg\sub-007_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 475099  =      0.000 ...   950.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-007\ses-03\eeg\sub-007_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 456049  =      0.000 ...   912.098 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-008\ses-01\eeg\sub-008_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 451724  =      0.000 ...   903.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-008\ses-02\eeg\sub-008_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 508074  =      0.000 ...  1016.148 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-009\ses-01\eeg\sub-009_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 555449  =      0.000 ...  1110.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-009\ses-02\eeg\sub-009_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 464574  =      0.000 ...   929.148 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-009\ses-03\eeg\sub-009_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 471574  =      0.000 ...   943.148 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-010\ses-01\eeg\sub-010_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 553799  =      0.000 ...  1107.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-011\ses-01\eeg\sub-011_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 508449  =      0.000 ...  1016.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-011\ses-02\eeg\sub-011_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 483599  =      0.000 ...   967.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-011\ses-03\eeg\sub-011_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 500424  =      0.000 ...  1000.848 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-012\ses-01\eeg\sub-012_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 491549  =      0.000 ...   983.098 secs...
# Skipping bad file: mTBI-ODD/sub-012\ses-02\eeg\sub-012_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-013\ses-01\eeg\sub-013_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 482149  =      0.000 ...   964.298 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-013\ses-02\eeg\sub-013_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 448124  =      0.000 ...   896.248 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-013\ses-03\eeg\sub-013_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 503449  =      0.000 ...  1006.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-014\ses-01\eeg\sub-014_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 540949  =      0.000 ...  1081.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-014\ses-02\eeg\sub-014_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 470624  =      0.000 ...   941.248 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-015\ses-01\eeg\sub-015_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 484974  =      0.000 ...   969.948 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-015\ses-02\eeg\sub-015_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 457224  =      0.000 ...   914.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-015\ses-03\eeg\sub-015_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 479224  =      0.000 ...   958.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-016\ses-01\eeg\sub-016_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 450724  =      0.000 ...   901.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-016\ses-02\eeg\sub-016_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 501149  =      0.000 ...  1002.298 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-016\ses-03\eeg\sub-016_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 416249  =      0.000 ...   832.498 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-017\ses-01\eeg\sub-017_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 492524  =      0.000 ...   985.048 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-017\ses-02\eeg\sub-017_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 519974  =      0.000 ...  1039.948 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-017\ses-03\eeg\sub-017_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 482699  =      0.000 ...   965.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub
598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-070\ses-03\eeg\sub-070_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 645699  =      0.000 ...  1291.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-071\ses-01\eeg\sub-071_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 477199  =      0.000 ...   954.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-071\ses-02\eeg\sub-071_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 467449  =      0.000 ...   934.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-072\ses-01\eeg\sub-072_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 617299  =      0.000 ...  1234.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-073\ses-01\eeg\sub-073_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 480974  =      0.000 ...   961.948 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-074\ses-01\eeg\sub-074_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 487524  =      0.000 ...   975.048 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-075\ses-01\eeg\sub-075_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 486474  =      0.000 ...   972.948 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-076\ses-01\eeg\sub-076_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 461999  =      0.000 ...   923.998 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-077\ses-01\eeg\sub-077_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 471449  =      0.000 ...   942.898 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-078\ses-01\eeg\sub-078_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 581999  =      0.000 ...  1163.998 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-079\ses-01\eeg\sub-079_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 483424  =      0.000 ...   966.848 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-080\ses-01\eeg\sub-080_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 554574  =      0.000 ...  1109.148 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-081\ses-01\eeg\sub-081_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 476649  =      0.000 ...   953.298 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-082\ses-01\eeg\sub-082_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 629299  =      0.000 ...  1258.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-083\ses-01\eeg\sub-083_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 464249  =      0.000 ...   928.498 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-084\ses-01\eeg\sub-084_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 693549  =      0.000 ...  1387.098 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-085\ses-01\eeg\sub-085_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 448724  =      0.000 ...   897.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-086\ses-01\eeg\sub-086_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 460274  =      0.000 ...   920.548 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-087\ses-01\eeg\sub-087_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 476774  =      0.000 ...   953.548 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-088\ses-01\eeg\sub-088_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 327299  =      0.000 ...   654.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-089\ses-01\eeg\sub-089_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 479874  =      0.000 ...   959.748 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-090\ses-01\eeg\sub-090_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 470099  =      0.000 ...   940.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-091\ses-01\eeg\sub-091_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 484699  =      0.000 ...   969.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-092\ses-01\eeg\sub-092_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 481149  =      0.000 ...   962.298 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-093\ses-01\eeg\sub-093_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 485774  =      0.000 ...   971.548 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-094\ses-01\eeg\sub-094_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 482324  =      0.000 ...   964.648 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-095\ses-01\eeg\sub-095_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 489724  =      0.000 ...   979.448 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-096\ses-01\eeg\sub-096_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 878174  =      0.000 ...  1756.348 secs...
# ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'EKG', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'VEOG', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# Common channels number:  63

# %%
## Data preprocessing and segmentation
feature_path = 'Processed/' + sub_folder_path + '/mTBI-ODD/Feature'
if not os.path.exists(feature_path):
    os.makedirs(feature_path)

label_path = 'Processed/' + sub_folder_path + '/mTBI-ODD/Label'
if not os.path.exists(label_path):
    os.makedirs(label_path)

# %%
def data_preprocessing(
    raw: mne.io.Raw,
    common_channels: list,
    sample_rate: int = 250,
    notch_freq: float = 60.0,
    l_freq: float = 0.5,
    h_freq: float = 40.0,
    do_bad_interp: bool = True,
    verbose: bool = True,
):
    """
    Preprocessing steps：
      1) Choose common channels and reorder
      2) Set Montage
      3) Notch filter (before bandpass)
      4) Bandpass filter (default 0.1–30 Hz)
      5) Interpolate bad channels (if do_bad_interp is True)
      6) Re-reference to average
      7) ICA (on 1 Hz high-pass copy, auto exclude with ICLabel if available)
      8) Downsample to sample_rate
    """

    raw.set_channel_types({'VEOG': 'eog', 'EKG': 'ecg'})
    raw.pick_types(eeg=True)

    # 1. Select common channels
    keep = [ch for ch in common_channels if ch in raw.ch_names]
    raw.pick_channels(keep)
    raw.reorder_channels(keep)
    if verbose:
        print(f"✔ Step 1: Picked {len(keep)} common EEG channels: {keep}")

    # 2. Set standard montage
    raw.set_montage(mne.channels.make_standard_montage('standard_1020'))
    if verbose:
        print("✔ Step 2: Montage set to 'standard_1020'.")

    # 3. Notch filter
    if notch_freq is not None:
        raw.notch_filter(freqs=[notch_freq], picks="eeg", verbose=False)
        if verbose:
            print(f"✔ Step 3: Notch filter applied @ {notch_freq} Hz")

    # 4. Bandpass filter
    raw.filter(l_freq=l_freq, h_freq=h_freq, picks="eeg", verbose=False)
    if verbose:
        print(f"✔ Step 4: Band-pass filtered ({l_freq}–{h_freq} Hz)")

    # 5. Interpolate bad channels
    if do_bad_interp and raw.info.get("bads"):
        raw.interpolate_bads(reset_bads=True, verbose=False)
        if verbose:
            print(f"✔ Step 5: Interpolated bads: {raw.info.get('bads', [])}")
    else:
        if verbose:
            print("ℹ Step 5: No bads to interpolate")

    # 6. Re-reference to average
    raw.set_eeg_reference("average", verbose=False)
    if verbose:
        print("✔ Step 6: Average reference applied")

    # 7) ICA (fit ICLabel on 1 Hz high-pass filtered copy, then apply to original)
    raw_for_ica = raw.copy().filter(l_freq=1.0, h_freq=None, picks="eeg", verbose=False)
    ica = ICA(n_components=None, method="fastica", random_state=97, max_iter="auto")
    ica.fit(raw_for_ica)

    excluded = []

    if 'label_components' in globals() and label_components is not None:
        try:
            ic_labels = label_components(raw_for_ica, ica, method="iclabel")
            labels = ic_labels["labels"]
            probs = ic_labels["y_pred_proba"]  # (n_components, n_classes)
            thresholds = {
                "eye blink": 0.7,
                "muscle artifact": 0.6,
                "heart beat": 0.5,
                "line noise": 0.8,
                "channel noise": 0.9,
            }
            for i, lab in enumerate(labels):
                if lab in thresholds:
                    p = probs[i].max() if probs is not None else 1.0
                    if p >= thresholds[lab]:
                        excluded.append(i)
        except Exception as e:
            if verbose:
                print(f"⚠ ICLabel failed: {e}")
    else:
        if verbose:
            print("ℹ ICLabel not available; fitted ICA but no auto exclusion")

    if excluded:
        ica.exclude = sorted(set(excluded))
        raw = ica.apply(raw.copy())
        if verbose:
            print(f"✔ Step 7: ICA applied. Excluded components: {ica.exclude}")
    else:
        if verbose:
            print("ℹ Step 7: No ICA components excluded")

    # 8. Resample
    if raw.info["sfreq"] != sample_rate:
        raw.resample(sample_rate, npad="auto", verbose=False)
        if verbose:
            print(f"✔ Step 8: Resampled to {sample_rate} Hz")

    return raw

# %%
def epoch_and_make_xy(
    raw: mne.io.Raw,
    events_tsv_path: str,
    tmin: float = -0.2,
    tmax: float = 0.8,
    baseline=(-0.2, 0),
    task_id: int = 1,
    subject_id: int = 1,
    session_id: int = 1,
    disease_id: int = 1,
):
    """
    Epoching & Constructing X, y for the Oddball Dataset
    - Extract stimulus onsets from events.tsv and align with trials
    - Epoch window: [-0.2, 0.8] seconds
    - baseline: [-0.2, 0] seconds
    - y = [task_id, stimulus_type, subject_id, session_id, disease_id]
    """
    # Read stimulus events from events.tsv
    ev = pd.read_csv(events_tsv_path, sep="\t")

    # Keep only events with event codes starting with 'S' followed by a number
    ev = ev[ev["value"].astype(str).str.match(r"^S\s*\d+$")].copy()
    ev["code"] = ev["value"].str.extract(r"(\d+)").astype(int)

    # Stimulus type mapping
    stim_map = {200: 0, 201: 1, 202: 2}   # S200=target, S201=standard, S202=novel
    ev["stimulus"] = ev["code"].map(stim_map).fillna(3).astype(int)  # Others are categorized as irrelevant
    ev = ev[ev['stimulus'].isin([0, 1, 2])].reset_index(drop=True)   # only use oddball tasks trials

    # onset → sample 
    sfreq = raw.info["sfreq"]
    stim_samples = np.round(ev["onset"].values * sfreq).astype(int)
    events = np.c_[stim_samples,
                   np.zeros_like(stim_samples),
                   np.ones_like(stim_samples).astype(int)]

    # Epoching
    picks = mne.pick_types(raw.info, eeg=True, eog=False, exclude="bads")
    epochs = mne.Epochs(
        raw, events, event_id=dict(cue=1),
        tmin=tmin, tmax=tmax,
        baseline=baseline, picks=picks,
        proj=False, preload=True, reject=None, verbose=False
    )

    # Ensure uniform (epoch) duration
    target_len = int((tmax - tmin) * sfreq)
    data = epochs.get_data()  # (N, C, T)
    if data.shape[-1] > target_len:
        data = data[..., :target_len]
    elif data.shape[-1] < target_len:
        pad = target_len - data.shape[-1]
        data = np.pad(data, ((0, 0), (0, 0), (0, pad)), mode="edge")

    # Reshape to (N, T, C) 
    X = np.transpose(data, (0, 2, 1))
    
    if len(data) == 0:
        print("⚠ Warning: No valid epochs found — returning None.")
        return None, None
    if len(ev) != len(data):
        print(f"⚠ Warning: Event count mismatch — ev: {len(ev)}, epochs: {len(data)}")
    
    ev = ev.iloc[:len(data)]  # truncate to match epoch count
    # Create label array y with structure: [task_id, stimulus_type, subject_id, session_id, disease_id]
    stimulus = ev["stimulus"].values.astype(int)
    y = np.column_stack([
        np.full_like(stimulus, task_id),
        stimulus,
        np.full_like(stimulus, subject_id),
        np.full_like(stimulus, session_id),
        np.full_like(stimulus, disease_id),
    ])

    return X, y

# %%
# Iterate over subjects/sessions 
for sub in os.listdir(root):
    if 'sub-' in sub:
        subject_id = int((sub.split('-')[-1]).split('.')[0])
        disease_id = participants.loc[participants['participant_id'] == sub, 'Group'].values[0]
        sub_path = os.path.join(root, sub)
        for ses in os.listdir(sub_path):
            if 'ses-' in ses:
                session_id = int((ses.split('-')[-1]).split('.')[0])
                eeg_path = os.path.join(sub_path, ses, 'eeg/')
                if not os.path.exists(eeg_path):
                    continue  # Skip if 'eeg' folder does not exist

                print(f"Current subject: {sub}, session: {ses}")

                # look for set and events file
                set_file_path, events_file_path = None, None
                for file in os.listdir(eeg_path):
                    if file.endswith('.set'):
                        set_file_path = os.path.join(eeg_path, file)
                    if file.endswith('events.tsv'):
                        events_file_path = os.path.join(eeg_path, file)

                if set_file_path is None:
                    raise FileNotFoundError(f".set file not found in: {eeg_path}")
                if events_file_path is None:
                    raise FileNotFoundError(f"events.tsv not found in: {eeg_path}")

                print("Find the EEG file:", set_file_path)
                print("Find the event file:", events_file_path)
                
                # load eeg data and preprocess
                print("Start preprocessing EEG data...")
                if any(subj in set_file_path and sess in set_file_path for subj, sess in bad_files):
                    print(f"Skipping bad file: {set_file_path}")
                    continue

                raw = mne.io.read_raw_eeglab(set_file_path, preload=True)
                raw = data_preprocessing(raw, common_channels, SAMPLE_RATE, notch_freq=60, l_freq=0.5, h_freq=40, verbose=True)

                #  Skip if None is returned
                if raw is None:
                    print(f"⚠ Skipping {sub}, {ses}")
                    continue

                print()

                print(f"Subject ID: {subject_id}, Disease ID: {disease_id}")
                print("Start epoching and making X, y...")

                # Epoch and construct X, y (as required by the paper: -0.2 to 0.8 s, baseline -0.2 to 0 s)
                print(raw.get_data().shape)
                X, y = epoch_and_make_xy(
                    raw, events_file_path,
                    tmin=-0.2, tmax=0.8, baseline=(-0.2, 0),
                    task_id=1, subject_id=subject_id, session_id=session_id, disease_id=disease_id
                )

                print(f"X shape: {X.shape}, y shape: {y.shape}")  
                # X: (N, SAMPLE_RATE * (tmax - tmin), C)
                # y: (N, 5) = [task_id, stimulus_type, subject_id, session_id, disease_id]

                # save X, y to npy files
                np.save(feature_path + f'/feature_{subject_id:03d}.npy', X)
                np.save(label_path + f'/label_{subject_id:03d}.npy', y)

                print("------------------------------------------------\n")
# Out:
# Current subject: sub-060, session: ses-01
# Find the EEG file: mTBI-ODD/sub-060\ses-01\eeg/sub-060_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-060\ses-01\eeg/sub-060_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Skipping bad file: mTBI-ODD/sub-060\ses-01\eeg/sub-060_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Current subject: sub-060, session: ses-02
# Find the EEG file: mTBI-ODD/sub-060\ses-02\eeg/sub-060_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-060\ses-02\eeg/sub-060_ses-02_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-060\ses-02\eeg\sub-060_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 703199  =      0.000 ...  1406.398 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 52.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 8 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [1, 2, 3, 5, 21, 24, 25, 44]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 60, Disease ID: 1
# Start epoching and making X, y...
# (61, 281280)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-060, session: ses-03
# Find the EEG file: mTBI-ODD/sub-060\ses-03\eeg/sub-060_ses-03_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-060\ses-03\eeg/sub-060_ses-03_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-060\ses-03\eeg\sub-060_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 534149  =      0.000 ...  1068.298 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 54.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 7 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 24, 25, 26, 28, 45]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 60, Disease ID: 1
# Start epoching and making X, y...
# (61, 213660)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-061, session: ses-01
# Find the EEG file: mTBI-ODD/sub-061\ses-01\eeg/sub-061_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-061\ses-01\eeg/sub-061_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-061\ses-01\eeg\sub-061_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 483049  =      0.000 ...   966.098 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 19.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 7 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 5, 7, 13, 33, 48]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 61, Disease ID: 0
# Start epoching and making X, y...
# (61, 193220)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-062, session: ses-01
# Find the EEG file: mTBI-ODD/sub-062\ses-01\eeg/sub-062_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-062\ses-01\eeg/sub-062_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-062\ses-01\eeg\sub-062_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 504449  =      0.000 ...  1008.898 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 42.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 12 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 3, 4, 14, 17, 18, 28, 34, 46, 47, 51]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 62, Disease ID: 0
# Start epoching and making X, y...
# (61, 201780)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-062, session: ses-02
# Find the EEG file: mTBI-ODD/sub-062\ses-02\eeg/sub-062_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-062\ses-02\eeg/sub-062_ses-02_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-062\ses-02\eeg\sub-062_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 589249  =      0.000 ...  1178.498 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 50.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 14 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [2, 3, 4, 12, 17, 18, 20, 21, 23, 28, 30, 32, 33, 47]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 62, Disease ID: 0
# Start epoching and making X, y...
# (61, 235700)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-063, session: ses-01
# Find the EEG file: mTBI-ODD/sub-063\ses-01\eeg/sub-063_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-063\ses-01\eeg/sub-063_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-063\ses-01\eeg\sub-063_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 613449  =      0.000 ...  1226.898 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 35 components
# Fitting ICA took 21.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (35 components)
#     Zeroing out 7 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [4, 11, 25, 27, 31, 32, 33]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 63, Disease ID: 1
# Start epoching and making X, y...
# (61, 245380)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-063, session: ses-02
# Find the EEG file: mTBI-ODD/sub-063\ses-02\eeg/sub-063_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-063\ses-02\eeg/sub-063_ses-02_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-063\ses-02\eeg\sub-063_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 597774  =      0.000 ...  1195.548 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 28.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 13 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 27, 28, 34, 38, 40, 42, 44, 45, 49, 52, 53]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 63, Disease ID: 1
# Start epoching and making X, y...
# (61, 239110)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-063, session: ses-03
# Find the EEG file: mTBI-ODD/sub-063\ses-03\eeg/sub-063_ses-03_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-063\ses-03\eeg/sub-063_ses-03_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-063\ses-03\eeg\sub-063_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 472699  =      0.000 ...   945.398 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 27.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 8 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 37, 40, 47, 48, 52, 54]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 63, Disease ID: 1
# Start epoching and making X, y...
# (61, 189080)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-064, session: ses-01
# Find the EEG file: mTBI-ODD/sub-064\ses-01\eeg/sub-064_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-064\ses-01\eeg/sub-064_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-064\ses-01\eeg\sub-064_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 552799  =      0.000 ...  1105.598 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 38.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 11 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 21, 23, 25, 29, 34, 37, 54]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 64, Disease ID: 1
# Start epoching and making X, y...
# (61, 221120)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-064, session: ses-02
# Find the EEG file: mTBI-ODD/sub-064\ses-02\eeg/sub-064_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-064\ses-02\eeg/sub-064_ses-02_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-064\ses-02\eeg\sub-064_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 470074  =      0.000 ...   940.148 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 18 components
# Fitting ICA took 5.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (18 components)
#     Zeroing out 1 ICA component
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [11]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 64, Disease ID: 1
# Start epoching and making X, y...
# (61, 188030)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-064, session: ses-03
# Find the EEG file: mTBI-ODD/sub-064\ses-03\eeg/sub-064_ses-03_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-064\ses-03\eeg/sub-064_ses-03_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-064\ses-03\eeg\sub-064_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 462949  =      0.000 ...   925.898 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 34.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 10 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 22, 37, 39, 43, 51, 58]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 64, Disease ID: 1
# Start epoching and making X, y...
# (61, 185180)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-065, session: ses-01
# Find the EEG file: mTBI-ODD/sub-065\ses-01\eeg/sub-065_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-065\ses-01\eeg/sub-065_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-065\ses-01\eeg\sub-065_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 539799  =      0.000 ...  1079.598 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 37.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 8 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 5, 6, 7, 17, 20, 31]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 65, Disease ID: 0
# Start epoching and making X, y...
# (61, 215920)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-065, session: ses-02
# Find the EEG file: mTBI-ODD/sub-065\ses-02\eeg/sub-065_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-065\ses-02\eeg/sub-065_ses-02_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-065\ses-02\eeg\sub-065_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 497524  =      0.000 ...   995.048 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 28.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 13 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [2, 5, 12, 13, 14, 15, 18, 21, 22, 23, 28, 31, 40]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 65, Disease ID: 0
# Start epoching and making X, y...
# (61, 199010)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-065, session: ses-03
# Find the EEG file: mTBI-ODD/sub-065\ses-03\eeg/sub-065_ses-03_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-065\ses-03\eeg/sub-065_ses-03_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-065\ses-03\eeg\sub-065_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 477574  =      0.000 ...   955.148 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 59 components
# Fitting ICA took 364.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (59 components)
#     Zeroing out 1 ICA component
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [50]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 65, Disease ID: 0
# Start epoching and making X, y...
# (61, 191030)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-066, session: ses-01
# Find the EEG file: mTBI-ODD/sub-066\ses-01\eeg/sub-066_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-066\ses-01\eeg/sub-066_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-066\ses-01\eeg\sub-066_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 645524  =      0.000 ...  1291.048 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 27.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 9 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [1, 4, 20, 30, 31, 33, 39, 40, 50]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 66, Disease ID: 1
# Start epoching and making X, y...
# (61, 258210)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-067, session: ses-01
# Find the EEG file: mTBI-ODD/sub-067\ses-01\eeg/sub-067_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-067\ses-01\eeg/sub-067_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-067\ses-01\eeg\sub-067_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 682849  =      0.000 ...  1365.698 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 36.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 5 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 20, 21]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 67, Disease ID: 1
# Start epoching and making X, y...
# (61, 273140)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-067, session: ses-02
# Find the EEG file: mTBI-ODD/sub-067\ses-02\eeg/sub-067_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-067\ses-02\eeg/sub-067_ses-02_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-067\ses-02\eeg\sub-067_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 523899  =      0.000 ...  1047.798 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 31.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 13 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 18, 21, 23, 29, 30, 31, 36, 44, 55]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 67, Disease ID: 1
# Start epoching and making X, y...
# (61, 209560)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-067, session: ses-03
# Find the EEG file: mTBI-ODD/sub-067\ses-03\eeg/sub-067_ses-03_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-067\ses-03\eeg/sub-067_ses-03_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-067\ses-03\eeg\sub-067_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 650474  =      0.000 ...  1300.948 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 28.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 13 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 3, 5, 16, 25, 31, 34, 38, 40, 45, 46, 51]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 67, Disease ID: 1
# Start epoching and making X, y...
# (61, 260190)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-068, session: ses-01
# Find the EEG file: mTBI-ODD/sub-068\ses-01\eeg/sub-068_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-068\ses-01\eeg/sub-068_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-068\ses-01\eeg\sub-068_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 576774  =      0.000 ...  1153.548 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 39.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 8 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 12, 13, 22, 41, 45]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 68, Disease ID: 0
# Start epoching and making X, y...
# (61, 230710)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-068, session: ses-02
# Find the EEG file: mTBI-ODD/sub-068\ses-02\eeg/sub-068_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-068\ses-02\eeg/sub-068_ses-02_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-068\ses-02\eeg\sub-068_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 489674  =      0.000 ...   979.348 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 20.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 8 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 20, 25, 27, 30, 31, 33]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 68, Disease ID: 0
# Start epoching and making X, y...
# (61, 195870)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-068, session: ses-03
# Find the EEG file: mTBI-ODD/sub-068\ses-03\eeg/sub-068_ses-03_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-068\ses-03\eeg/sub-068_ses-03_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-068\ses-03\eeg\sub-068_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 549824  =      0.000 ...  1099.648 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 9 components
# Fitting ICA took 2.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (9 components)
#     Zeroing out 1 ICA component
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [5]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 68, Disease ID: 0
# Start epoching and making X, y...
# (61, 219930)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-069, session: ses-01
# Find the EEG file: mTBI-ODD/sub-069\ses-01\eeg/sub-069_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-069\ses-01\eeg/sub-069_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-069\ses-01\eeg\sub-069_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 853049  =      0.000 ...  1706.098 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 35 components
# Fitting ICA took 24.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (35 components)
#     Zeroing out 3 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [1, 6, 15]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 69, Disease ID: 0
# Start epoching and making X, y...
# (61, 341220)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-070, session: ses-01
# Find the EEG file: mTBI-ODD/sub-070\ses-01\eeg/sub-070_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-070\ses-01\eeg/sub-070_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-070\ses-01\eeg\sub-070_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 770924  =      0.000 ...  1541.848 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 42.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 4 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [1, 4, 36, 49]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 70, Disease ID: 1
# Start epoching and making X, y...
# (61, 308370)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-070, session: ses-02
# Find the EEG file: mTBI-ODD/sub-070\ses-02\eeg/sub-070_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-070\ses-02\eeg/sub-070_ses-02_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-070\ses-02\eeg\sub-070_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 590299  =      0.000 ...  1180.598 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 34.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 8 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 3, 9, 18, 22, 38, 46]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 70, Disease ID: 1
# Start epoching and making X, y...
# (61, 236120)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-070, session: ses-03
# Find the EEG file: mTBI-ODD/sub-070\ses-03\eeg/sub-070_ses-03_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-070\ses-03\eeg/sub-070_ses-03_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-070\ses-03\eeg\sub-070_ses-03_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 645699  =      0.000 ...  1291.398 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 38.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 6 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 29, 40, 41]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 70, Disease ID: 1
# Start epoching and making X, y...
# (61, 258280)
# X shape: (245, 200, 61), y shape: (245, 5)
# ------------------------------------------------
#
# Current subject: sub-071, session: ses-01
# Find the EEG file: mTBI-ODD/sub-071\ses-01\eeg/sub-071_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-071\ses-01\eeg/sub-071_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-071\ses-01\eeg\sub-071_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 477199  =      0.000 ...   954.398 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 33.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 7 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 3, 15, 18, 26, 31, 45]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 71, Disease ID: 0
# Start epoching and making X, y...
# (61, 190880)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-071, session: ses-02
# Find the EEG file: mTBI-ODD/sub-071\ses-02\eeg/sub-071_ses-02_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-071\ses-02\eeg/sub-071_ses-02_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-071\ses-02\eeg\sub-071_ses-02_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 467449  =      0.000 ...   934.898 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 17.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 10 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 14, 23, 30, 35, 37, 40, 47, 48]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 71, Disease ID: 0
# Start epoching and making X, y...
# (61, 186980)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-072, session: ses-01
# Find the EEG file: mTBI-ODD/sub-072\ses-01\eeg/sub-072_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-072\ses-01\eeg/sub-072_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-072\ses-01\eeg\sub-072_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 617299  =      0.000 ...  1234.598 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 57.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 11 ICA components
#     Projecting back using 61 PCA components
# ...
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 52 components
# Fitting ICA took 21.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (52 components)
#     Zeroing out 7 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [20, 22, 24, 25, 28, 36, 41]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 87, Disease ID: 2
# Start epoching and making X, y...
# (61, 190710)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-088, session: ses-01
# Find the EEG file: mTBI-ODD/sub-088\ses-01\eeg/sub-088_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-088\ses-01\eeg/sub-088_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-088\ses-01\eeg\sub-088_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 327299  =      0.000 ...   654.598 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 56 components
# Fitting ICA took 6.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (56 components)
#     Zeroing out 2 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [3, 5]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 88, Disease ID: 2
# Start epoching and making X, y...
# (61, 130920)
# X shape: (200, 200, 61), y shape: (200, 5)
# ------------------------------------------------
#
# Current subject: sub-089, session: ses-01
# Find the EEG file: mTBI-ODD/sub-089\ses-01\eeg/sub-089_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-089\ses-01\eeg/sub-089_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-089\ses-01\eeg\sub-089_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 479874  =      0.000 ...   959.748 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 19.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 12 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 5, 22, 28, 29, 32, 35, 36, 37, 39, 45]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 89, Disease ID: 2
# Start epoching and making X, y...
# (61, 191950)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-090, session: ses-01
# Find the EEG file: mTBI-ODD/sub-090\ses-01\eeg/sub-090_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-090\ses-01\eeg/sub-090_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-090\ses-01\eeg\sub-090_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 470099  =      0.000 ...   940.198 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 32.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 7 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 4, 12, 13, 42, 52]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 90, Disease ID: 2
# Start epoching and making X, y...
# (61, 188040)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-091, session: ses-01
# Find the EEG file: mTBI-ODD/sub-091\ses-01\eeg/sub-091_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-091\ses-01\eeg/sub-091_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-091\ses-01\eeg\sub-091_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 484699  =      0.000 ...   969.398 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 20.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 6 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 3, 5, 10, 14, 23]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 91, Disease ID: 2
# Start epoching and making X, y...
# (61, 193880)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-092, session: ses-01
# Find the EEG file: mTBI-ODD/sub-092\ses-01\eeg/sub-092_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-092\ses-01\eeg/sub-092_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-092\ses-01\eeg\sub-092_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 481149  =      0.000 ...   962.298 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 25.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 3 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 25]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 92, Disease ID: 2
# Start epoching and making X, y...
# (61, 192460)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-093, session: ses-01
# Find the EEG file: mTBI-ODD/sub-093\ses-01\eeg/sub-093_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-093\ses-01\eeg/sub-093_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-093\ses-01\eeg\sub-093_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 485774  =      0.000 ...   971.548 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 48 components
# Fitting ICA took 31.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (48 components)
#     Zeroing out 1 ICA component
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [3]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 93, Disease ID: 2
# Start epoching and making X, y...
# (61, 194310)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-094, session: ses-01
# Find the EEG file: mTBI-ODD/sub-094\ses-01\eeg/sub-094_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-094\ses-01\eeg/sub-094_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-094\ses-01\eeg\sub-094_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 482324  =      0.000 ...   964.648 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 19.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 13 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 5, 7, 13, 14, 18, 19, 25, 27, 31, 40, 45]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 94, Disease ID: 2
# Start epoching and making X, y...
# (61, 192930)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-095, session: ses-01
# Find the EEG file: mTBI-ODD/sub-095\ses-01\eeg/sub-095_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-095\ses-01\eeg/sub-095_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-095\ses-01\eeg\sub-095_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 489724  =      0.000 ...   979.448 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 27.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 9 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 8, 11, 12, 14, 23, 25, 26]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 95, Disease ID: 2
# Start epoching and making X, y...
# (61, 195890)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------
#
# Current subject: sub-096, session: ses-01
# Find the EEG file: mTBI-ODD/sub-096\ses-01\eeg/sub-096_ses-01_task-ThreeStimAuditoryOddball_eeg.set
# Find the event file: mTBI-ODD/sub-096\ses-01\eeg/sub-096_ses-01_task-ThreeStimAuditoryOddball_events.tsv
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\mTBI-ODD\mTBI-ODD\sub-096\ses-01\eeg\sub-096_ses-01_task-ThreeStimAuditoryOddball_eeg.fdt
# Reading 0 ... 878174  =      0.000 ...  1756.348 secs...
# ✔ Step 1: Picked 61 common EEG channels: ['CP2', 'FC1', 'F1', 'C2', 'C3', 'FT9', 'TP8', 'C1', 'FC3', 'Fz', 'AF8', 'C4', 'FCz', 'P7', 'CP3', 'Cz', 'FC5', 'Oz', 'PO4', 'F5', 'C6', 'FC6', 'P1', 'TP9', 'O1', 'P8', 'P6', 'P5', 'Pz', 'F6', 'P3', 'PO3', 'O2', 'TP10', 'CP6', 'FT10', 'C5', 'PO7', 'POz', 'F8', 'F7', 'FC4', 'P4', 'CP1', 'F2', 'TP7', 'AFz', 'F4', 'Fp1', 'CP5', 'FC2', 'AF7', 'AF4', 'CP4', 'PO8', 'F3', 'FT7', 'Fp2', 'AF3', 'FT8', 'P2']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filter applied @ 60 Hz
# ✔ Step 4: Band-pass filtered (0.5–40 Hz)
# ℹ Step 5: No bads to interpolate
# ✔ Step 6: Average reference applied
# Fitting ICA to data using 61 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 60 components
# Fitting ICA took 37.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (60 components)
#     Zeroing out 5 ICA components
#     Projecting back using 61 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 32]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 96, Disease ID: 2
# Start epoching and making X, y...
# (61, 351270)
# X shape: (260, 200, 61), y shape: (260, 5)
# ------------------------------------------------

# %% [markdown]
# ## Load and check the processed data

# %%
# Test the saved npy file
# example
import re

total_samples = 0
for feature_file, label_file in zip(os.listdir(feature_path), os.listdir(label_path)):
    sub_id = int(re.search(r'\d+', feature_file).group())
    feature_file_path = os.path.join(feature_path, feature_file)
    label_file_path = os.path.join(label_path, label_file)
    X = np.load(feature_file_path)
    y = np.load(label_file_path)
    print(f"Subject {sub_id}: X shape: {X.shape}, y shape: {y.shape}")
    if X.shape[0] != y.shape[0]:
        raise(f"Subject {sub_id} data and label length mismatch: " 
                f"{X.shape[0]} vs {y.shape[0]}")
    total_samples += np.load(feature_file_path).shape[0]
    sub_id += 1
print("\nTotal number of trials:", total_samples)
# Out:
# Subject 1: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 2: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 3: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 4: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 5: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 6: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 7: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 8: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 9: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 10: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 11: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 12: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 13: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 14: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 15: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 16: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 17: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 18: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 19: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 20: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 21: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 22: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 23: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 24: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 25: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 26: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 27: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 28: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 29: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 30: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 31: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 32: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 33: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 34: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 35: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 36: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 37: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 38: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 39: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 40: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 41: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 42: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 43: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 44: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 45: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 46: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 47: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 48: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 49: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 50: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 51: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 52: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 53: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 54: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 55: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 56: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 57: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 58: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 59: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 60: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 61: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 62: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 63: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 64: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 65: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 66: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 67: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 68: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 69: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 70: X shape: (245, 200, 61), y shape: (245, 5)
# Subject 71: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 72: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 73: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 74: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 75: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 76: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 77: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 78: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 79: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 80: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 81: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 82: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 83: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 84: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 85: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 86: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 87: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 88: X shape: (200, 200, 61), y shape: (200, 5)
# Subject 89: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 90: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 91: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 92: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 93: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 94: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 95: X shape: (260, 200, 61), y shape: (260, 5)
# Subject 96: X shape: (260, 200, 61), y shape: (260, 5)
#
# Total number of trials: 24885
