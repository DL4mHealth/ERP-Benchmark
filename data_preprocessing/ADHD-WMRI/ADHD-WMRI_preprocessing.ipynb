# %%
import os
import numpy as np
import h5py
import pandas as pd
from scipy.signal import resample
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
import mne
from mne.preprocessing import ICA
try:
    from mne_icalabel import label_components
except Exception:
    label_components = None

# %%
SAMPLE_RATE = 200  # fs
# SAMPLE_LEN = 1.0   # sample seconds
# OVERLAPPING = 0.8  # overlapping seconds
sub_folder_path = str(SAMPLE_RATE) + 'Hz'
sub_folder_path
# Out:
# '200Hz'

# %%
# root dir
import os
import re  
root = "ADHD-WMRI/"

for file in os.listdir(root):
    if file.endswith(".cnt"):
        # Extract Subject ID and Group

        match = re.match(r"Subject(\d+)_(Control|ADHD)_(\w+)_Raw\.cnt", file)
        if match:
            subject_id = int(match.group(1))
            group = match.group(2)
            task = match.group(3)   # NBackTask / GoNogoTask / CombinedTask

            if group == "Control":
                disease_id = 0
            elif group == "ADHD":
                disease_id = 1

            print(f"Subject {subject_id}, Group={group}, DiseaseID={disease_id}, Task={task}, File={file}")
# Out:
# Subject 10, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject10_Control_CombinedTask_Raw.cnt
# Subject 10, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject10_Control_GoNogoTask_Raw.cnt
# Subject 10, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject10_Control_NBackTask_Raw.cnt
# Subject 11, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject11_Control_CombinedTask_Raw.cnt
# Subject 11, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject11_Control_GoNogoTask_Raw.cnt
# Subject 11, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject11_Control_NBackTask_Raw.cnt
# Subject 12, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject12_Control_CombinedTask_Raw.cnt
# Subject 12, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject12_Control_GoNogoTask_Raw.cnt
# Subject 12, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject12_Control_NBackTask_Raw.cnt
# Subject 13, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject13_Control_CombinedTask_Raw.cnt
# Subject 13, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject13_Control_GoNogoTask_Raw.cnt
# Subject 13, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject13_Control_NBackTask_Raw.cnt
# Subject 14, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject14_Control_CombinedTask_Raw.cnt
# Subject 14, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject14_Control_GoNogoTask_Raw.cnt
# Subject 14, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject14_Control_NBackTask_Raw.cnt
# Subject 15, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject15_Control_CombinedTask_Raw.cnt
# Subject 15, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject15_Control_GoNogoTask_Raw.cnt
# Subject 15, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject15_Control_NBackTask_Raw.cnt
# Subject 16, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject16_Control_CombinedTask_Raw.cnt
# Subject 16, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject16_Control_GoNogoTask_Raw.cnt
# Subject 16, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject16_Control_NBackTask_Raw.cnt
# Subject 17, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject17_Control_CombinedTask_Raw.cnt
# Subject 17, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject17_Control_GoNogoTask_Raw.cnt
# Subject 17, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject17_Control_NBackTask_Raw.cnt
# Subject 18, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject18_Control_CombinedTask_Raw.cnt
# Subject 18, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject18_Control_GoNogoTask_Raw.cnt
# Subject 18, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject18_Control_NBackTask_Raw.cnt
# Subject 19, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject19_Control_CombinedTask_Raw.cnt
# Subject 19, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject19_Control_GoNogoTask_Raw.cnt
# Subject 19, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject19_Control_NBackTask_Raw.cnt
# Subject 1, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject1_Control_CombinedTask_Raw.cnt
# Subject 1, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject1_Control_GoNogoTask_Raw.cnt
# Subject 1, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject1_Control_NBackTask_Raw.cnt
# Subject 20, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject20_Control_CombinedTask_Raw.cnt
# Subject 20, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject20_Control_GoNogoTask_Raw.cnt
# Subject 20, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject20_Control_NBackTask_Raw.cnt
# Subject 21, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject21_Control_CombinedTask_Raw.cnt
# Subject 21, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject21_Control_GoNogoTask_Raw.cnt
# Subject 21, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject21_Control_NBackTask_Raw.cnt
# Subject 22, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject22_Control_CombinedTask_Raw.cnt
# Subject 22, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject22_Control_GoNogoTask_Raw.cnt
# Subject 22, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject22_Control_NBackTask_Raw.cnt
# Subject 23, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject23_Control_CombinedTask_Raw.cnt
# Subject 23, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject23_Control_GoNogoTask_Raw.cnt
# Subject 23, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject23_Control_NBackTask_Raw.cnt
# Subject 24, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject24_Control_CombinedTask_Raw.cnt
# Subject 24, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject24_Control_GoNogoTask_Raw.cnt
# Subject 24, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject24_Control_NBackTask_Raw.cnt
# Subject 25, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject25_Control_CombinedTask_Raw.cnt
# Subject 25, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject25_Control_GoNogoTask_Raw.cnt
# Subject 25, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject25_Control_NBackTask_Raw.cnt
# Subject 26, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject26_ADHD_CombinedTask_Raw.cnt
# Subject 27, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject27_ADHD_CombinedTask_Raw.cnt
# Subject 28, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject28_ADHD_CombinedTask_Raw.cnt
# Subject 29, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject29_ADHD_CombinedTask_Raw.cnt
# Subject 2, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject2_Control_CombinedTask_Raw.cnt
# Subject 2, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject2_Control_GoNogoTask_Raw.cnt
# Subject 2, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject2_Control_NBackTask_Raw.cnt
# Subject 30, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject30_ADHD_CombinedTask_Raw.cnt
# Subject 31, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject31_ADHD_CombinedTask_Raw.cnt
# Subject 32, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject32_ADHD_CombinedTask_Raw.cnt
# Subject 33, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject33_ADHD_CombinedTask_Raw.cnt
# Subject 34, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject34_ADHD_CombinedTask_Raw.cnt
# Subject 35, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject35_ADHD_CombinedTask_Raw.cnt
# Subject 36, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject36_ADHD_CombinedTask_Raw.cnt
# Subject 37, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject37_ADHD_CombinedTask_Raw.cnt
# Subject 38, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject38_ADHD_CombinedTask_Raw.cnt
# Subject 39, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject39_ADHD_CombinedTask_Raw.cnt
# Subject 3, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject3_Control_CombinedTask_Raw.cnt
# Subject 3, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject3_Control_GoNogoTask_Raw.cnt
# Subject 3, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject3_Control_NBackTask_Raw.cnt
# Subject 40, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject40_ADHD_CombinedTask_Raw.cnt
# Subject 41, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject41_ADHD_CombinedTask_Raw.cnt
# Subject 42, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject42_ADHD_CombinedTask_Raw.cnt
# Subject 43, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject43_ADHD_CombinedTask_Raw.cnt
# Subject 44, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject44_ADHD_CombinedTask_Raw.cnt
# Subject 45, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject45_ADHD_CombinedTask_Raw.cnt
# Subject 46, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject46_ADHD_CombinedTask_Raw.cnt
# Subject 47, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject47_ADHD_CombinedTask_Raw.cnt
# Subject 48, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject48_ADHD_CombinedTask_Raw.cnt
# Subject 49, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject49_ADHD_CombinedTask_Raw.cnt
# Subject 4, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject4_Control_CombinedTask_Raw.cnt
# Subject 4, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject4_Control_GoNogoTask_Raw.cnt
# Subject 4, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject4_Control_NBackTask_Raw.cnt
# Subject 50, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject50_ADHD_CombinedTask_Raw.cnt
# Subject 51, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject51_ADHD_CombinedTask_Raw.cnt
# Subject 52, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject52_ADHD_CombinedTask_Raw.cnt
# Subject 53, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject53_ADHD_CombinedTask_Raw.cnt
# Subject 54, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject54_ADHD_CombinedTask_Raw.cnt
# Subject 55, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject55_ADHD_CombinedTask_Raw.cnt
# Subject 56, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject56_ADHD_CombinedTask_Raw.cnt
# Subject 57, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject57_ADHD_CombinedTask_Raw.cnt
# Subject 58, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject58_ADHD_CombinedTask_Raw.cnt
# Subject 59, Group=ADHD, DiseaseID=1, Task=CombinedTask, File=Subject59_ADHD_CombinedTask_Raw.cnt
# Subject 5, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject5_Control_CombinedTask_Raw.cnt
# Subject 5, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject5_Control_GoNogoTask_Raw.cnt
# Subject 5, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject5_Control_NBackTask_Raw.cnt
# Subject 6, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject6_Control_GoNogoTask_Raw.cnt
# Subject 6, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject6_Control_NBackTask_Raw.cnt
# Subject 7, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject7_Control_CombinedTask_Raw.cnt
# Subject 7, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject7_Control_GoNogoTask_Raw.cnt
# Subject 7, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject7_Control_NBackTask_Raw.cnt
# Subject 8, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject8_Control_CombinedTask_Raw.cnt
# Subject 8, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject8_Control_GoNogoTask_Raw.cnt
# Subject 8, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject8_Control_NBackTask_Raw.cnt
# Subject 9, Group=Control, DiseaseID=0, Task=CombinedTask, File=Subject9_Control_CombinedTask_Raw.cnt
# Subject 9, Group=Control, DiseaseID=0, Task=GoNogoTask, File=Subject9_Control_GoNogoTask_Raw.cnt
# Subject 9, Group=Control, DiseaseID=0, Task=NBackTask, File=Subject9_Control_NBackTask_Raw.cnt

# %%
bad_channel_list, sampling_freq_list, data_shape_list = [], [], []

for file in os.listdir(root):
    if file.endswith(".cnt"):  # Find all .cnt files
        file_path = os.path.join(root, file)
        print(f"🔹 Loading {file_path} ...")
        
        # Load EEG data (Neuroscan CNT format)
        raw = mne.io.read_raw_cnt(file_path, preload=True, verbose=False)

        # Get bad channels (if any are marked)
        bad_channel = raw.info['bads']
        bad_channel_list.append(bad_channel)

        # Get sampling rate
        sampling_freq = raw.info['sfreq']
        sampling_freq_list.append(sampling_freq)

        #  Get data shape
        data = raw.get_data()
        data_shape = data.shape
        data_shape_list.append(data_shape)
# Out:
# 🔹 Loading ADHD-WMRI/Subject10_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject10_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject10_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject11_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject11_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject11_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject12_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject12_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject12_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject13_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject13_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject13_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject14_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject14_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject14_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject15_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject15_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject15_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject16_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject16_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject16_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject17_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject17_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject17_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject18_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject18_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject18_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject19_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject19_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject19_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject1_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject1_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject1_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject20_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject20_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject20_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject21_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject21_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject21_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject22_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject22_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject22_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject23_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject23_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject23_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject24_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject24_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject24_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject25_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject25_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject25_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject26_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject27_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject28_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject29_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject2_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject2_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject2_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject30_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject31_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject32_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject33_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject34_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject35_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject36_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject37_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject38_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject39_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject3_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject3_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject3_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject40_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject41_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject42_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject43_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject44_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject45_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject46_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject47_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject48_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject49_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject4_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject4_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject4_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject50_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject51_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject52_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject53_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject54_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject55_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject56_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject57_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject58_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject59_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject5_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject5_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject5_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject6a_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject6b_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject6_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject6_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject7_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject7_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject7_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject8_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject8_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject8_Control_NBackTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject9_Control_CombinedTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject9_Control_GoNogoTask_Raw.cnt ...
# 🔹 Loading ADHD-WMRI/Subject9_Control_NBackTask_Raw.cnt ...

# %%
from collections import Counter

print(bad_channel_list)
print(data_shape_list[0])
print("Channel number counter:", Counter(i[0] for i in data_shape_list))
print("Sampling rate counter:", Counter(sampling_freq_list))
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# (23, 461400)
# Channel number counter: Counter({23: 110})
# Sampling rate counter: Counter({500.0: 110})

# %%
# channel number not consistent, take the common channels
common_channels = None

for file in os.listdir(root):
    if file.endswith(".cnt"):  # Iterate over all .cnt files
        file_path = os.path.join(root, file)
        print(f"🔹 Checking channels in {file_path} ...")

        raw = mne.io.read_raw_cnt(file_path, preload=False, verbose=False)  # Read data without fully loading it

        current_channels = set(raw.info['ch_names'])  # Channels of the current file
        if common_channels is None:
            common_channels = current_channels
        else:
            common_channels &= current_channels  # Take the intersection

# Convert to list and sort
if common_channels is None:
    common_channels = []
else:
    common_channels = sorted(list(common_channels))
print(common_channels)
print("Common channels number: ", len(common_channels))
# Out:
# 🔹 Checking channels in ADHD-WMRI/Subject10_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject10_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject10_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject11_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject11_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject11_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject12_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject12_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject12_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject13_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject13_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject13_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject14_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject14_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject14_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject15_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject15_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject15_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject16_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject16_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject16_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject17_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject17_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject17_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject18_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject18_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject18_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject19_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject19_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject19_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject1_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject1_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject1_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject20_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject20_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject20_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject21_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject21_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject21_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject22_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject22_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject22_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject23_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject23_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject23_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject24_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject24_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject24_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject25_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject25_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject25_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject26_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject27_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject28_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject29_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject2_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject2_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject2_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject30_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject31_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject32_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject33_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject34_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject35_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject36_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject37_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject38_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject39_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject3_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject3_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject3_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject40_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject41_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject42_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject43_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject44_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject45_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject46_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject47_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject48_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject49_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject4_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject4_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject4_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject50_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject51_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject52_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject53_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject54_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject55_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject56_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject57_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject58_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject59_ADHD_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject5_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject5_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject5_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject6a_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject6b_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject6_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject6_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject7_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject7_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject7_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject8_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject8_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject8_Control_NBackTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject9_Control_CombinedTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject9_Control_GoNogoTask_Raw.cnt ...
# 🔹 Checking channels in ADHD-WMRI/Subject9_Control_NBackTask_Raw.cnt ...
# ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# Common channels number:  23

# %%
feature_path = 'Processed/' + sub_folder_path + '/ADHD-WMRI/Feature'
if not os.path.exists(feature_path):
    os.makedirs(feature_path)
    
label_path = 'Processed/' + sub_folder_path + '/ADHD-WMRI/Label'
if not os.path.exists(label_path):
    os.makedirs(label_path)

# %%
def data_preprocessing(
    raw: mne.io.Raw,
    common_channels: list,
    sample_rate: int = 250,
    notch_freq: float = 50.0,
    l_freq: float = 0.5,
    h_freq: float = 40.0,
    do_bad_interp: bool = True,
    verbose: bool = True,
):
    """
    Preprocessing steps ：
      1) choose common channels and reorder
      2) Set Montage 
      3) 50 Hz Notch（before band pass）
      4) bandpass filter（default 0.5–40 Hz）
      5) interpolate bad channels（if do_bad_interp is True）
      6) re-reference to average
      7) ICA (fit on a 1 Hz high-pass filtered copy; automatically exclude eye/muscle artifacts using mne-icalabel)
      8) downsample to 250 Hz
    """
    
    # 1. select common channels and reorder to given order
    keep = [ch for ch in common_channels if ch in raw.ch_names]
    raw.pick_channels(keep)
    raw.reorder_channels(keep)
    if verbose:
        print(f"✔ Step 2: Picked common channels ({len(keep)}): {keep}")
    # Remove non-EEG channels
    raw.drop_channels([ch for ch in ['HEOG', 'VEOG'] if ch in raw.ch_names])
    channel_types = raw.get_channel_types(picks=None)
    non_eeg_channels = [ch_name for ch_name, ch_type in zip(raw.ch_names, channel_types) if ch_type != 'eeg']
    if non_eeg_channels:
        raw.drop_channels(non_eeg_channels)
        if verbose:
            print(f"✔ Step 2.5: Dropped non-EEG channels: {non_eeg_channels}")
            
    # Channel renaming map (to ensure compatibility with the standard_1020 format)
    rename_dict = {
        'FP1': 'Fp1',
        'FP2': 'Fp2',
        'FZ': 'Fz',
        'CZ': 'Cz',
        'PZ': 'Pz',
    }

    # Rename only the channels that exist in raw
    rename_dict = {k: v for k, v in rename_dict.items() if k in raw.ch_names}
    raw.rename_channels(rename_dict)

    
    # 2. Set Montage
    raw.set_montage(mne.channels.make_standard_montage('standard_1020'))
    if verbose:
        print("✔ Step 1, Montage set: 'standard_1020'.")
        
    # 3. Notch
    if notch_freq is not None:
        raw.notch_filter(freqs=[notch_freq], picks="eeg", verbose=False)
        if verbose:
            print(f"✔ Step 3: Notch @ {notch_freq} Hz")
        
    # 4. Bandpass Filter (0.5–40 Hz)
    raw.filter(l_freq=l_freq, h_freq=h_freq, picks="eeg", verbose=False)
    if verbose:
        print(f"✔ Step 4: Band-pass {l_freq}–{h_freq} Hz")
        
    # 5. Interpolate bad channels
    if do_bad_interp and raw.info.get("bads"):
        raw.interpolate_bads(reset_bads=True, verbose=False)
        if verbose:
            print(f"✔ Step 5: Interpolated bads: {raw.info.get('bads', [])}")
    else:
        if verbose:
            print("ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)")
            
    # 6) Re-reference to average
    raw.set_eeg_reference("average", verbose=False)
    if verbose:
        print("✔ Step 6: Average reference")
    
    print()
    # 7) ICA (fit ICLabel on 1 Hz high-pass filtered copy, then apply to original)
    raw_for_ica = raw.copy().filter(l_freq=1.0, h_freq=None, picks="eeg", verbose=False)
    ica = ICA(n_components=0.999, method="fastica", random_state=97, max_iter="auto")
    ica.fit(raw_for_ica)

    excluded = []
    if label_components is not None:
        try:
            ic_labels = label_components(raw_for_ica, ica, method="iclabel")
            labels = ic_labels["labels"]
            probs = ic_labels["y_pred_proba"]  # (n_comp, n_classes)
            thresholds = {
                "eye blink": 0.7,
                "muscle artifact": 0.6,
                "heart beat": 0.5,
                "line noise": 0.8,
                "channel noise": 0.9,
            }
            for i, lab in enumerate(labels):
                if lab in thresholds:
                    if probs is not None:
                        p = probs[i].max()
                    else:
                        p = 1.0
                    if p >= thresholds[lab]:
                        excluded.append(i)
        except Exception as e:
            if verbose:
                print(f"⚠ ICLabel failed ({e}). Skipping auto exclusion.")
    else:
        if verbose:
            print("ℹ ICLabel not available; fitted ICA but no auto component exclusion.")

    if excluded:
        ica.exclude = sorted(set(excluded))
        raw = ica.apply(raw.copy())
        if verbose:
            print(f"✔ Step 7: ICA applied. Excluded comps: {ica.exclude}")
    else:
        if verbose:
            print("ℹ Step 7: No ICA components excluded.")

    # 8) downsample to 250 Hz
    if raw.info["sfreq"] != sample_rate:
        raw.resample(sample_rate, npad="auto", verbose=False)
    if verbose:
        print(f"✔ Step 8: Resampled to {sample_rate} Hz")
        
    return raw

# %%
def epoch_and_make_xy(
    raw: mne.io.Raw,
    tmin: float = -0.2,
    tmax: float = 0.65,
    baseline=(-0.2, 0),
    task_id: int = 1,
    subject_id: int = 1,
    disease_id: int = 1,
    task_type: str = "CombinedTask",  # "NBackTask", "GoNogoTask", or "CombinedTask"
):
    """
    # Extract stimulus events (S 2) from the .cnt file to construct epochs and labels. No external behavioral file required.
    # Applicable when event information is already included in raw.annotations.
    """

    # Extract annotations and convert to events
    if not raw.annotations or len(raw.annotations) == 0:
        raise ValueError("raw.annotations is empty; unable to extract events from the .cnt file.")
    events, _ = mne.events_from_annotations(raw)
    
    # Filter stimulus events with code == 2
    stimulus_events = events[events[:, 2] == 2]
    if len(stimulus_events) == 0:
        raise ValueError("No stimulus events with code == 2 (S 2) were found.")

    # epoching
    picks = mne.pick_types(raw.info, eeg=True, eog=False, exclude="bads")
    epochs = mne.Epochs(
        raw,
        events=stimulus_events,
        event_id={"stimulus": 2},
        tmin=tmin,
        tmax=tmax,
        baseline=baseline,
        picks=picks,
        proj=False,
        preload=True,
        reject=None,
        verbose=False,
    )

    # Ensure consistent epoch length
    sfreq = raw.info["sfreq"]
    target_len = int((tmax - tmin) * sfreq)
    data = epochs.get_data()  # shape: (N, C, T)
    if data.shape[-1] > target_len:
        data = data[..., :target_len]
    elif data.shape[-1] < target_len:
        pad = target_len - data.shape[-1]
        data = np.pad(data, ((0, 0), (0, 0), (0, pad)), mode="edge")

    # Convert to (N, T, C)
    X = np.transpose(data, (0, 2, 1))

    # Cannot access behavioral labels for now; use empty or default labels
    # If you know the stimulus trial type (target / nogo / go) for the given task_type, you can assign a uniform label
    N = len(X)
    if task_type == "NBackTask":
        y0 = np.zeros(N, dtype=int)  
    elif task_type == "GoNogoTask":
        y0 = np.ones(N, dtype=int)  
    elif task_type == "CombinedTask":
        y0 = np.full(N, 2, dtype=int)  
    else:
        raise ValueError(f"Unsupported task_type: {task_type}")

    y = np.column_stack([
        y0,
        np.ones(N, dtype=int),  # All marked as correct (placeholder)
        np.full(N, task_id),
        np.full(N, subject_id),
        np.full(N, disease_id),
    ])

    return X, y

# %%
from collections import defaultdict

files_by_sub = defaultdict(list)
for fname in os.listdir(root):
    if not fname.endswith(".cnt"):
        continue
    m = re.search(r"Subject(\d+)", fname)
    if not m:
        continue
    sid = int(m.group(1))
    files_by_sub[sid].append(fname)
files_by_sub
# Out:
# defaultdict(list,
#             {10: ['Subject10_Control_CombinedTask_Raw.cnt',
#               'Subject10_Control_GoNogoTask_Raw.cnt',
#               'Subject10_Control_NBackTask_Raw.cnt'],
#              11: ['Subject11_Control_CombinedTask_Raw.cnt',
#               'Subject11_Control_GoNogoTask_Raw.cnt',
#               'Subject11_Control_NBackTask_Raw.cnt'],
#              12: ['Subject12_Control_CombinedTask_Raw.cnt',
#               'Subject12_Control_GoNogoTask_Raw.cnt',
#               'Subject12_Control_NBackTask_Raw.cnt'],
#              13: ['Subject13_Control_CombinedTask_Raw.cnt',
#               'Subject13_Control_GoNogoTask_Raw.cnt',
#               'Subject13_Control_NBackTask_Raw.cnt'],
#              14: ['Subject14_Control_CombinedTask_Raw.cnt',
#               'Subject14_Control_GoNogoTask_Raw.cnt',
#               'Subject14_Control_NBackTask_Raw.cnt'],
#              15: ['Subject15_Control_CombinedTask_Raw.cnt',
#               'Subject15_Control_GoNogoTask_Raw.cnt',
#               'Subject15_Control_NBackTask_Raw.cnt'],
#              16: ['Subject16_Control_CombinedTask_Raw.cnt',
#               'Subject16_Control_GoNogoTask_Raw.cnt',
#               'Subject16_Control_NBackTask_Raw.cnt'],
#              17: ['Subject17_Control_CombinedTask_Raw.cnt',
#               'Subject17_Control_GoNogoTask_Raw.cnt',
#               'Subject17_Control_NBackTask_Raw.cnt'],
#              18: ['Subject18_Control_CombinedTask_Raw.cnt',
#               'Subject18_Control_GoNogoTask_Raw.cnt',
#               'Subject18_Control_NBackTask_Raw.cnt'],
#              19: ['Subject19_Control_CombinedTask_Raw.cnt',
#               'Subject19_Control_GoNogoTask_Raw.cnt',
#               'Subject19_Control_NBackTask_Raw.cnt'],
#              1: ['Subject1_Control_CombinedTask_Raw.cnt',
#               'Subject1_Control_GoNogoTask_Raw.cnt',
#               'Subject1_Control_NBackTask_Raw.cnt'],
#              20: ['Subject20_Control_CombinedTask_Raw.cnt',
#               'Subject20_Control_GoNogoTask_Raw.cnt',
#               'Subject20_Control_NBackTask_Raw.cnt'],
#              21: ['Subject21_Control_CombinedTask_Raw.cnt',
#               'Subject21_Control_GoNogoTask_Raw.cnt',
#               'Subject21_Control_NBackTask_Raw.cnt'],
#              22: ['Subject22_Control_CombinedTask_Raw.cnt',
#               'Subject22_Control_GoNogoTask_Raw.cnt',
#               'Subject22_Control_NBackTask_Raw.cnt'],
#              23: ['Subject23_Control_CombinedTask_Raw.cnt',
#               'Subject23_Control_GoNogoTask_Raw.cnt',
#               'Subject23_Control_NBackTask_Raw.cnt'],
#              24: ['Subject24_Control_CombinedTask_Raw.cnt',
#               'Subject24_Control_GoNogoTask_Raw.cnt',
#               'Subject24_Control_NBackTask_Raw.cnt'],
#              25: ['Subject25_Control_CombinedTask_Raw.cnt',
#               'Subject25_Control_GoNogoTask_Raw.cnt',
#               'Subject25_Control_NBackTask_Raw.cnt'],
#              26: ['Subject26_ADHD_CombinedTask_Raw.cnt'],
#              27: ['Subject27_ADHD_CombinedTask_Raw.cnt'],
#              28: ['Subject28_ADHD_CombinedTask_Raw.cnt'],
#              29: ['Subject29_ADHD_CombinedTask_Raw.cnt'],
#              2: ['Subject2_Control_CombinedTask_Raw.cnt',
#               'Subject2_Control_GoNogoTask_Raw.cnt',
#               'Subject2_Control_NBackTask_Raw.cnt'],
#              30: ['Subject30_ADHD_CombinedTask_Raw.cnt'],
#              31: ['Subject31_ADHD_CombinedTask_Raw.cnt'],
#              32: ['Subject32_ADHD_CombinedTask_Raw.cnt'],
#              33: ['Subject33_ADHD_CombinedTask_Raw.cnt'],
#              34: ['Subject34_ADHD_CombinedTask_Raw.cnt'],
#              35: ['Subject35_ADHD_CombinedTask_Raw.cnt'],
#              36: ['Subject36_ADHD_CombinedTask_Raw.cnt'],
#              37: ['Subject37_ADHD_CombinedTask_Raw.cnt'],
#              38: ['Subject38_ADHD_CombinedTask_Raw.cnt'],
#              39: ['Subject39_ADHD_CombinedTask_Raw.cnt'],
#              3: ['Subject3_Control_CombinedTask_Raw.cnt',
#               'Subject3_Control_GoNogoTask_Raw.cnt',
#               'Subject3_Control_NBackTask_Raw.cnt'],
#              40: ['Subject40_ADHD_CombinedTask_Raw.cnt'],
#              41: ['Subject41_ADHD_CombinedTask_Raw.cnt'],
#              42: ['Subject42_ADHD_CombinedTask_Raw.cnt'],
#              43: ['Subject43_ADHD_CombinedTask_Raw.cnt'],
#              44: ['Subject44_ADHD_CombinedTask_Raw.cnt'],
#              45: ['Subject45_ADHD_CombinedTask_Raw.cnt'],
#              46: ['Subject46_ADHD_CombinedTask_Raw.cnt'],
#              47: ['Subject47_ADHD_CombinedTask_Raw.cnt'],
#              48: ['Subject48_ADHD_CombinedTask_Raw.cnt'],
#              49: ['Subject49_ADHD_CombinedTask_Raw.cnt'],
#              4: ['Subject4_Control_CombinedTask_Raw.cnt',
#               'Subject4_Control_GoNogoTask_Raw.cnt',
#               'Subject4_Control_NBackTask_Raw.cnt'],
#              50: ['Subject50_ADHD_CombinedTask_Raw.cnt'],
#              51: ['Subject51_ADHD_CombinedTask_Raw.cnt'],
#              52: ['Subject52_ADHD_CombinedTask_Raw.cnt'],
#              53: ['Subject53_ADHD_CombinedTask_Raw.cnt'],
#              54: ['Subject54_ADHD_CombinedTask_Raw.cnt'],
#              55: ['Subject55_ADHD_CombinedTask_Raw.cnt'],
#              56: ['Subject56_ADHD_CombinedTask_Raw.cnt'],
#              57: ['Subject57_ADHD_CombinedTask_Raw.cnt'],
#              58: ['Subject58_ADHD_CombinedTask_Raw.cnt'],
#              59: ['Subject59_ADHD_CombinedTask_Raw.cnt'],
#              5: ['Subject5_Control_CombinedTask_Raw.cnt',
#               'Subject5_Control_GoNogoTask_Raw.cnt',
#               'Subject5_Control_NBackTask_Raw.cnt'],
#              6: ['Subject6a_Control_CombinedTask_Raw.cnt',
#               'Subject6b_Control_CombinedTask_Raw.cnt',
#               'Subject6_Control_GoNogoTask_Raw.cnt',
#               'Subject6_Control_NBackTask_Raw.cnt'],
#              7: ['Subject7_Control_CombinedTask_Raw.cnt',
#               'Subject7_Control_GoNogoTask_Raw.cnt',
#               'Subject7_Control_NBackTask_Raw.cnt'],
#              8: ['Subject8_Control_CombinedTask_Raw.cnt',
#               'Subject8_Control_GoNogoTask_Raw.cnt',
#               'Subject8_Control_NBackTask_Raw.cnt'],
#              9: ['Subject9_Control_CombinedTask_Raw.cnt',
#               'Subject9_Control_GoNogoTask_Raw.cnt',
#               'Subject9_Control_NBackTask_Raw.cnt']})

# %%
for subject_id, file_list in sorted(files_by_sub.items()):
    X_parts, y_parts = [], []
    print(f"\n=== Subject {subject_id:03d} ===")
    print(file_list)
    
    for filename in file_list:
        print("Current file:", filename)

        # Extract subject_id, group, and task_type from the filename
        name_parts = filename.replace(".cnt", "").split("_")
        group = name_parts[1]  # Control or PD
        task_type = name_parts[2]  # NBackTask / GoNogoTask / CombinedTask

        disease_id = 0 if group == "Control" else 1
        task_id = {"NBackTask": 0, "GoNogoTask": 1, "CombinedTask": 2}[task_type]

        raw_path = os.path.join(root, filename)
        print(f"Subject ID: {subject_id}, Group: {group}, Task: {task_type}")

        raw = mne.io.read_raw_cnt(raw_path, preload=True)
        raw = data_preprocessing(raw, common_channels, SAMPLE_RATE, verbose=True)

        X, y = epoch_and_make_xy(
            raw,
            tmin=-0.2,
            tmax=0.65,
            baseline=(-0.2, 0),
            task_id=task_id,
            subject_id=subject_id,
            disease_id=disease_id,
            task_type=task_type
        )

        print(f"Task {task_id} trial with X shape: {X.shape}, y shape: {y.shape}")
        X_parts.append(X)   # X: (N, T, C)
        y_parts.append(y)   # y: (N, 5) = [task_id, stimulus_type, subject_id, session_id?, disease_id]
        print("----------------\n")

    if X_parts:
        X_all = np.concatenate(X_parts, axis=0)
        y_all = np.concatenate(y_parts, axis=0)
        np.save(os.path.join(feature_path, f"feature_{subject_id:03d}.npy"), X_all)
        np.save(os.path.join(label_path,   f"label_{subject_id:03d}.npy"),   y_all)
        print(f"Saved Subject {subject_id:03d}: X {X_all.shape}, y {y_all.shape}")
    else:
        print(f"(Nothing to save for Subject {subject_id:03d})")

    print("------------------------------------------------\n")
# Out:
# === Subject 001 ===
# ['Subject1_Control_CombinedTask_Raw.cnt', 'Subject1_Control_GoNogoTask_Raw.cnt', 'Subject1_Control_NBackTask_Raw.cnt']
# Current file: Subject1_Control_CombinedTask_Raw.cnt
# Subject ID: 1, Group: Control, Task: CombinedTask
# Reading 0 ... 467199  =      0.000 ...   934.398 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 8.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [2, 5, 15, 17, 19]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (206, 170, 21), y shape: (206, 5)
# ----------------
#
# Current file: Subject1_Control_GoNogoTask_Raw.cnt
# Subject ID: 1, Group: Control, Task: GoNogoTask
# Reading 0 ... 454859  =      0.000 ...   909.718 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 13, 15, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (270, 170, 21), y shape: (270, 5)
# ----------------
#
# Current file: Subject1_Control_NBackTask_Raw.cnt
# Subject ID: 1, Group: Control, Task: NBackTask
# Reading 0 ... 401199  =      0.000 ...   802.398 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 3.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 6 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 11, 13, 14, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 001: X (536, 170, 21), y (536, 5)
# ------------------------------------------------
#
#
# === Subject 002 ===
# ['Subject2_Control_CombinedTask_Raw.cnt', 'Subject2_Control_GoNogoTask_Raw.cnt', 'Subject2_Control_NBackTask_Raw.cnt']
# Current file: Subject2_Control_CombinedTask_Raw.cnt
# Subject ID: 2, Group: Control, Task: CombinedTask
# Reading 0 ... 466919  =      0.000 ...   933.838 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 18 components
# Fitting ICA took 2.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (18 components)
#     Zeroing out 4 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 10, 15]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (206, 170, 21), y shape: (206, 5)
# ----------------
#
# Current file: Subject2_Control_GoNogoTask_Raw.cnt
# Subject ID: 2, Group: Control, Task: GoNogoTask
# Reading 0 ... 455299  =      0.000 ...   910.598 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 18 components
# Fitting ICA took 2.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (18 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 11, 15, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '73']
# Task 1 trial with X shape: (270, 170, 21), y shape: (270, 5)
# ----------------
#
# Current file: Subject2_Control_NBackTask_Raw.cnt
# Subject ID: 2, Group: Control, Task: NBackTask
# Reading 0 ... 413179  =      0.000 ...   826.358 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 18 components
# Fitting ICA took 3.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (18 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 12, 14, 15]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 002: X (536, 170, 21), y (536, 5)
# ------------------------------------------------
#
#
# === Subject 003 ===
# ['Subject3_Control_CombinedTask_Raw.cnt', 'Subject3_Control_GoNogoTask_Raw.cnt', 'Subject3_Control_NBackTask_Raw.cnt']
# Current file: Subject3_Control_CombinedTask_Raw.cnt
# Subject ID: 3, Group: Control, Task: CombinedTask
# Reading 0 ... 454939  =      0.000 ...   909.878 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (205, 170, 21), y shape: (205, 5)
# ----------------
#
# Current file: Subject3_Control_GoNogoTask_Raw.cnt
# Subject ID: 3, Group: Control, Task: GoNogoTask
# Reading 0 ... 456619  =      0.000 ...   913.238 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 3.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 2, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (273, 170, 21), y shape: (273, 5)
# ----------------
#
# Current file: Subject3_Control_NBackTask_Raw.cnt
# Subject ID: 3, Group: Control, Task: NBackTask
# Reading 0 ... 373279  =      0.000 ...   746.558 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 5.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 4 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 14, 19]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 003: X (538, 170, 21), y (538, 5)
# ------------------------------------------------
#
#
# === Subject 004 ===
# ['Subject4_Control_CombinedTask_Raw.cnt', 'Subject4_Control_GoNogoTask_Raw.cnt', 'Subject4_Control_NBackTask_Raw.cnt']
# Current file: Subject4_Control_CombinedTask_Raw.cnt
# Subject ID: 4, Group: Control, Task: CombinedTask
# Reading 0 ... 461239  =      0.000 ...   922.478 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 5, 9, 11, 18]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (202, 170, 21), y shape: (202, 5)
# ----------------
#
# Current file: Subject4_Control_GoNogoTask_Raw.cnt
# Subject ID: 4, Group: Control, Task: GoNogoTask
# Reading 0 ... 460239  =      0.000 ...   920.478 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 6 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 4, 13, 15, 16, 18]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (270, 170, 21), y shape: (270, 5)
# ----------------
#
# Current file: Subject4_Control_NBackTask_Raw.cnt
# Subject ID: 4, Group: Control, Task: NBackTask
# Reading 0 ... 401659  =      0.000 ...   803.318 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 3.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 6 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 7, 10, 15, 16]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 004: X (532, 170, 21), y (532, 5)
# ------------------------------------------------
#
#
# === Subject 005 ===
# ['Subject5_Control_CombinedTask_Raw.cnt', 'Subject5_Control_GoNogoTask_Raw.cnt', 'Subject5_Control_NBackTask_Raw.cnt']
# Current file: Subject5_Control_CombinedTask_Raw.cnt
# Subject ID: 5, Group: Control, Task: CombinedTask
# Reading 0 ... 464659  =      0.000 ...   929.318 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 6.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 12]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (203, 170, 21), y shape: (203, 5)
# ----------------
#
# Current file: Subject5_Control_GoNogoTask_Raw.cnt
# Subject ID: 5, Group: Control, Task: GoNogoTask
# Reading 0 ... 576459  =      0.000 ...  1152.918 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 11.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 1 ICA component
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [5]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (270, 170, 21), y shape: (270, 5)
# ----------------
#
# Current file: Subject5_Control_NBackTask_Raw.cnt
# Subject ID: 5, Group: Control, Task: NBackTask
# Reading 0 ... 391959  =      0.000 ...   783.918 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 3]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 005: X (533, 170, 21), y (533, 5)
# ------------------------------------------------
#
#
# === Subject 006 ===
# ['Subject6a_Control_CombinedTask_Raw.cnt', 'Subject6b_Control_CombinedTask_Raw.cnt', 'Subject6_Control_GoNogoTask_Raw.cnt', 'Subject6_Control_NBackTask_Raw.cnt']
# Current file: Subject6a_Control_CombinedTask_Raw.cnt
# Subject ID: 6, Group: Control, Task: CombinedTask
# Reading 0 ... 310439  =      0.000 ...   620.878 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (136, 170, 21), y shape: (136, 5)
# ----------------
#
# Current file: Subject6b_Control_CombinedTask_Raw.cnt
# Subject ID: 6, Group: Control, Task: CombinedTask
# Reading 0 ... 127039  =      0.000 ...   254.078 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 0.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 2]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72']
# Task 2 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Current file: Subject6_Control_GoNogoTask_Raw.cnt
# Subject ID: 6, Group: Control, Task: GoNogoTask
# Reading 0 ... 466659  =      0.000 ...   933.318 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (273, 170, 21), y shape: (273, 5)
# ----------------
#
# Current file: Subject6_Control_NBackTask_Raw.cnt
# Subject ID: 6, Group: Control, Task: NBackTask
# Reading 0 ... 386279  =      0.000 ...   772.558 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 006: X (529, 170, 21), y (529, 5)
# ------------------------------------------------
#
#
# === Subject 007 ===
# ['Subject7_Control_CombinedTask_Raw.cnt', 'Subject7_Control_GoNogoTask_Raw.cnt', 'Subject7_Control_NBackTask_Raw.cnt']
# Current file: Subject7_Control_CombinedTask_Raw.cnt
# Subject ID: 7, Group: Control, Task: CombinedTask
# Reading 0 ... 455979  =      0.000 ...   911.958 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 4.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 2, 16]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (204, 170, 21), y shape: (204, 5)
# ----------------
#
# Current file: Subject7_Control_GoNogoTask_Raw.cnt
# Subject ID: 7, Group: Control, Task: GoNogoTask
# Reading 0 ... 480859  =      0.000 ...   961.718 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 2.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 3, 14, 17, 18]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (273, 170, 21), y shape: (273, 5)
# ----------------
#
# Current file: Subject7_Control_NBackTask_Raw.cnt
# Subject ID: 7, Group: Control, Task: NBackTask
# Reading 0 ... 410199  =      0.000 ...   820.398 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 2.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 2, 11, 12, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 007: X (537, 170, 21), y (537, 5)
# ------------------------------------------------
#
#
# === Subject 008 ===
# ['Subject8_Control_CombinedTask_Raw.cnt', 'Subject8_Control_GoNogoTask_Raw.cnt', 'Subject8_Control_NBackTask_Raw.cnt']
# Current file: Subject8_Control_CombinedTask_Raw.cnt
# Subject ID: 8, Group: Control, Task: CombinedTask
# Reading 0 ... 467719  =      0.000 ...   935.438 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 2.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 2]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (198, 170, 21), y shape: (198, 5)
# ----------------
#
# Current file: Subject8_Control_GoNogoTask_Raw.cnt
# Subject ID: 8, Group: Control, Task: GoNogoTask
# Reading 0 ... 458279  =      0.000 ...   916.558 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 18 components
# Fitting ICA took 2.9s.
# ℹ Step 7: No ICA components excluded.
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (270, 170, 21), y shape: (270, 5)
# ----------------
#
# Current file: Subject8_Control_NBackTask_Raw.cnt
# Subject ID: 8, Group: Control, Task: NBackTask
# Reading 0 ... 404679  =      0.000 ...   809.358 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 3.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 13]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 008: X (528, 170, 21), y (528, 5)
# ------------------------------------------------
#
#
# === Subject 009 ===
# ['Subject9_Control_CombinedTask_Raw.cnt', 'Subject9_Control_GoNogoTask_Raw.cnt', 'Subject9_Control_NBackTask_Raw.cnt']
# Current file: Subject9_Control_CombinedTask_Raw.cnt
# Subject ID: 9, Group: Control, Task: CombinedTask
# Reading 0 ... 461099  =      0.000 ...   922.198 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 17 components
# Fitting ICA took 2.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (17 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (204, 170, 21), y shape: (204, 5)
# ----------------
#
# Current file: Subject9_Control_GoNogoTask_Raw.cnt
# Subject ID: 9, Group: Control, Task: GoNogoTask
# Reading 0 ... 458139  =      0.000 ...   916.278 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 18 components
# Fitting ICA took 4.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (18 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (273, 170, 21), y shape: (273, 5)
# ----------------
#
# Current file: Subject9_Control_NBackTask_Raw.cnt
# Subject ID: 9, Group: Control, Task: NBackTask
# Reading 0 ... 397499  =      0.000 ...   794.998 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 18 components
# Fitting ICA took 4.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (18 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 14]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 009: X (537, 170, 21), y (537, 5)
# ------------------------------------------------
#
#
# === Subject 010 ===
# ['Subject10_Control_CombinedTask_Raw.cnt', 'Subject10_Control_GoNogoTask_Raw.cnt', 'Subject10_Control_NBackTask_Raw.cnt']
# Current file: Subject10_Control_CombinedTask_Raw.cnt
# Subject ID: 10, Group: Control, Task: CombinedTask
# Reading 0 ... 461399  =      0.000 ...   922.798 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 3.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (206, 170, 21), y shape: (206, 5)
# ----------------
#
# Current file: Subject10_Control_GoNogoTask_Raw.cnt
# Subject ID: 10, Group: Control, Task: GoNogoTask
# Reading 0 ... 460419  =      0.000 ...   920.838 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 3.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 15]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (273, 170, 21), y shape: (273, 5)
# ----------------
#
# Current file: Subject10_Control_NBackTask_Raw.cnt
# Subject ID: 10, Group: Control, Task: NBackTask
# Reading 0 ... 390959  =      0.000 ...   781.918 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 2.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 15, 17, 18]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 010: X (539, 170, 21), y (539, 5)
# ------------------------------------------------
#
#
# === Subject 011 ===
# ['Subject11_Control_CombinedTask_Raw.cnt', 'Subject11_Control_GoNogoTask_Raw.cnt', 'Subject11_Control_NBackTask_Raw.cnt']
# Current file: Subject11_Control_CombinedTask_Raw.cnt
# Subject ID: 11, Group: Control, Task: CombinedTask
# Reading 0 ... 472619  =      0.000 ...   945.238 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 3.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 7 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 3, 6, 13, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (203, 170, 21), y shape: (203, 5)
# ----------------
#
# Current file: Subject11_Control_GoNogoTask_Raw.cnt
# Subject ID: 11, Group: Control, Task: GoNogoTask
# Reading 0 ... 465919  =      0.000 ...   931.838 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 2.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 6 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 3, 5, 10]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (267, 170, 21), y shape: (267, 5)
# ----------------
#
# Current file: Subject11_Control_NBackTask_Raw.cnt
# Subject ID: 11, Group: Control, Task: NBackTask
# Reading 0 ... 389219  =      0.000 ...   778.438 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 4.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 6 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 3, 8, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 011: X (530, 170, 21), y (530, 5)
# ------------------------------------------------
#
#
# === Subject 012 ===
# ['Subject12_Control_CombinedTask_Raw.cnt', 'Subject12_Control_GoNogoTask_Raw.cnt', 'Subject12_Control_NBackTask_Raw.cnt']
# Current file: Subject12_Control_CombinedTask_Raw.cnt
# Subject ID: 12, Group: Control, Task: CombinedTask
# Reading 0 ... 460599  =      0.000 ...   921.198 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 6.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 6 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 2, 3, 9, 15, 16]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (203, 170, 21), y shape: (203, 5)
# ----------------
#
# Current file: Subject12_Control_GoNogoTask_Raw.cnt
# Subject ID: 12, Group: Control, Task: GoNogoTask
# Reading 0 ... 456339  =      0.000 ...   912.678 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 2, 4, 9, 19]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '31', '71', '73']
# Task 1 trial with X shape: (272, 170, 21), y shape: (272, 5)
# ----------------
#
# Current file: Subject12_Control_NBackTask_Raw.cnt
# Subject ID: 12, Group: Control, Task: NBackTask
# Reading 0 ... 423739  =      0.000 ...   847.478 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 3.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 12]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['21', '22', '31', '32', '71', '72', '73']
# Task 0 trial with X shape: (60, 170, 21), y shape: (60, 5)
# ----------------
#
# Saved Subject 012: X (535, 170, 21), y (535, 5)
# ------------------------------------------------
#
#
# === Subject 013 ===
# ['Subject13_Control_CombinedTask_Raw.cnt', 'Subject13_Control_GoNogoTask_Raw.cnt', 'Subject13_Control_NBackTask_Raw.cnt']
# Current file: Subject13_Control_CombinedTask_Raw.cnt
# Subject ID: 13, Group: Control, Task: CombinedTask
# Reading 0 ... 471859  =      0.000 ...   943.718 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 6, 18]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (204, 170, 21), y shape: (204, 5)
# ----------------
#
# Current file: Subject13_Control_GoNogoTask_Raw.cnt
# Subject ID: 13, Group: Control, Task: GoNogoTask
# Reading 0 ... 479179  =      0.000 ...   958.358 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 6 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 6, 11, 15, 17, 18]
# ...
# ------------------------------------------------
#
#
# === Subject 048 ===
# ['Subject48_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject48_ADHD_CombinedTask_Raw.cnt
# Subject ID: 48, Group: ADHD, Task: CombinedTask
# Reading 0 ... 749579  =      0.000 ...  1499.158 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 6.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [1, 5, 16]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (268, 170, 21), y shape: (268, 5)
# ----------------
#
# Saved Subject 048: X (268, 170, 21), y (268, 5)
# ------------------------------------------------
#
#
# === Subject 049 ===
# ['Subject49_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject49_ADHD_CombinedTask_Raw.cnt
# Subject ID: 49, Group: ADHD, Task: CombinedTask
# Reading 0 ... 739899  =      0.000 ...  1479.798 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 7.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 5 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [1, 3, 5, 6, 11]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (265, 170, 21), y shape: (265, 5)
# ----------------
#
# Saved Subject 049: X (265, 170, 21), y (265, 5)
# ------------------------------------------------
#
#
# === Subject 050 ===
# ['Subject50_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject50_ADHD_CombinedTask_Raw.cnt
# Subject ID: 50, Group: ADHD, Task: CombinedTask
# Reading 0 ... 673219  =      0.000 ...  1346.438 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 5.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 6 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 10, 13, 14, 16]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (270, 170, 21), y shape: (270, 5)
# ----------------
#
# Saved Subject 050: X (270, 170, 21), y (270, 5)
# ------------------------------------------------
#
#
# === Subject 051 ===
# ['Subject51_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject51_ADHD_CombinedTask_Raw.cnt
# Subject ID: 51, Group: ADHD, Task: CombinedTask
# Reading 0 ... 681259  =      0.000 ...  1362.518 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 6.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 4]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (259, 170, 21), y shape: (259, 5)
# ----------------
#
# Saved Subject 051: X (259, 170, 21), y (259, 5)
# ------------------------------------------------
#
#
# === Subject 052 ===
# ['Subject52_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject52_ADHD_CombinedTask_Raw.cnt
# Subject ID: 52, Group: ADHD, Task: CombinedTask
# Reading 0 ... 637039  =      0.000 ...  1274.078 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 4.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 13]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (266, 170, 21), y shape: (266, 5)
# ----------------
#
# Saved Subject 052: X (266, 170, 21), y (266, 5)
# ------------------------------------------------
#
#
# === Subject 053 ===
# ['Subject53_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject53_ADHD_CombinedTask_Raw.cnt
# Subject ID: 53, Group: ADHD, Task: CombinedTask
# Reading 0 ... 772479  =      0.000 ...  1544.958 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 5.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 6 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 6, 7, 10]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (267, 170, 21), y shape: (267, 5)
# ----------------
#
# Saved Subject 053: X (267, 170, 21), y (267, 5)
# ------------------------------------------------
#
#
# === Subject 054 ===
# ['Subject54_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject54_ADHD_CombinedTask_Raw.cnt
# Subject ID: 54, Group: ADHD, Task: CombinedTask
# Reading 0 ... 645479  =      0.000 ...  1290.958 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 3.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 4 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 16, 17]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (267, 170, 21), y shape: (267, 5)
# ----------------
#
# Saved Subject 054: X (267, 170, 21), y (267, 5)
# ------------------------------------------------
#
#
# === Subject 055 ===
# ['Subject55_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject55_ADHD_CombinedTask_Raw.cnt
# Subject ID: 55, Group: ADHD, Task: CombinedTask
# Reading 0 ... 645179  =      0.000 ...  1290.358 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 5.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (273, 170, 21), y shape: (273, 5)
# ----------------
#
# Saved Subject 055: X (273, 170, 21), y (273, 5)
# ------------------------------------------------
#
#
# === Subject 056 ===
# ['Subject56_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject56_ADHD_CombinedTask_Raw.cnt
# Subject ID: 56, Group: ADHD, Task: CombinedTask
# Reading 0 ... 683919  =      0.000 ...  1367.838 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 5.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 7 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 6, 7, 10, 11, 13]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (270, 170, 21), y shape: (270, 5)
# ----------------
#
# Saved Subject 056: X (270, 170, 21), y (270, 5)
# ------------------------------------------------
#
#
# === Subject 057 ===
# ['Subject57_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject57_ADHD_CombinedTask_Raw.cnt
# Subject ID: 57, Group: ADHD, Task: CombinedTask
# Reading 0 ... 652539  =      0.000 ...  1305.078 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 19 components
# Fitting ICA took 3.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (19 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (266, 170, 21), y shape: (266, 5)
# ----------------
#
# Saved Subject 057: X (266, 170, 21), y (266, 5)
# ------------------------------------------------
#
#
# === Subject 058 ===
# ['Subject58_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject58_ADHD_CombinedTask_Raw.cnt
# Subject ID: 58, Group: ADHD, Task: CombinedTask
# Reading 0 ... 667319  =      0.000 ...  1334.638 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 5.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 2 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 4]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (259, 170, 21), y shape: (259, 5)
# ----------------
#
# Saved Subject 058: X (259, 170, 21), y (259, 5)
# ------------------------------------------------
#
#
# === Subject 059 ===
# ['Subject59_ADHD_CombinedTask_Raw.cnt']
# Current file: Subject59_ADHD_CombinedTask_Raw.cnt
# Subject ID: 59, Group: ADHD, Task: CombinedTask
# Reading 0 ... 647559  =      0.000 ...  1295.118 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✔ Step 2: Picked common channels (23): ['C3', 'C4', 'Cz', 'F3', 'F4', 'F7', 'F8', 'FC5', 'FC6', 'FP1', 'FP2', 'FT10', 'FT9', 'Fz', 'HEOG', 'O1', 'O2', 'P3', 'P4', 'P7', 'P8', 'Pz', 'VEOG']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 50.0 Hz
# ✔ Step 4: Band-pass 0.5–40.0 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 21 channels (please be patient, this may take a while)
# Selecting by explained variance: 20 components
# Fitting ICA took 4.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 3 ICA components
#     Projecting back using 21 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 16]
# ✔ Step 8: Resampled to 200 Hz
# Used Annotations descriptions: ['20', '21', '22', '31', '32', '71', '72', '73']
# Task 2 trial with X shape: (272, 170, 21), y shape: (272, 5)
# ----------------
#
# Saved Subject 059: X (272, 170, 21), y (272, 5)
# ------------------------------------------------

# %%
# Test the saved npy file
# example
import re

total_samples = 0
for feature_file, label_file in zip(os.listdir(feature_path), os.listdir(label_path)):
    sub_id = int(re.search(r'\d+', feature_file).group())
    feature_file_path = os.path.join(feature_path, feature_file)
    label_file_path = os.path.join(label_path, label_file)
    X = np.load(feature_file_path)
    y = np.load(label_file_path)
    print(f"Subject {sub_id}: X shape: {X.shape}, y shape: {y.shape}")
    if X.shape[0] != y.shape[0]:
        raise(f"Subject {sub_id} data and label length mismatch: " 
                f"{X.shape[0]} vs {y.shape[0]}")
    total_samples += np.load(feature_file_path).shape[0]
    sub_id += 1
print("\nTotal number of trials:", total_samples)
# Out:
# Subject 1: X shape: (536, 170, 21), y shape: (536, 5)
# Subject 2: X shape: (536, 170, 21), y shape: (536, 5)
# Subject 3: X shape: (538, 170, 21), y shape: (538, 5)
# Subject 4: X shape: (532, 170, 21), y shape: (532, 5)
# Subject 5: X shape: (533, 170, 21), y shape: (533, 5)
# Subject 6: X shape: (529, 170, 21), y shape: (529, 5)
# Subject 7: X shape: (537, 170, 21), y shape: (537, 5)
# Subject 8: X shape: (528, 170, 21), y shape: (528, 5)
# Subject 9: X shape: (537, 170, 21), y shape: (537, 5)
# Subject 10: X shape: (539, 170, 21), y shape: (539, 5)
# Subject 11: X shape: (530, 170, 21), y shape: (530, 5)
# Subject 12: X shape: (535, 170, 21), y shape: (535, 5)
# Subject 13: X shape: (537, 170, 21), y shape: (537, 5)
# Subject 14: X shape: (538, 170, 21), y shape: (538, 5)
# Subject 15: X shape: (536, 170, 21), y shape: (536, 5)
# Subject 16: X shape: (540, 170, 21), y shape: (540, 5)
# Subject 17: X shape: (536, 170, 21), y shape: (536, 5)
# Subject 18: X shape: (539, 170, 21), y shape: (539, 5)
# Subject 19: X shape: (537, 170, 21), y shape: (537, 5)
# Subject 20: X shape: (529, 170, 21), y shape: (529, 5)
# Subject 21: X shape: (536, 170, 21), y shape: (536, 5)
# Subject 22: X shape: (536, 170, 21), y shape: (536, 5)
# Subject 23: X shape: (535, 170, 21), y shape: (535, 5)
# Subject 24: X shape: (533, 170, 21), y shape: (533, 5)
# Subject 25: X shape: (532, 170, 21), y shape: (532, 5)
# Subject 26: X shape: (206, 170, 21), y shape: (206, 5)
# Subject 27: X shape: (206, 170, 21), y shape: (206, 5)
# Subject 28: X shape: (206, 170, 21), y shape: (206, 5)
# Subject 29: X shape: (206, 170, 21), y shape: (206, 5)
# Subject 30: X shape: (206, 170, 21), y shape: (206, 5)
# Subject 31: X shape: (206, 170, 21), y shape: (206, 5)
# Subject 32: X shape: (204, 170, 21), y shape: (204, 5)
# Subject 33: X shape: (199, 170, 21), y shape: (199, 5)
# Subject 34: X shape: (202, 170, 21), y shape: (202, 5)
# Subject 35: X shape: (203, 170, 21), y shape: (203, 5)
# Subject 36: X shape: (266, 170, 21), y shape: (266, 5)
# Subject 37: X shape: (265, 170, 21), y shape: (265, 5)
# Subject 38: X shape: (266, 170, 21), y shape: (266, 5)
# Subject 39: X shape: (266, 170, 21), y shape: (266, 5)
# Subject 40: X shape: (268, 170, 21), y shape: (268, 5)
# Subject 41: X shape: (266, 170, 21), y shape: (266, 5)
# Subject 42: X shape: (272, 170, 21), y shape: (272, 5)
# Subject 43: X shape: (265, 170, 21), y shape: (265, 5)
# Subject 44: X shape: (274, 170, 21), y shape: (274, 5)
# Subject 45: X shape: (270, 170, 21), y shape: (270, 5)
# Subject 46: X shape: (267, 170, 21), y shape: (267, 5)
# Subject 47: X shape: (267, 170, 21), y shape: (267, 5)
# Subject 48: X shape: (268, 170, 21), y shape: (268, 5)
# Subject 49: X shape: (265, 170, 21), y shape: (265, 5)
# Subject 50: X shape: (270, 170, 21), y shape: (270, 5)
# Subject 51: X shape: (259, 170, 21), y shape: (259, 5)
# Subject 52: X shape: (266, 170, 21), y shape: (266, 5)
# Subject 53: X shape: (267, 170, 21), y shape: (267, 5)
# Subject 54: X shape: (267, 170, 21), y shape: (267, 5)
# Subject 55: X shape: (273, 170, 21), y shape: (273, 5)
# Subject 56: X shape: (270, 170, 21), y shape: (270, 5)
# Subject 57: X shape: (266, 170, 21), y shape: (266, 5)
# Subject 58: X shape: (259, 170, 21), y shape: (259, 5)
# Subject 59: X shape: (272, 170, 21), y shape: (272, 5)
#
# Total number of trials: 21832
