# %%
import os
import numpy as np
import h5py
import pandas as pd
from scipy.signal import resample
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
import mne
from mne.preprocessing import ICA
try:
    from mne_icalabel import label_components
except Exception:
    label_components = None

# %%
SAMPLE_RATE = 200  # fs
# SAMPLE_LEN = 1.0   # sample seconds
# OVERLAPPING = 0.8  # overlapping seconds
sub_folder_path = str(SAMPLE_RATE) + 'Hz'
sub_folder_path
# Out:
# '200Hz'

# %%
## Load participants.tsv file
# root dirNencki-Symfonia EEG
root = "NSERP/"
participants_path = os.path.join(root, "participants.tsv")
participants = pd.read_csv(participants_path, sep="\t")
participants
# Out:
#    participant_id sex  age  medication use                    medication type  \
# 0          sub-01   F   22               1  ethinylestradiolum/ drospirenonum
# 1          sub-02   F   21               0                                NaN
# 2          sub-03   M   27               0                                NaN
# 3          sub-04   M   26               0                                NaN
# 4          sub-05   M   25               0                                NaN
# 5          sub-06   M   26               0                                NaN
# 6          sub-07   M   25               0                                NaN
# 7          sub-08   M   33               1            levothyroxinum natricum
# 8          sub-09   F   20               0                                NaN
# 9          sub-10   F   20               0                                NaN
# 10         sub-11   M   27               0                                NaN
# 11         sub-12   M   23               0                                NaN
# 12         sub-13   M   21               0                                NaN
# 13         sub-14   F   20               0                                NaN
# 14         sub-15   M   25               0                                NaN
# 15         sub-16   F   32               0                                NaN
# 16         sub-17   M   24               0                                NaN
# 17         sub-18   M   29               0                                NaN
# 18         sub-19   F   25               0                                NaN
# 19         sub-20   F   23               0                                NaN
# 20         sub-21   M   21               0                                NaN
# 21         sub-22   F   34               1            levothyroxinum natricum
# 22         sub-23   M   21               0                                NaN
# 23         sub-24   F   24               0                                NaN
# 24         sub-25   F   21               0                                NaN
# 25         sub-26   F   21               0                                NaN
# 26         sub-27   F   22               0                                NaN
# 27         sub-28   M   24               0                                NaN
# 28         sub-29   M   24               0                                NaN
# 29         sub-30   M   21               1        fexofenadini hydrochloridum
# 30         sub-31   F   32               1                        aciclovirum
# 31         sub-32   M   32               0                                NaN
# 32         sub-33   F   26               0                                NaN
# 33         sub-34   F   22               0                                NaN
# 34         sub-35   F   23               0                                NaN
# 35         sub-36   M   33               0                                NaN
# 36         sub-37   F   23               0                                NaN
# 37         sub-38   F   20               0                                NaN
# 38         sub-39   F   22               0                                NaN
# 39         sub-40   F   20               0                                NaN
# 40         sub-41   F   24               0                                NaN
# 41         sub-42   M   30               0                                NaN
#
#     caffeine uptake  stress  rest  menstrual cycle  \
# 0                 0       2     4             10.0
# 1                 1       5     3             21.0
# 2                 0       3     5              NaN
# 3                 0       3     3              NaN
# 4                 0       4     1              NaN
# 5                 0       4     3              NaN
# 6                 0       1     3              NaN
# 7                 1       2     4              NaN
# 8                 0       4     2             20.0
# 9                 0       4     3             16.0
# 10                1       2     5              NaN
# 11                1       2     3              NaN
# 12                0       4     4              NaN
# 13                0       2     4              7.0
# 14                0       3     4              NaN
# 15                1       4     4             15.0
# 16                1       3     4              NaN
# 17                0       5     3              NaN
# 18                0       2     5             17.0
# 19                0       2     3             21.0
# 20                0       2     4              NaN
# 21                1       2     3             26.0
# 22                1       2     2              NaN
# 23                1       1     3             26.0
# 24                0       3     4             20.0
# 25                1       3     4              5.0
# 26                0       2     2             24.0
# 27                1       2     3              NaN
# 28                0       2     5              NaN
# 29                0       2     4              NaN
# 30                1       4     2             22.0
# 31                1       4     4              NaN
# 32                1       3     4              7.0
# 33                0       4     4             27.0
# 34                0       3     3             21.0
# 35                1       3     4              NaN
# 36                0       4     3             11.0
# 37                1       1     4             11.0
# 38                0       2     3             25.0
# 39                0       2     1              6.0
# 40                1       3     4             25.0
# 41                0       1     5              NaN
#
#     UMACL/UWIST Niezadowolony Dissatisfied  ...  ARSQ_41  ARSQ_42  ARSQ_43  \
# 0                                        4  ...        1        2        4
# 1                                        3  ...        1        1        1
# 2                                        3  ...        1        1        5
# 3                                        3  ...        1        1        1
# 4                                        3  ...        1        1        1
# 5                                        3  ...        1        1        1
# 6                                        2  ...        1        2        1
# 7                                        4  ...        1        1        4
# 8                                        3  ...        2        1        1
# 9                                        4  ...        1        1        1
# 10                                       3  ...        1        1        1
# 11                                       3  ...        1        1        1
# 12                                       4  ...        1        1        5
# 13                                       4  ...        2        2        2
# 14                                       4  ...        1        2        2
# 15                                       3  ...        1        1        1
# 16                                       3  ...        2        2        4
# 17                                       2  ...        2        2        1
# 18                                       3  ...        1        1        1
# 19                                       4  ...        1        1        1
# 20                                       4  ...        1        1        4
# 21                                       3  ...        4        4        4
# 22                                       2  ...        1        1        1
# 23                                       3  ...        1        1        1
# 24                                       4  ...        3        2        2
# 25                                       4  ...        1        2        4
# 26                                       4  ...        4        3        4
# 27                                       3  ...        2        2        5
# 28                                       3  ...        2        2        2
# 29                                       4  ...        1        1        5
# 30                                       3  ...        1        1        1
# 31                                       3  ...        2        1        4
# 32                                       4  ...        1        2        5
# 33                                       4  ...        1        1        1
# 34                                       4  ...        1        5        2
# 35                                       4  ...        2        2        4
# 36                                       3  ...        1        1        1
# 37                                       4  ...        1        1        1
# 38                                       4  ...        1        1        1
# 39                                       3  ...        2        1        3
# 40                                       2  ...        1        2        4
# 41                                       4  ...        2        1        1
#
#     ARSQ_44  ARSQ_45  ARSQ_46  ARSQ_47  ARSQ_48  ARSQ_49  ARSQ_50
# 0         1        2        3        4        4        2        5
# 1         1        1        4        1        3        1        5
# 2         1        1        3        2        2        2        5
# 3         1        1        3        3        3        3        5
# 4         1        4        4        2        2        1        5
# 5         3        2        1        3        1        1        4
# 6         1        1        4        5        5        2        5
# 7         1        1        2        3        2        2        5
# 8         1        1        3        1        1        1        5
# 9         1        1        4        3        1        2        5
# 10        1        1        3        1        1        1        5
# 11        1        1        3        2        2        1        5
# 12        1        1        4        4        4        3        5
# 13        2        2        3        4        3        1        5
# 14        1        1        1        4        4        1        5
# 15        1        1        4        2        2        1        5
# 16        1        2        3        4        4        3        4
# 17        1        4        1        4        4        4        5
# 18        1        1        1        2        2        2        5
# 19        1        1        4        1        1        1        5
# 20        2        1        4        4        3        1        5
# 21        3        2        4        3        2        3        4
# 22        1        1        1        1        1        2        4
# 23        1        1        2        2        3        3        5
# 24        1        4        4        2        1        3        5
# 25        1        1        4        2        2        1        5
# 26        1        1        4        2        2        1        5
# 27        1        4        5        1        1        1        5
# 28        1        1        4        2        2        1        5
# 29        1        1        1        1        1        1        5
# 30        1        1        3        4        4        1        5
# 31        1        2        4        5        4        1        5
# 32        1        2        2        2        2        1        5
# 33        1        1        3        1        1        1        5
# 34        1        1        3        1        1        1        5
# 35        1        1        2        2        2        1        5
# 36        1        1        3        3        1        2        4
# 37        1        1        3        2        1        1        5
# 38        1        2        4        1        2        1        5
# 39        4        2        4        2        2        1        5
# 40        3        2        2        3        2        3        3
# 41        1        1        4        1        1        1        5
#
# [42 rows x 90 columns]

# %%
# Test for bad channels, sampling freq and shape
# The data is BrainVision format (Brain Products) not EEGLAB .set/.fdt format

bad_channel_list, sampling_freq_list, data_shape_list = [], [], []

# Loop through each subject folder
for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub, 'eeg')
        if not os.path.exists(sub_path):
            print(f"❌ Missing folder: {sub_path}")
            continue
        files = os.listdir(sub_path)
        # Look for the .vhdr file (BrainVision header file)
        for file in files:
            if file.endswith('.vhdr'):
                file_path = os.path.join(sub_path, file)
                print(f"✅ Reading: {file_path}")
                raw = mne.io.read_raw_brainvision(file_path, preload=True)

                # Collect bad channels
                bad_channel_list.append(raw.info['bads'])
                # Collect sampling frequency
                sampling_freq_list.append(raw.info['sfreq'])
                # Collect EEG data shape
                data_shape_list.append(raw.get_data().shape)
# Out:
# ✅ Reading: NSERP/sub-01\eeg\sub-01_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-01\eeg\sub-01_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1437859  =      0.000 ...  1437.859 secs...
# ✅ Reading: NSERP/sub-01\eeg\sub-01_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-01\eeg\sub-01_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1371319  =      0.000 ...  1371.319 secs...
# ✅ Reading: NSERP/sub-01\eeg\sub-01_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-01\eeg\sub-01_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 732699  =      0.000 ...   732.699 secs...
# ✅ Reading: NSERP/sub-01\eeg\sub-01_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-01\eeg\sub-01_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 428819  =      0.000 ...   428.819 secs...
# ✅ Reading: NSERP/sub-02\eeg\sub-02_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-02\eeg\sub-02_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1308539  =      0.000 ...  1308.539 secs...
# ✅ Reading: NSERP/sub-02\eeg\sub-02_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-02\eeg\sub-02_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1345819  =      0.000 ...  1345.819 secs...
# ✅ Reading: NSERP/sub-02\eeg\sub-02_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-02\eeg\sub-02_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 740359  =      0.000 ...   740.359 secs...
# ✅ Reading: NSERP/sub-02\eeg\sub-02_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-02\eeg\sub-02_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 461419  =      0.000 ...   461.419 secs...
# ✅ Reading: NSERP/sub-03\eeg\sub-03_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-03\eeg\sub-03_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1340079  =      0.000 ...  1340.079 secs...
# ✅ Reading: NSERP/sub-03\eeg\sub-03_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-03\eeg\sub-03_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1329199  =      0.000 ...  1329.199 secs...
# ✅ Reading: NSERP/sub-03\eeg\sub-03_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-03\eeg\sub-03_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 771179  =      0.000 ...   771.179 secs...
# ✅ Reading: NSERP/sub-03\eeg\sub-03_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-03\eeg\sub-03_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 447439  =      0.000 ...   447.439 secs...
# ✅ Reading: NSERP/sub-04\eeg\sub-04_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-04\eeg\sub-04_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1372979  =      0.000 ...  1372.979 secs...
# ✅ Reading: NSERP/sub-04\eeg\sub-04_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-04\eeg\sub-04_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1326119  =      0.000 ...  1326.119 secs...
# ✅ Reading: NSERP/sub-04\eeg\sub-04_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-04\eeg\sub-04_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 719739  =      0.000 ...   719.739 secs...
# ✅ Reading: NSERP/sub-04\eeg\sub-04_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-04\eeg\sub-04_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 489999  =      0.000 ...   489.999 secs...
# ✅ Reading: NSERP/sub-05\eeg\sub-05_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-05\eeg\sub-05_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1338439  =      0.000 ...  1338.439 secs...
# ✅ Reading: NSERP/sub-05\eeg\sub-05_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-05\eeg\sub-05_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1322839  =      0.000 ...  1322.839 secs...
# ✅ Reading: NSERP/sub-05\eeg\sub-05_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-05\eeg\sub-05_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 725619  =      0.000 ...   725.619 secs...
# ✅ Reading: NSERP/sub-05\eeg\sub-05_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-05\eeg\sub-05_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 424939  =      0.000 ...   424.939 secs...
# ✅ Reading: NSERP/sub-06\eeg\sub-06_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-06\eeg\sub-06_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1313399  =      0.000 ...  1313.399 secs...
# ✅ Reading: NSERP/sub-06\eeg\sub-06_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-06\eeg\sub-06_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1329879  =      0.000 ...  1329.879 secs...
# ✅ Reading: NSERP/sub-06\eeg\sub-06_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-06\eeg\sub-06_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 714499  =      0.000 ...   714.499 secs...
# ✅ Reading: NSERP/sub-06\eeg\sub-06_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-06\eeg\sub-06_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 421239  =      0.000 ...   421.239 secs...
# ✅ Reading: NSERP/sub-07\eeg\sub-07_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-07\eeg\sub-07_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1340119  =      0.000 ...  1340.119 secs...
# ✅ Reading: NSERP/sub-07\eeg\sub-07_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-07\eeg\sub-07_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1342279  =      0.000 ...  1342.279 secs...
# ✅ Reading: NSERP/sub-07\eeg\sub-07_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-07\eeg\sub-07_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 702479  =      0.000 ...   702.479 secs...
# ✅ Reading: NSERP/sub-07\eeg\sub-07_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-07\eeg\sub-07_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 437779  =      0.000 ...   437.779 secs...
# ✅ Reading: NSERP/sub-08\eeg\sub-08_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-08\eeg\sub-08_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1352259  =      0.000 ...  1352.259 secs...
# ✅ Reading: NSERP/sub-08\eeg\sub-08_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-08\eeg\sub-08_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1694859  =      0.000 ...  1694.859 secs...
# ✅ Reading: NSERP/sub-08\eeg\sub-08_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-08\eeg\sub-08_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 750399  =      0.000 ...   750.399 secs...
# ✅ Reading: NSERP/sub-08\eeg\sub-08_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-08\eeg\sub-08_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 453499  =      0.000 ...   453.499 secs...
# ✅ Reading: NSERP/sub-09\eeg\sub-09_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-09\eeg\sub-09_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1589859  =      0.000 ...  1589.859 secs...
# ✅ Reading: NSERP/sub-09\eeg\sub-09_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-09\eeg\sub-09_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1326139  =      0.000 ...  1326.139 secs...
# ✅ Reading: NSERP/sub-09\eeg\sub-09_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-09\eeg\sub-09_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 728979  =      0.000 ...   728.979 secs...
# ✅ Reading: NSERP/sub-09\eeg\sub-09_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-09\eeg\sub-09_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 465459  =      0.000 ...   465.459 secs...
# ✅ Reading: NSERP/sub-10\eeg\sub-10_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-10\eeg\sub-10_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1370499  =      0.000 ...  1370.499 secs...
# ✅ Reading: NSERP/sub-10\eeg\sub-10_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-10\eeg\sub-10_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1346079  =      0.000 ...  1346.079 secs...
# ✅ Reading: NSERP/sub-10\eeg\sub-10_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-10\eeg\sub-10_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 743239  =      0.000 ...   743.239 secs...
# ✅ Reading: NSERP/sub-10\eeg\sub-10_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-10\eeg\sub-10_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 407839  =      0.000 ...   407.839 secs...
# ✅ Reading: NSERP/sub-11\eeg\sub-11_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-11\eeg\sub-11_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1331199  =      0.000 ...  1331.199 secs...
# ✅ Reading: NSERP/sub-11\eeg\sub-11_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-11\eeg\sub-11_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1335239  =      0.000 ...  1335.239 secs...
# ✅ Reading: NSERP/sub-11\eeg\sub-11_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-11\eeg\sub-11_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 706459  =      0.000 ...   706.459 secs...
# ✅ Reading: NSERP/sub-11\eeg\sub-11_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-11\eeg\sub-11_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 432539  =      0.000 ...   432.539 secs...
# ✅ Reading: NSERP/sub-12\eeg\sub-12_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-12\eeg\sub-12_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1362199  =      0.000 ...  1362.199 secs...
# ✅ Reading: NSERP/sub-12\eeg\sub-12_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-12\eeg\sub-12_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1319299  =      0.000 ...  1319.299 secs...
# ✅ Reading: NSERP/sub-12\eeg\sub-12_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-12\eeg\sub-12_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 701899  =      0.000 ...   701.899 secs...
# ✅ Reading: NSERP/sub-12\eeg\sub-12_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-12\eeg\sub-12_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 399499  =      0.000 ...   399.499 secs...
# ✅ Reading: NSERP/sub-13\eeg\sub-13_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-13\eeg\sub-13_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1331899  =      0.000 ...  1331.899 secs...
# ✅ Reading: NSERP/sub-13\eeg\sub-13_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-13\eeg\sub-13_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1364559  =      0.000 ...  1364.559 secs...
# ✅ Reading: NSERP/sub-13\eeg\sub-13_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-13\eeg\sub-13_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 711839  =      0.000 ...   711.839 secs...
# ✅ Reading: NSERP/sub-13\eeg\sub-13_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-13\eeg\sub-13_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 455519  =      0.000 ...   455.519 secs...
# ✅ Reading: NSERP/sub-14\eeg\sub-14_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-14\eeg\sub-14_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1359119  =      0.000 ...  1359.119 secs...
# ✅ Reading: NSERP/sub-14\eeg\sub-14_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-14\eeg\sub-14_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1337259  =      0.000 ...  1337.259 secs...
# ✅ Reading: NSERP/sub-14\eeg\sub-14_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-14\eeg\sub-14_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 772059  =      0.000 ...   772.059 secs...
# ✅ Reading: NSERP/sub-14\eeg\sub-14_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-14\eeg\sub-14_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 406139  =      0.000 ...   406.139 secs...
# ✅ Reading: NSERP/sub-15\eeg\sub-15_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-15\eeg\sub-15_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1364599  =      0.000 ...  1364.599 secs...
# ✅ Reading: NSERP/sub-15\eeg\sub-15_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-15\eeg\sub-15_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1400659  =      0.000 ...  1400.659 secs...
# ✅ Reading: NSERP/sub-15\eeg\sub-15_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-15\eeg\sub-15_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 766819  =      0.000 ...   766.819 secs...
# ✅ Reading: NSERP/sub-15\eeg\sub-15_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-15\eeg\sub-15_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 568099  =      0.000 ...   568.099 secs...
# ✅ Reading: NSERP/sub-16\eeg\sub-16_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-16\eeg\sub-16_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1309899  =      0.000 ...  1309.899 secs...
# ✅ Reading: NSERP/sub-16\eeg\sub-16_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-16\eeg\sub-16_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1331419  =      0.000 ...  1331.419 secs...
# ✅ Reading: NSERP/sub-16\eeg\sub-16_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-16\eeg\sub-16_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 732779  =      0.000 ...   732.779 secs...
# ✅ Reading: NSERP/sub-16\eeg\sub-16_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-16\eeg\sub-16_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 439099  =      0.000 ...   439.099 secs...
# ✅ Reading: NSERP/sub-17\eeg\sub-17_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-17\eeg\sub-17_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1298859  =      0.000 ...  1298.859 secs...
# ✅ Reading: NSERP/sub-17\eeg\sub-17_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-17\eeg\sub-17_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1333399  =      0.000 ...  1333.399 secs...
# ✅ Reading: NSERP/sub-17\eeg\sub-17_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-17\eeg\sub-17_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 713719  =      0.000 ...   713.719 secs...
# ✅ Reading: NSERP/sub-17\eeg\sub-17_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-17\eeg\sub-17_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 410619  =      0.000 ...   410.619 secs...
# ✅ Reading: NSERP/sub-18\eeg\sub-18_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-18\eeg\sub-18_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1338059  =      0.000 ...  1338.059 secs...
# ✅ Reading: NSERP/sub-18\eeg\sub-18_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-18\eeg\sub-18_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1345719  =      0.000 ...  1345.719 secs...
# ✅ Reading: NSERP/sub-18\eeg\sub-18_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-18\eeg\sub-18_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 750919  =      0.000 ...   750.919 secs...
# ✅ Reading: NSERP/sub-18\eeg\sub-18_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-18\eeg\sub-18_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 413759  =      0.000 ...   413.759 secs...
# ✅ Reading: NSERP/sub-19\eeg\sub-19_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-19\eeg\sub-19_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1345039  =      0.000 ...  1345.039 secs...
# ✅ Reading: NSERP/sub-19\eeg\sub-19_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-19\eeg\sub-19_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1317219  =      0.000 ...  1317.219 secs...
# ✅ Reading: NSERP/sub-19\eeg\sub-19_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-19\eeg\sub-19_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 699939  =      0.000 ...   699.939 secs...
# ✅ Reading: NSERP/sub-19\eeg\sub-19_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-19\eeg\sub-19_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 408759  =      0.000 ...   408.759 secs...
# ✅ Reading: NSERP/sub-20\eeg\sub-20_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-20\eeg\sub-20_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1321779  =      0.000 ...  1321.779 secs...
# ✅ Reading: NSERP/sub-20\eeg\sub-20_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-20\eeg\sub-20_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1340559  =      0.000 ...  1340.559 secs...
# ✅ Reading: NSERP/sub-20\eeg\sub-20_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-20\eeg\sub-20_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 764099  =      0.000 ...   764.099 secs...
# ✅ Reading: NSERP/sub-20\eeg\sub-20_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-20\eeg\sub-20_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 433499  =      0.000 ...   433.499 secs...
# ✅ Reading: NSERP/sub-21\eeg\sub-21_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-21\eeg\sub-21_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1031659  =      0.000 ...  1031.659 secs...
# ✅ Reading: NSERP/sub-21\eeg\sub-21_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-21\eeg\sub-21_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1344679  =      0.000 ...  1344.679 secs...
# ✅ Reading: NSERP/sub-21\eeg\sub-21_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-21\eeg\sub-21_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 763319  =      0.000 ...   763.319 secs...
# ✅ Reading: NSERP/sub-21\eeg\sub-21_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-21\eeg\sub-21_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 398699  =      0.000 ...   398.699 secs...
# ✅ Reading: NSERP/sub-22\eeg\sub-22_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-22\eeg\sub-22_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1369959  =      0.000 ...  1369.959 secs...
# ✅ Reading: NSERP/sub-22\eeg\sub-22_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-22\eeg\sub-22_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1403619  =      0.000 ...  1403.619 secs...
# ✅ Reading: NSERP/sub-22\eeg\sub-22_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-22\eeg\sub-22_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 737299  =      0.000 ...   737.299 secs...
# ✅ Reading: NSERP/sub-22\eeg\sub-22_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-22\eeg\sub-22_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 453079  =      0.000 ...   453.079 secs...
# ✅ Reading: NSERP/sub-23\eeg\sub-23_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-23\eeg\sub-23_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1551179  =      0.000 ...  1551.179 secs...
# ✅ Reading: NSERP/sub-23\eeg\sub-23_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-23\eeg\sub-23_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1419839  =      0.000 ...  1419.839 secs...
# ✅ Reading: NSERP/sub-23\eeg\sub-23_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-23\eeg\sub-23_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 733139  =      0.000 ...   733.139 secs...
# ✅ Reading: NSERP/sub-23\eeg\sub-23_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-23\eeg\sub-23_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 435459  =      0.000 ...   435.459 secs...
# ✅ Reading: NSERP/sub-24\eeg\sub-24_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-24\eeg\sub-24_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1371459  =      0.000 ...  1371.459 secs...
# ✅ Reading: NSERP/sub-24\eeg\sub-24_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-24\eeg\sub-24_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1349599  =      0.000 ...  1349.599 secs...
# ✅ Reading: NSERP/sub-24\eeg\sub-24_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-24\eeg\sub-24_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 743619  =      0.000 ...   743.619 secs...
# ✅ Reading: NSERP/sub-24\eeg\sub-24_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-24\eeg\sub-24_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 451479  =      0.000 ...   451.479 secs...
# ✅ Reading: NSERP/sub-25\eeg\sub-25_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-25\eeg\sub-25_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1321739  =      0.000 ...  1321.739 secs...
# ✅ Reading: NSERP/sub-25\eeg\sub-25_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-25\eeg\sub-25_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1515259  =      0.000 ...  1515.259 secs...
# ✅ Reading: NSERP/sub-25\eeg\sub-25_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-25\eeg\sub-25_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 660685  =      0.000 ...   660.685 secs...
# ✅ Reading: NSERP/sub-25\eeg\sub-25_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-25\eeg\sub-25_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 447879  =      0.000 ...   447.879 secs...
# ✅ Reading: NSERP/sub-26\eeg\sub-26_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-26\eeg\sub-26_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1336799  =      0.000 ...  1336.799 secs...
# ✅ Reading: NSERP/sub-26\eeg\sub-26_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-26\eeg\sub-26_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1331759  =      0.000 ...  1331.759 secs...
# ✅ Reading: NSERP/sub-26\eeg\sub-26_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-26\eeg\sub-26_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 718879  =      0.000 ...   718.879 secs...
# ✅ Reading: NSERP/sub-26\eeg\sub-26_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-26\eeg\sub-26_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 418539  =      0.000 ...   418.539 secs...
# ✅ Reading: NSERP/sub-27\eeg\sub-27_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-27\eeg\sub-27_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1343859  =      0.000 ...  1343.859 secs...
# ✅ Reading: NSERP/sub-27\eeg\sub-27_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-27\eeg\sub-27_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1367919  =      0.000 ...  1367.919 secs...
# ✅ Reading: NSERP/sub-27\eeg\sub-27_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-27\eeg\sub-27_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 767019  =      0.000 ...   767.019 secs...
# ✅ Reading: NSERP/sub-27\eeg\sub-27_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-27\eeg\sub-27_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 450619  =      0.000 ...   450.619 secs...
# ✅ Reading: NSERP/sub-28\eeg\sub-28_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-28\eeg\sub-28_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1477139  =      0.000 ...  1477.139 secs...
# ✅ Reading: NSERP/sub-28\eeg\sub-28_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-28\eeg\sub-28_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1342579  =      0.000 ...  1342.579 secs...
# ✅ Reading: NSERP/sub-28\eeg\sub-28_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-28\eeg\sub-28_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 701939  =      0.000 ...   701.939 secs...
# ✅ Reading: NSERP/sub-28\eeg\sub-28_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-28\eeg\sub-28_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 428879  =      0.000 ...   428.879 secs...
# ✅ Reading: NSERP/sub-29\eeg\sub-29_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-29\eeg\sub-29_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1478659  =      0.000 ...  1478.659 secs...
# ✅ Reading: NSERP/sub-29\eeg\sub-29_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-29\eeg\sub-29_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1332519  =      0.000 ...  1332.519 secs...
# ✅ Reading: NSERP/sub-29\eeg\sub-29_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-29\eeg\sub-29_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 950159  =      0.000 ...   950.159 secs...
# ✅ Reading: NSERP/sub-30\eeg\sub-30_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-30\eeg\sub-30_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1336079  =      0.000 ...  1336.079 secs...
# ✅ Reading: NSERP/sub-30\eeg\sub-30_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-30\eeg\sub-30_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1350299  =      0.000 ...  1350.299 secs...
# ✅ Reading: NSERP/sub-30\eeg\sub-30_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-30\eeg\sub-30_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 716959  =      0.000 ...   716.959 secs...
# ✅ Reading: NSERP/sub-30\eeg\sub-30_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-30\eeg\sub-30_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 508319  =      0.000 ...   508.319 secs...
# ✅ Reading: NSERP/sub-31\eeg\sub-31_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-31\eeg\sub-31_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1316119  =      0.000 ...  1316.119 secs...
# ✅ Reading: NSERP/sub-31\eeg\sub-31_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-31\eeg\sub-31_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1328859  =      0.000 ...  1328.859 secs...
# ✅ Reading: NSERP/sub-31\eeg\sub-31_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-31\eeg\sub-31_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 721199  =      0.000 ...   721.199 secs...
# ✅ Reading: NSERP/sub-31\eeg\sub-31_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-31\eeg\sub-31_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 637459  =      0.000 ...   637.459 secs...
# ✅ Reading: NSERP/sub-32\eeg\sub-32_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-32\eeg\sub-32_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1345659  =      0.000 ...  1345.659 secs...
# ✅ Reading: NSERP/sub-32\eeg\sub-32_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-32\eeg\sub-32_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1362419  =      0.000 ...  1362.419 secs...
# ✅ Reading: NSERP/sub-32\eeg\sub-32_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-32\eeg\sub-32_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 732419  =      0.000 ...   732.419 secs...
# ✅ Reading: NSERP/sub-32\eeg\sub-32_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-32\eeg\sub-32_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 455859  =      0.000 ...   455.859 secs...
# ✅ Reading: NSERP/sub-33\eeg\sub-33_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-33\eeg\sub-33_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1382219  =      0.000 ...  1382.219 secs...
# ✅ Reading: NSERP/sub-33\eeg\sub-33_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-33\eeg\sub-33_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1320579  =      0.000 ...  1320.579 secs...
# ✅ Reading: NSERP/sub-33\eeg\sub-33_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-33\eeg\sub-33_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 719159  =      0.000 ...   719.159 secs...
# ✅ Reading: NSERP/sub-33\eeg\sub-33_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-33\eeg\sub-33_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 445439  =      0.000 ...   445.439 secs...
# ✅ Reading: NSERP/sub-34\eeg\sub-34_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-34\eeg\sub-34_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1335379  =      0.000 ...  1335.379 secs...
# ✅ Reading: NSERP/sub-34\eeg\sub-34_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-34\eeg\sub-34_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1347299  =      0.000 ...  1347.299 secs...
# ✅ Reading: NSERP/sub-34\eeg\sub-34_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-34\eeg\sub-34_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 726339  =      0.000 ...   726.339 secs...
# ✅ Reading: NSERP/sub-34\eeg\sub-34_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-34\eeg\sub-34_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 452279  =      0.000 ...   452.279 secs...
# ✅ Reading: NSERP/sub-35\eeg\sub-35_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-35\eeg\sub-35_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1315699  =      0.000 ...  1315.699 secs...
# ✅ Reading: NSERP/sub-35\eeg\sub-35_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-35\eeg\sub-35_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1388699  =      0.000 ...  1388.699 secs...
# ✅ Reading: NSERP/sub-35\eeg\sub-35_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-35\eeg\sub-35_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 721419  =      0.000 ...   721.419 secs...
# ✅ Reading: NSERP/sub-35\eeg\sub-35_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-35\eeg\sub-35_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 409979  =      0.000 ...   409.979 secs...
# ✅ Reading: NSERP/sub-36\eeg\sub-36_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-36\eeg\sub-36_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1403479  =      0.000 ...  1403.479 secs...
# ✅ Reading: NSERP/sub-36\eeg\sub-36_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-36\eeg\sub-36_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1426039  =      0.000 ...  1426.039 secs...
# ✅ Reading: NSERP/sub-36\eeg\sub-36_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-36\eeg\sub-36_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 758199  =      0.000 ...   758.199 secs...
# ✅ Reading: NSERP/sub-36\eeg\sub-36_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-36\eeg\sub-36_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 434239  =      0.000 ...   434.239 secs...
# ✅ Reading: NSERP/sub-37\eeg\sub-37_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-37\eeg\sub-37_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1355919  =      0.000 ...  1355.919 secs...
# ✅ Reading: NSERP/sub-37\eeg\sub-37_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-37\eeg\sub-37_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1397439  =      0.000 ...  1397.439 secs...
# ✅ Reading: NSERP/sub-37\eeg\sub-37_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-37\eeg\sub-37_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 693399  =      0.000 ...   693.399 secs...
# ✅ Reading: NSERP/sub-37\eeg\sub-37_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-37\eeg\sub-37_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 411899  =      0.000 ...   411.899 secs...
# ✅ Reading: NSERP/sub-38\eeg\sub-38_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-38\eeg\sub-38_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1349539  =      0.000 ...  1349.539 secs...
# ✅ Reading: NSERP/sub-38\eeg\sub-38_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-38\eeg\sub-38_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1512739  =      0.000 ...  1512.739 secs...
# ✅ Reading: NSERP/sub-38\eeg\sub-38_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-38\eeg\sub-38_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 720759  =      0.000 ...   720.759 secs...
# ✅ Reading: NSERP/sub-38\eeg\sub-38_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-38\eeg\sub-38_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 441939  =      0.000 ...   441.939 secs...
# ✅ Reading: NSERP/sub-39\eeg\sub-39_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-39\eeg\sub-39_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1325939  =      0.000 ...  1325.939 secs...
# ✅ Reading: NSERP/sub-39\eeg\sub-39_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-39\eeg\sub-39_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1334239  =      0.000 ...  1334.239 secs...
# ✅ Reading: NSERP/sub-39\eeg\sub-39_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-39\eeg\sub-39_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 707959  =      0.000 ...   707.959 secs...
# ✅ Reading: NSERP/sub-39\eeg\sub-39_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-39\eeg\sub-39_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 454919  =      0.000 ...   454.919 secs...
# ✅ Reading: NSERP/sub-40\eeg\sub-40_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-40\eeg\sub-40_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1430359  =      0.000 ...  1430.359 secs...
# ✅ Reading: NSERP/sub-40\eeg\sub-40_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-40\eeg\sub-40_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1453479  =      0.000 ...  1453.479 secs...
# ✅ Reading: NSERP/sub-40\eeg\sub-40_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-40\eeg\sub-40_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 710359  =      0.000 ...   710.359 secs...
# ✅ Reading: NSERP/sub-40\eeg\sub-40_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-40\eeg\sub-40_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 451619  =      0.000 ...   451.619 secs...
# ✅ Reading: NSERP/sub-41\eeg\sub-41_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-41\eeg\sub-41_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1373839  =      0.000 ...  1373.839 secs...
# ✅ Reading: NSERP/sub-41\eeg\sub-41_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-41\eeg\sub-41_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1352959  =      0.000 ...  1352.959 secs...
# ✅ Reading: NSERP/sub-41\eeg\sub-41_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-41\eeg\sub-41_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 775399  =      0.000 ...   775.399 secs...
# ✅ Reading: NSERP/sub-41\eeg\sub-41_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-41\eeg\sub-41_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 447859  =      0.000 ...   447.859 secs...
# ✅ Reading: NSERP/sub-42\eeg\sub-42_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-42\eeg\sub-42_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1312559  =      0.000 ...  1312.559 secs...
# ✅ Reading: NSERP/sub-42\eeg\sub-42_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-42\eeg\sub-42_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1321579  =      0.000 ...  1321.579 secs...
# ✅ Reading: NSERP/sub-42\eeg\sub-42_task-rest_eeg.vhdr
# Extracting parameters from NSERP/sub-42\eeg\sub-42_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 727499  =      0.000 ...   727.499 secs...
# ✅ Reading: NSERP/sub-42\eeg\sub-42_task-srt_eeg.vhdr
# Extracting parameters from NSERP/sub-42\eeg\sub-42_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 389899  =      0.000 ...   389.899 secs...

# %%
from collections import Counter

print(bad_channel_list)
print(data_shape_list[0])
print("Channel number counter:", Counter(i[0] for i in data_shape_list))
print("Sampling rate counter:", Counter(sampling_freq_list))
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# (127, 1437860)
# Channel number counter: Counter({127: 167})
# Sampling rate counter: Counter({1000.0: 167})

# %%
# Initialize common channel list
common_channels = []

# Loop through subject folders
for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub, 'eeg/')
        for file in os.listdir(sub_path):
            # Change: look for BrainVision .vhdr files
            if file.endswith('.vhdr'):
                file_path = os.path.join(sub_path, file)
                raw = mne.io.read_raw_brainvision(file_path, preload=True)
                current_channels = set(raw.info['ch_names'])

                if not common_channels:
                    common_channels = current_channels
                else:
                    common_channels &= current_channels  # Intersection

# Convert set to list
common_channels = list(common_channels)
# Print result
print(common_channels)
print("Common channels number: ", len(common_channels))
# Out:
# Extracting parameters from NSERP/sub-01\eeg/sub-01_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1437859  =      0.000 ...  1437.859 secs...
# Extracting parameters from NSERP/sub-01\eeg/sub-01_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1371319  =      0.000 ...  1371.319 secs...
# Extracting parameters from NSERP/sub-01\eeg/sub-01_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 732699  =      0.000 ...   732.699 secs...
# Extracting parameters from NSERP/sub-01\eeg/sub-01_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 428819  =      0.000 ...   428.819 secs...
# Extracting parameters from NSERP/sub-02\eeg/sub-02_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1308539  =      0.000 ...  1308.539 secs...
# Extracting parameters from NSERP/sub-02\eeg/sub-02_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1345819  =      0.000 ...  1345.819 secs...
# Extracting parameters from NSERP/sub-02\eeg/sub-02_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 740359  =      0.000 ...   740.359 secs...
# Extracting parameters from NSERP/sub-02\eeg/sub-02_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 461419  =      0.000 ...   461.419 secs...
# Extracting parameters from NSERP/sub-03\eeg/sub-03_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1340079  =      0.000 ...  1340.079 secs...
# Extracting parameters from NSERP/sub-03\eeg/sub-03_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1329199  =      0.000 ...  1329.199 secs...
# Extracting parameters from NSERP/sub-03\eeg/sub-03_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 771179  =      0.000 ...   771.179 secs...
# Extracting parameters from NSERP/sub-03\eeg/sub-03_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 447439  =      0.000 ...   447.439 secs...
# Extracting parameters from NSERP/sub-04\eeg/sub-04_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1372979  =      0.000 ...  1372.979 secs...
# Extracting parameters from NSERP/sub-04\eeg/sub-04_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1326119  =      0.000 ...  1326.119 secs...
# Extracting parameters from NSERP/sub-04\eeg/sub-04_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 719739  =      0.000 ...   719.739 secs...
# Extracting parameters from NSERP/sub-04\eeg/sub-04_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 489999  =      0.000 ...   489.999 secs...
# Extracting parameters from NSERP/sub-05\eeg/sub-05_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1338439  =      0.000 ...  1338.439 secs...
# Extracting parameters from NSERP/sub-05\eeg/sub-05_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1322839  =      0.000 ...  1322.839 secs...
# Extracting parameters from NSERP/sub-05\eeg/sub-05_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 725619  =      0.000 ...   725.619 secs...
# Extracting parameters from NSERP/sub-05\eeg/sub-05_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 424939  =      0.000 ...   424.939 secs...
# Extracting parameters from NSERP/sub-06\eeg/sub-06_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1313399  =      0.000 ...  1313.399 secs...
# Extracting parameters from NSERP/sub-06\eeg/sub-06_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1329879  =      0.000 ...  1329.879 secs...
# Extracting parameters from NSERP/sub-06\eeg/sub-06_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 714499  =      0.000 ...   714.499 secs...
# Extracting parameters from NSERP/sub-06\eeg/sub-06_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 421239  =      0.000 ...   421.239 secs...
# Extracting parameters from NSERP/sub-07\eeg/sub-07_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1340119  =      0.000 ...  1340.119 secs...
# Extracting parameters from NSERP/sub-07\eeg/sub-07_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1342279  =      0.000 ...  1342.279 secs...
# Extracting parameters from NSERP/sub-07\eeg/sub-07_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 702479  =      0.000 ...   702.479 secs...
# Extracting parameters from NSERP/sub-07\eeg/sub-07_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 437779  =      0.000 ...   437.779 secs...
# Extracting parameters from NSERP/sub-08\eeg/sub-08_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1352259  =      0.000 ...  1352.259 secs...
# Extracting parameters from NSERP/sub-08\eeg/sub-08_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1694859  =      0.000 ...  1694.859 secs...
# Extracting parameters from NSERP/sub-08\eeg/sub-08_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 750399  =      0.000 ...   750.399 secs...
# Extracting parameters from NSERP/sub-08\eeg/sub-08_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 453499  =      0.000 ...   453.499 secs...
# Extracting parameters from NSERP/sub-09\eeg/sub-09_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1589859  =      0.000 ...  1589.859 secs...
# Extracting parameters from NSERP/sub-09\eeg/sub-09_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1326139  =      0.000 ...  1326.139 secs...
# Extracting parameters from NSERP/sub-09\eeg/sub-09_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 728979  =      0.000 ...   728.979 secs...
# Extracting parameters from NSERP/sub-09\eeg/sub-09_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 465459  =      0.000 ...   465.459 secs...
# Extracting parameters from NSERP/sub-10\eeg/sub-10_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1370499  =      0.000 ...  1370.499 secs...
# Extracting parameters from NSERP/sub-10\eeg/sub-10_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1346079  =      0.000 ...  1346.079 secs...
# Extracting parameters from NSERP/sub-10\eeg/sub-10_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 743239  =      0.000 ...   743.239 secs...
# Extracting parameters from NSERP/sub-10\eeg/sub-10_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 407839  =      0.000 ...   407.839 secs...
# Extracting parameters from NSERP/sub-11\eeg/sub-11_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1331199  =      0.000 ...  1331.199 secs...
# Extracting parameters from NSERP/sub-11\eeg/sub-11_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1335239  =      0.000 ...  1335.239 secs...
# Extracting parameters from NSERP/sub-11\eeg/sub-11_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 706459  =      0.000 ...   706.459 secs...
# Extracting parameters from NSERP/sub-11\eeg/sub-11_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 432539  =      0.000 ...   432.539 secs...
# Extracting parameters from NSERP/sub-12\eeg/sub-12_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1362199  =      0.000 ...  1362.199 secs...
# Extracting parameters from NSERP/sub-12\eeg/sub-12_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1319299  =      0.000 ...  1319.299 secs...
# Extracting parameters from NSERP/sub-12\eeg/sub-12_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 701899  =      0.000 ...   701.899 secs...
# Extracting parameters from NSERP/sub-12\eeg/sub-12_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 399499  =      0.000 ...   399.499 secs...
# Extracting parameters from NSERP/sub-13\eeg/sub-13_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1331899  =      0.000 ...  1331.899 secs...
# Extracting parameters from NSERP/sub-13\eeg/sub-13_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1364559  =      0.000 ...  1364.559 secs...
# Extracting parameters from NSERP/sub-13\eeg/sub-13_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 711839  =      0.000 ...   711.839 secs...
# Extracting parameters from NSERP/sub-13\eeg/sub-13_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 455519  =      0.000 ...   455.519 secs...
# Extracting parameters from NSERP/sub-14\eeg/sub-14_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1359119  =      0.000 ...  1359.119 secs...
# Extracting parameters from NSERP/sub-14\eeg/sub-14_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1337259  =      0.000 ...  1337.259 secs...
# Extracting parameters from NSERP/sub-14\eeg/sub-14_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 772059  =      0.000 ...   772.059 secs...
# Extracting parameters from NSERP/sub-14\eeg/sub-14_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 406139  =      0.000 ...   406.139 secs...
# Extracting parameters from NSERP/sub-15\eeg/sub-15_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1364599  =      0.000 ...  1364.599 secs...
# Extracting parameters from NSERP/sub-15\eeg/sub-15_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1400659  =      0.000 ...  1400.659 secs...
# Extracting parameters from NSERP/sub-15\eeg/sub-15_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 766819  =      0.000 ...   766.819 secs...
# Extracting parameters from NSERP/sub-15\eeg/sub-15_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 568099  =      0.000 ...   568.099 secs...
# Extracting parameters from NSERP/sub-16\eeg/sub-16_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1309899  =      0.000 ...  1309.899 secs...
# Extracting parameters from NSERP/sub-16\eeg/sub-16_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1331419  =      0.000 ...  1331.419 secs...
# Extracting parameters from NSERP/sub-16\eeg/sub-16_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 732779  =      0.000 ...   732.779 secs...
# Extracting parameters from NSERP/sub-16\eeg/sub-16_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 439099  =      0.000 ...   439.099 secs...
# Extracting parameters from NSERP/sub-17\eeg/sub-17_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1298859  =      0.000 ...  1298.859 secs...
# Extracting parameters from NSERP/sub-17\eeg/sub-17_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1333399  =      0.000 ...  1333.399 secs...
# Extracting parameters from NSERP/sub-17\eeg/sub-17_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 713719  =      0.000 ...   713.719 secs...
# Extracting parameters from NSERP/sub-17\eeg/sub-17_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 410619  =      0.000 ...   410.619 secs...
# Extracting parameters from NSERP/sub-18\eeg/sub-18_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1338059  =      0.000 ...  1338.059 secs...
# Extracting parameters from NSERP/sub-18\eeg/sub-18_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1345719  =      0.000 ...  1345.719 secs...
# Extracting parameters from NSERP/sub-18\eeg/sub-18_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 750919  =      0.000 ...   750.919 secs...
# Extracting parameters from NSERP/sub-18\eeg/sub-18_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 413759  =      0.000 ...   413.759 secs...
# Extracting parameters from NSERP/sub-19\eeg/sub-19_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1345039  =      0.000 ...  1345.039 secs...
# Extracting parameters from NSERP/sub-19\eeg/sub-19_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1317219  =      0.000 ...  1317.219 secs...
# Extracting parameters from NSERP/sub-19\eeg/sub-19_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 699939  =      0.000 ...   699.939 secs...
# Extracting parameters from NSERP/sub-19\eeg/sub-19_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 408759  =      0.000 ...   408.759 secs...
# Extracting parameters from NSERP/sub-20\eeg/sub-20_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1321779  =      0.000 ...  1321.779 secs...
# Extracting parameters from NSERP/sub-20\eeg/sub-20_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1340559  =      0.000 ...  1340.559 secs...
# Extracting parameters from NSERP/sub-20\eeg/sub-20_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 764099  =      0.000 ...   764.099 secs...
# Extracting parameters from NSERP/sub-20\eeg/sub-20_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 433499  =      0.000 ...   433.499 secs...
# Extracting parameters from NSERP/sub-21\eeg/sub-21_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1031659  =      0.000 ...  1031.659 secs...
# Extracting parameters from NSERP/sub-21\eeg/sub-21_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1344679  =      0.000 ...  1344.679 secs...
# Extracting parameters from NSERP/sub-21\eeg/sub-21_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 763319  =      0.000 ...   763.319 secs...
# Extracting parameters from NSERP/sub-21\eeg/sub-21_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 398699  =      0.000 ...   398.699 secs...
# Extracting parameters from NSERP/sub-22\eeg/sub-22_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1369959  =      0.000 ...  1369.959 secs...
# Extracting parameters from NSERP/sub-22\eeg/sub-22_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1403619  =      0.000 ...  1403.619 secs...
# Extracting parameters from NSERP/sub-22\eeg/sub-22_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 737299  =      0.000 ...   737.299 secs...
# Extracting parameters from NSERP/sub-22\eeg/sub-22_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 453079  =      0.000 ...   453.079 secs...
# Extracting parameters from NSERP/sub-23\eeg/sub-23_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1551179  =      0.000 ...  1551.179 secs...
# Extracting parameters from NSERP/sub-23\eeg/sub-23_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1419839  =      0.000 ...  1419.839 secs...
# Extracting parameters from NSERP/sub-23\eeg/sub-23_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 733139  =      0.000 ...   733.139 secs...
# Extracting parameters from NSERP/sub-23\eeg/sub-23_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 435459  =      0.000 ...   435.459 secs...
# Extracting parameters from NSERP/sub-24\eeg/sub-24_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1371459  =      0.000 ...  1371.459 secs...
# Extracting parameters from NSERP/sub-24\eeg/sub-24_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1349599  =      0.000 ...  1349.599 secs...
# Extracting parameters from NSERP/sub-24\eeg/sub-24_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 743619  =      0.000 ...   743.619 secs...
# Extracting parameters from NSERP/sub-24\eeg/sub-24_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 451479  =      0.000 ...   451.479 secs...
# Extracting parameters from NSERP/sub-25\eeg/sub-25_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1321739  =      0.000 ...  1321.739 secs...
# Extracting parameters from NSERP/sub-25\eeg/sub-25_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1515259  =      0.000 ...  1515.259 secs...
# Extracting parameters from NSERP/sub-25\eeg/sub-25_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 660685  =      0.000 ...   660.685 secs...
# Extracting parameters from NSERP/sub-25\eeg/sub-25_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 447879  =      0.000 ...   447.879 secs...
# Extracting parameters from NSERP/sub-26\eeg/sub-26_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1336799  =      0.000 ...  1336.799 secs...
# Extracting parameters from NSERP/sub-26\eeg/sub-26_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1331759  =      0.000 ...  1331.759 secs...
# Extracting parameters from NSERP/sub-26\eeg/sub-26_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 718879  =      0.000 ...   718.879 secs...
# Extracting parameters from NSERP/sub-26\eeg/sub-26_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 418539  =      0.000 ...   418.539 secs...
# Extracting parameters from NSERP/sub-27\eeg/sub-27_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1343859  =      0.000 ...  1343.859 secs...
# Extracting parameters from NSERP/sub-27\eeg/sub-27_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1367919  =      0.000 ...  1367.919 secs...
# Extracting parameters from NSERP/sub-27\eeg/sub-27_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 767019  =      0.000 ...   767.019 secs...
# Extracting parameters from NSERP/sub-27\eeg/sub-27_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 450619  =      0.000 ...   450.619 secs...
# Extracting parameters from NSERP/sub-28\eeg/sub-28_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1477139  =      0.000 ...  1477.139 secs...
# Extracting parameters from NSERP/sub-28\eeg/sub-28_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1342579  =      0.000 ...  1342.579 secs...
# Extracting parameters from NSERP/sub-28\eeg/sub-28_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 701939  =      0.000 ...   701.939 secs...
# Extracting parameters from NSERP/sub-28\eeg/sub-28_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 428879  =      0.000 ...   428.879 secs...
# Extracting parameters from NSERP/sub-29\eeg/sub-29_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1478659  =      0.000 ...  1478.659 secs...
# Extracting parameters from NSERP/sub-29\eeg/sub-29_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1332519  =      0.000 ...  1332.519 secs...
# Extracting parameters from NSERP/sub-29\eeg/sub-29_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 950159  =      0.000 ...   950.159 secs...
# Extracting parameters from NSERP/sub-30\eeg/sub-30_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1336079  =      0.000 ...  1336.079 secs...
# Extracting parameters from NSERP/sub-30\eeg/sub-30_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1350299  =      0.000 ...  1350.299 secs...
# Extracting parameters from NSERP/sub-30\eeg/sub-30_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 716959  =      0.000 ...   716.959 secs...
# Extracting parameters from NSERP/sub-30\eeg/sub-30_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 508319  =      0.000 ...   508.319 secs...
# Extracting parameters from NSERP/sub-31\eeg/sub-31_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1316119  =      0.000 ...  1316.119 secs...
# Extracting parameters from NSERP/sub-31\eeg/sub-31_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1328859  =      0.000 ...  1328.859 secs...
# Extracting parameters from NSERP/sub-31\eeg/sub-31_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 721199  =      0.000 ...   721.199 secs...
# Extracting parameters from NSERP/sub-31\eeg/sub-31_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 637459  =      0.000 ...   637.459 secs...
# Extracting parameters from NSERP/sub-32\eeg/sub-32_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1345659  =      0.000 ...  1345.659 secs...
# Extracting parameters from NSERP/sub-32\eeg/sub-32_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1362419  =      0.000 ...  1362.419 secs...
# Extracting parameters from NSERP/sub-32\eeg/sub-32_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 732419  =      0.000 ...   732.419 secs...
# Extracting parameters from NSERP/sub-32\eeg/sub-32_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 455859  =      0.000 ...   455.859 secs...
# Extracting parameters from NSERP/sub-33\eeg/sub-33_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1382219  =      0.000 ...  1382.219 secs...
# Extracting parameters from NSERP/sub-33\eeg/sub-33_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1320579  =      0.000 ...  1320.579 secs...
# Extracting parameters from NSERP/sub-33\eeg/sub-33_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 719159  =      0.000 ...   719.159 secs...
# Extracting parameters from NSERP/sub-33\eeg/sub-33_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 445439  =      0.000 ...   445.439 secs...
# Extracting parameters from NSERP/sub-34\eeg/sub-34_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1335379  =      0.000 ...  1335.379 secs...
# Extracting parameters from NSERP/sub-34\eeg/sub-34_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1347299  =      0.000 ...  1347.299 secs...
# Extracting parameters from NSERP/sub-34\eeg/sub-34_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 726339  =      0.000 ...   726.339 secs...
# Extracting parameters from NSERP/sub-34\eeg/sub-34_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 452279  =      0.000 ...   452.279 secs...
# Extracting parameters from NSERP/sub-35\eeg/sub-35_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1315699  =      0.000 ...  1315.699 secs...
# Extracting parameters from NSERP/sub-35\eeg/sub-35_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1388699  =      0.000 ...  1388.699 secs...
# Extracting parameters from NSERP/sub-35\eeg/sub-35_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 721419  =      0.000 ...   721.419 secs...
# Extracting parameters from NSERP/sub-35\eeg/sub-35_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 409979  =      0.000 ...   409.979 secs...
# Extracting parameters from NSERP/sub-36\eeg/sub-36_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1403479  =      0.000 ...  1403.479 secs...
# Extracting parameters from NSERP/sub-36\eeg/sub-36_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1426039  =      0.000 ...  1426.039 secs...
# Extracting parameters from NSERP/sub-36\eeg/sub-36_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 758199  =      0.000 ...   758.199 secs...
# Extracting parameters from NSERP/sub-36\eeg/sub-36_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 434239  =      0.000 ...   434.239 secs...
# Extracting parameters from NSERP/sub-37\eeg/sub-37_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1355919  =      0.000 ...  1355.919 secs...
# Extracting parameters from NSERP/sub-37\eeg/sub-37_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1397439  =      0.000 ...  1397.439 secs...
# Extracting parameters from NSERP/sub-37\eeg/sub-37_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 693399  =      0.000 ...   693.399 secs...
# Extracting parameters from NSERP/sub-37\eeg/sub-37_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 411899  =      0.000 ...   411.899 secs...
# Extracting parameters from NSERP/sub-38\eeg/sub-38_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1349539  =      0.000 ...  1349.539 secs...
# Extracting parameters from NSERP/sub-38\eeg/sub-38_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1512739  =      0.000 ...  1512.739 secs...
# Extracting parameters from NSERP/sub-38\eeg/sub-38_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 720759  =      0.000 ...   720.759 secs...
# Extracting parameters from NSERP/sub-38\eeg/sub-38_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 441939  =      0.000 ...   441.939 secs...
# Extracting parameters from NSERP/sub-39\eeg/sub-39_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1325939  =      0.000 ...  1325.939 secs...
# Extracting parameters from NSERP/sub-39\eeg/sub-39_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1334239  =      0.000 ...  1334.239 secs...
# Extracting parameters from NSERP/sub-39\eeg/sub-39_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 707959  =      0.000 ...   707.959 secs...
# Extracting parameters from NSERP/sub-39\eeg/sub-39_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 454919  =      0.000 ...   454.919 secs...
# Extracting parameters from NSERP/sub-40\eeg/sub-40_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1430359  =      0.000 ...  1430.359 secs...
# Extracting parameters from NSERP/sub-40\eeg/sub-40_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1453479  =      0.000 ...  1453.479 secs...
# Extracting parameters from NSERP/sub-40\eeg/sub-40_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 710359  =      0.000 ...   710.359 secs...
# Extracting parameters from NSERP/sub-40\eeg/sub-40_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 451619  =      0.000 ...   451.619 secs...
# Extracting parameters from NSERP/sub-41\eeg/sub-41_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1373839  =      0.000 ...  1373.839 secs...
# Extracting parameters from NSERP/sub-41\eeg/sub-41_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1352959  =      0.000 ...  1352.959 secs...
# Extracting parameters from NSERP/sub-41\eeg/sub-41_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 775399  =      0.000 ...   775.399 secs...
# Extracting parameters from NSERP/sub-41\eeg/sub-41_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 447859  =      0.000 ...   447.859 secs...
# Extracting parameters from NSERP/sub-42\eeg/sub-42_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1312559  =      0.000 ...  1312.559 secs...
# Extracting parameters from NSERP/sub-42\eeg/sub-42_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1321579  =      0.000 ...  1321.579 secs...
# Extracting parameters from NSERP/sub-42\eeg/sub-42_task-rest_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 727499  =      0.000 ...   727.499 secs...
# Extracting parameters from NSERP/sub-42\eeg/sub-42_task-srt_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 389899  =      0.000 ...   389.899 secs...
# ['AFz', 'AF3', 'TTP8h', 'FFT7h', 'AFp1', 'CPP3h', 'F5', 'POz', 'CPP5h', 'FTT7h', 'PO10', 'FT9', 'P10', 'CCP4h', 'P3', 'POO9h', 'AF8', 'OI1h', 'FCC1h', 'FC2', 'C5', 'PPO6h', 'C3', 'CPP1h', 'Fz', 'P5', 'PO9', 'Fp2', 'FCC6h', 'FFC2h', 'FT10', 'P1', 'FCC4h', 'FCC3h', 'F6', 'C1', 'AFF5h', 'CP3', 'TPP8h', 'CP6', 'PO8', 'CP5', 'AF4', 'TPP7h', 'FFC4h', 'FTT8h', 'PPO9h', 'F8', 'POO1', 'P7', 'AFF1h', 'TP10 RIGHT EAR', 'O1', 'P2', 'F10', 'CP4', 'T8', 'FFT9h', 'Cz', 'PPO2h', 'POO10h', 'FTT10h', 'O10', 'FTT9h', 'AFF6h', 'TP8', 'TTP7h', 'Oz', 'TPP9h', 'CCP1h', 'FFC6h', 'PO7', 'CCP5h', 'FCC5h', 'CP1', 'TPP10h', 'FC4', 'Fp1', 'FC1', 'P8', 'F7', 'FFC1h', 'P6', 'PPO1h', 'F3', 'FT7', 'OI2h', 'CPP4h', 'PPO10h', 'FFC5h', 'C4', 'POO2', 'TP9 LEFT EAR', 'P9', 'CCP2h', 'C6', 'F1', 'CPz', 'PO4', 'AFp2', 'CPP2h', 'FFT10h', 'O2', 'CP2', 'FC6', 'FFC3h', 'AFF2h', 'CCP3h', 'P4', 'F9', 'PPO5h', 'F2', 'FT8', 'O9', 'FC3', 'TP7', 'FCC2h', 'AF7', 'PO3', 'F4', 'FC5', 'CPP6h', 'CCP6h', 'Pz', 'C2', 'FFT8h', 'T7']
# Common channels number:  127

# %%
MSIT_feature_path = 'Processed/' + sub_folder_path + '/NSERP-MSIT/Feature'
if not os.path.exists(MSIT_feature_path):
    os.makedirs(MSIT_feature_path)
    
MSIT_label_path = 'Processed/' + sub_folder_path + '/NSERP-MSIT/Label'
if not os.path.exists(MSIT_label_path):
    os.makedirs(MSIT_label_path)
    
ODD_feature_path = 'Processed/' + sub_folder_path + '/NSERP-ODD/Feature'
if not os.path.exists(ODD_feature_path):
    os.makedirs(ODD_feature_path)
    
ODD_label_path = 'Processed/' + sub_folder_path + '/NSERP-ODD/Label'
if not os.path.exists(ODD_label_path):
    os.makedirs(ODD_label_path)

# %%
def data_preprocessing(
    raw: mne.io.Raw,
    common_channels: list,
    sample_rate: int = 250,
    notch_freq: float = 60.0,
    l_freq: float = 0.5,
    h_freq: float = 40.0,
    do_bad_interp: bool = True,
    verbose: bool = True,
):
    """
    Preprocessing steps ：
      1) choose common channels and reorder
      2) Set Montage 
      3) 60 Hz Notch（before band pass）
      4) bandpass filter（default 0.5–40 Hz）
      5) interpolate bad channels（if do_bad_interp is True）
      6) re-reference to average
      7) ICA（on 1 Hz high-pass filtered copy）
      8) downsample to 250 Hz
    """

    # Remove 'boundary' or 'segment' events before anything else
    # Events like "boundary" or "new segment" inserted during file conversion are not real trials and must be excluded from annotations before epoching.
    raw.annotations.delete([
        i for i, desc in enumerate(raw.annotations.description)
        if 'boundary' in desc.lower() or 'segment' in desc.lower()
    ])
    if verbose:
        print("✔ Cleaned: Removed 'boundary' or 'segment' annotations")

    # 1. select common channels and reorder to given order
    keep = [ch for ch in common_channels if ch in raw.ch_names]
    raw.pick_channels(keep)
    raw.reorder_channels(keep)
    if verbose:
        print(f"✔ Step 2: Picked common channels ({len(keep)}): {keep}")
        
    # 2. Set Montage
    # List of non-standard channels not recognized by 'standard_1020' montage
    """nonstandard_channels = [
        'FCC4h', 'CPP4h', 'POO10h', 'CPP3h', 'CPP5h', 'AFF1h', 'TTP8h',
        'FCC5h', 'FFT9h', 'PPO2h', 'PPO6h', 'FFC3h', 'PPO9h', 'PPO10h',
        'FFC6h', 'CCP2h', 'FTT7h', 'CCP3h', 'CPP2h', 'FFT7h', 'FFC2h',
        'FCC2h', 'AFF5h', 'TPP9h', 'FFT10h', 'PPO1h', 'POO2', 'FFC4h',
        'FTT10h', 'FTT9h', 'PPO5h', 'POO9h', 'FTT8h', 'OI1h', 'CPP1h',
        'FCC3h', 'FFT8h', 'CCP1h', 'FFC5h', 'TPP7h', 'FCC1h', 'POO1',
        'TTP7h', 'AFF2h', 'OI2h', 'CCP5h', 'TPP10h', 'CCP4h', 'FCC6h',
        'CPP6h', 'AFF6h', 'TPP8h','TP9 LEFT EAR', 'FFC1h', 'CCP6h', 'AFp1', 'AFp2', 'TP10 RIGHT EAR'
    ]"""
    
    nonstandard_channels = [
        'TP9 LEFT EAR', 'TP10 RIGHT EAR', 'O9', 'O10'
    ]

    # Drop non-standard channels (if they exist in the dataset)
    raw.drop_channels([ch for ch in nonstandard_channels if ch in raw.ch_names])

    # Set standard 10-20 montage and ignore any channels that are missing positions
    raw.set_montage('standard_1005')
        
    # 3. Notch
    if notch_freq is not None:
        raw.notch_filter(freqs=[notch_freq], picks="eeg", verbose=False)
        if verbose:
            print(f"✔ Step 3: Notch @ {notch_freq} Hz")
        
    # 4. Bandpass Filter (0.5–40 Hz)
    raw.filter(l_freq=l_freq, h_freq=h_freq, picks="eeg", verbose=False)
    if verbose:
        print(f"✔ Step 4: Band-pass {l_freq}–{h_freq} Hz")
        
    # 5. Interpolate bad channels
    if do_bad_interp and raw.info.get("bads"):
        raw.interpolate_bads(reset_bads=True, verbose=False)
        if verbose:
            print(f"✔ Step 5: Interpolated bads: {raw.info.get('bads', [])}")
    else:
        if verbose:
            print("ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)")
            
    # 6) Re-reference to average
    raw.set_eeg_reference("average", verbose=False)
    if verbose:
        print("✔ Step 6: Average reference")

    print()
    
    # 7) ICA (fit ICLabel on 1 Hz high-pass filtered copy, then apply to original)
    raw_for_ica = raw.copy().filter(l_freq=1.0, h_freq=None, picks="eeg", verbose=False)
    ica = ICA(n_components=None, method="fastica", random_state=97, max_iter="auto")
    ica.fit(raw_for_ica)

    excluded = []
    if 'label_components' in globals() and label_components is not None:
        try:
            ic_labels = label_components(raw_for_ica, ica, method="iclabel")
            labels = ic_labels["labels"]
            probs = ic_labels["y_pred_proba"]
            thresholds = {
                "eye blink": 0.7,
                "muscle artifact": 0.6,
                "heart beat": 0.5,
                "line noise": 0.8,
                "channel noise": 0.9,
            }
            for i, lab in enumerate(labels):
                if lab in thresholds:
                    p = probs[i].max() if probs is not None else 1.0
                    if p >= thresholds[lab]:
                        excluded.append(i)
        except Exception as e:
            if verbose:
                print(f"⚠ ICLabel failed ({e}). Skipping auto exclusion.")
    else:
        if verbose:
            print("ℹ ICLabel not available; fitted ICA but no auto component exclusion.")

    if excluded:
        ica.exclude = sorted(set(excluded))
        raw = ica.apply(raw.copy())
        if verbose:
            print(f"✔ Step 7: ICA applied. Excluded comps: {ica.exclude}")
    else:
        if verbose:
            print("ℹ Step 7: No ICA components excluded.")

    # 8) downsample to 250 Hz
    if raw.info["sfreq"] != sample_rate:
        raw.resample(sample_rate, npad="auto", verbose=False)
    if verbose:
        print(f"✔ Step 8: Resampled to {sample_rate} Hz")
        
    return raw

# %%
mapping_dict = {
    # SRT: only 5; 
    # Oddball: 5,6,7 for standard,target,deviant; 
    # MSIT: 5,6,7,8 for F0, FS, 00, S0 according to paper
    5:0, 6:1, 7:2, 8:3
}


def epoch_and_make_xy(
    raw: mne.io.Raw,
    events_tsv_path: str,
    tmin: float = -0.5,
    tmax: float = 1.5,
    baseline=(-0.5, 0),
    task_id: int = 1,
    subject_id: int = 1,
):

    # Read and parse events.tsv
    ev = pd.read_csv(events_tsv_path, sep="\t")
    ev = ev[ev["event_type"].astype(str).str.match(r"^S\s*\d+$")].copy()
    ev["code"] = ev["event_type"].str.extract(r"(\d+)").astype(int)

    # Select stimulus events based on task type
    stim = ev[(ev["code"].isin([5, 6, 7, 8])) & (ev["trial_type"] == "stimulus")].reset_index(drop=True)
    labels = stim["code"].map(mapping_dict).astype(int)
    labels = labels.values

    sfreq = raw.info["sfreq"]
    print(f"Current sampling frequency: {sfreq} Hz")

    # Convert stimulus events to sample indices
    onset_samples = np.round(stim["onset"].values * sfreq).astype(int)

    # Check epoch time boundaries to avoid exceeding raw data limits
    min_sample = int(-tmin * sfreq)
    max_sample = int(len(raw) - tmax * sfreq)
    valid_mask = (onset_samples >= min_sample) & (onset_samples <= max_sample)
    onset_samples = onset_samples[valid_mask]
    labels = labels[valid_mask]
    events = np.c_[onset_samples, np.zeros_like(onset_samples), np.ones_like(onset_samples).astype(int)]

    # Extract epochs
    picks = mne.pick_types(raw.info, eeg=True, eog=False, exclude="bads")
    epochs = mne.Epochs(
        raw, events, event_id=dict(stim=1),
        tmin=tmin, tmax=tmax,
        baseline=baseline, picks=picks,
        proj=False, preload=True, reject=None, verbose=False
    )

    # Get indices of valid trials
    good_idx = epochs.selection  # Map indices back to positions in stim/labels
    labels = labels[good_idx]    # Trim labels to match EEG epochs

    # Get EEG data (N, C, T)
    target_len = int((tmax - tmin) * sfreq)
    data = epochs.get_data()
    if data.shape[-1] > target_len:
        data = data[..., :target_len]
    elif data.shape[-1] < target_len:
        pad = target_len - data.shape[-1]
        data = np.pad(data, ((0, 0), (0, 0), (0, pad)), mode="edge")

    # Transpose to (N, T, C)
    X = np.transpose(data, (0, 2, 1))

    # Construct y
    y = np.column_stack([
        np.full_like(labels, task_id),
        labels,
        np.full_like(labels, subject_id),
    ])

    return X, y

# %%
import re
import os
task_id = 0
def get_subject_id(path: str) -> int:
    # match string like "sub-xxx" 
    match = re.search(r"sub-(\d+)", path)
    if match:
        return int(match.group(1).lstrip("0"))  
    else:
        raise ValueError(f"No subject_id found in path: {path}")
    
    
for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub, 'eeg/')
        # print(sub_path)
        subject_id = get_subject_id(sub_path)
        
        for file in os.listdir(sub_path):
            if 'msit_eeg.vhdr' in file or 'oddball_eeg.vhdr' in file or "srt_eeg.vhdr" in file: 
                # check task
                # only use visual task here
                if "msit_eeg.vhdr" in file:
                    task_id = 0
                    feature_path = MSIT_feature_path
                    label_path = MSIT_label_path
                if "oddball_eeg.vhdr" in file: 
                    task_id = 1
                    feature_path = ODD_feature_path
                    label_path = ODD_label_path
                if "srt_eeg.vhdr" in file: 
                    continue
                # load eeg data and preprocess
                print(sub_path)
                
                vhdr_path = os.path.join(sub_path, file)
                events_file = file.split(".")[0].split("_")[0] + "_" + file.split(".")[0].split("_")[1] + "_events.tsv"
                events_file_path = os.path.join(sub_path, events_file)
                
                print(vhdr_path)
                raw = mne.io.read_raw_brainvision(vhdr_path, preload=True)                
                raw.pick_types(eeg=True)   # only keep EEG channels
                raw = data_preprocessing(raw, common_channels, SAMPLE_RATE, notch_freq=50, l_freq=0.5, h_freq=40, verbose=True)
                print()
                
                # segment and make X, y
                
                print(f"Start epoching file {file} making X, y...")
                X, y = epoch_and_make_xy(
                    raw, events_file_path,
                    tmin=-0.5, tmax=1.0, baseline=(-0.5, 0),  #  -200ms - 800ms
                    task_id=task_id, subject_id=subject_id, 
                )
                print(f"File {file} epoch into trial X shape: {X.shape}, y shape: {y.shape}")

                # save X, y to npy files
                np.save(feature_path + '/feature_{:03d}.npy'.format(subject_id), X)
                np.save(label_path + '/label_{:03d}.npy'.format(subject_id), y)
                print("------------------------------------------------\n")
# Out:
# NSERP/sub-41\eeg/
# NSERP/sub-41\eeg/sub-41_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-41\eeg/sub-41_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1373839  =      0.000 ...  1373.839 secs...
# ✔ Cleaned: Removed 'boundary' or 'segment' annotations
# ✔ Step 2: Picked common channels (127): ['AFz', 'AF3', 'TTP8h', 'FFT7h', 'AFp1', 'CPP3h', 'F5', 'POz', 'CPP5h', 'FTT7h', 'PO10', 'FT9', 'P10', 'CCP4h', 'P3', 'POO9h', 'AF8', 'OI1h', 'FCC1h', 'FC2', 'C5', 'PPO6h', 'C3', 'CPP1h', 'Fz', 'P5', 'PO9', 'Fp2', 'FCC6h', 'FFC2h', 'FT10', 'P1', 'FCC4h', 'FCC3h', 'F6', 'C1', 'AFF5h', 'CP3', 'TPP8h', 'CP6', 'PO8', 'CP5', 'AF4', 'TPP7h', 'FFC4h', 'FTT8h', 'PPO9h', 'F8', 'POO1', 'P7', 'AFF1h', 'TP10 RIGHT EAR', 'O1', 'P2', 'F10', 'CP4', 'T8', 'FFT9h', 'Cz', 'PPO2h', 'POO10h', 'FTT10h', 'O10', 'FTT9h', 'AFF6h', 'TP8', 'TTP7h', 'Oz', 'TPP9h', 'CCP1h', 'FFC6h', 'PO7', 'CCP5h', 'FCC5h', 'CP1', 'TPP10h', 'FC4', 'Fp1', 'FC1', 'P8', 'F7', 'FFC1h', 'P6', 'PPO1h', 'F3', 'FT7', 'OI2h', 'CPP4h', 'PPO10h', 'FFC5h', 'C4', 'POO2', 'TP9 LEFT EAR', 'P9', 'CCP2h', 'C6', 'F1', 'CPz', 'PO4', 'AFp2', 'CPP2h', 'FFT10h', 'O2', 'CP2', 'FC6', 'FFC3h', 'AFF2h', 'CCP3h', 'P4', 'F9', 'PPO5h', 'F2', 'FT8', 'O9', 'FC3', 'TP7', 'FCC2h', 'AF7', 'PO3', 'F4', 'FC5', 'CPP6h', 'CCP6h', 'Pz', 'C2', 'FFT8h', 'T7']
# ✔ Step 3: Notch @ 50 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 123 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 122 components
# Fitting ICA took 1587.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (122 components)
#     Zeroing out 22 ICA components
#     Projecting back using 123 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 9, 14, 15, 18, 19, 21, 23, 33, 35, 36, 47, 48, 56, 74, 98, 101, 102, 110, 111, 113]
# ✔ Step 8: Resampled to 200 Hz
#
# Start epoching file sub-41_task-msit_eeg.vhdr making X, y...
# Current sampling frequency: 200.0 Hz
# File sub-41_task-msit_eeg.vhdr epoch into trial X shape: (406, 300, 123), y shape: (406, 3)
# ------------------------------------------------
#
# NSERP/sub-41\eeg/
# NSERP/sub-41\eeg/sub-41_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-41\eeg/sub-41_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1352959  =      0.000 ...  1352.959 secs...
# ✔ Cleaned: Removed 'boundary' or 'segment' annotations
# ✔ Step 2: Picked common channels (127): ['AFz', 'AF3', 'TTP8h', 'FFT7h', 'AFp1', 'CPP3h', 'F5', 'POz', 'CPP5h', 'FTT7h', 'PO10', 'FT9', 'P10', 'CCP4h', 'P3', 'POO9h', 'AF8', 'OI1h', 'FCC1h', 'FC2', 'C5', 'PPO6h', 'C3', 'CPP1h', 'Fz', 'P5', 'PO9', 'Fp2', 'FCC6h', 'FFC2h', 'FT10', 'P1', 'FCC4h', 'FCC3h', 'F6', 'C1', 'AFF5h', 'CP3', 'TPP8h', 'CP6', 'PO8', 'CP5', 'AF4', 'TPP7h', 'FFC4h', 'FTT8h', 'PPO9h', 'F8', 'POO1', 'P7', 'AFF1h', 'TP10 RIGHT EAR', 'O1', 'P2', 'F10', 'CP4', 'T8', 'FFT9h', 'Cz', 'PPO2h', 'POO10h', 'FTT10h', 'O10', 'FTT9h', 'AFF6h', 'TP8', 'TTP7h', 'Oz', 'TPP9h', 'CCP1h', 'FFC6h', 'PO7', 'CCP5h', 'FCC5h', 'CP1', 'TPP10h', 'FC4', 'Fp1', 'FC1', 'P8', 'F7', 'FFC1h', 'P6', 'PPO1h', 'F3', 'FT7', 'OI2h', 'CPP4h', 'PPO10h', 'FFC5h', 'C4', 'POO2', 'TP9 LEFT EAR', 'P9', 'CCP2h', 'C6', 'F1', 'CPz', 'PO4', 'AFp2', 'CPP2h', 'FFT10h', 'O2', 'CP2', 'FC6', 'FFC3h', 'AFF2h', 'CCP3h', 'P4', 'F9', 'PPO5h', 'F2', 'FT8', 'O9', 'FC3', 'TP7', 'FCC2h', 'AF7', 'PO3', 'F4', 'FC5', 'CPP6h', 'CCP6h', 'Pz', 'C2', 'FFT8h', 'T7']
# ✔ Step 3: Notch @ 50 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 123 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 88 components
# Fitting ICA took 104.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (88 components)
#     Zeroing out 16 ICA components
#     Projecting back using 123 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [1, 2, 3, 10, 12, 13, 23, 28, 32, 34, 42, 46, 52, 56, 66, 79]
# ✔ Step 8: Resampled to 200 Hz
#
# Start epoching file sub-41_task-oddball_eeg.vhdr making X, y...
# Current sampling frequency: 200.0 Hz
# File sub-41_task-oddball_eeg.vhdr epoch into trial X shape: (660, 300, 123), y shape: (660, 3)
# ------------------------------------------------
#
# NSERP/sub-42\eeg/
# NSERP/sub-42\eeg/sub-42_task-msit_eeg.vhdr
# Extracting parameters from NSERP/sub-42\eeg/sub-42_task-msit_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1312559  =      0.000 ...  1312.559 secs...
# ✔ Cleaned: Removed 'boundary' or 'segment' annotations
# ✔ Step 2: Picked common channels (127): ['AFz', 'AF3', 'TTP8h', 'FFT7h', 'AFp1', 'CPP3h', 'F5', 'POz', 'CPP5h', 'FTT7h', 'PO10', 'FT9', 'P10', 'CCP4h', 'P3', 'POO9h', 'AF8', 'OI1h', 'FCC1h', 'FC2', 'C5', 'PPO6h', 'C3', 'CPP1h', 'Fz', 'P5', 'PO9', 'Fp2', 'FCC6h', 'FFC2h', 'FT10', 'P1', 'FCC4h', 'FCC3h', 'F6', 'C1', 'AFF5h', 'CP3', 'TPP8h', 'CP6', 'PO8', 'CP5', 'AF4', 'TPP7h', 'FFC4h', 'FTT8h', 'PPO9h', 'F8', 'POO1', 'P7', 'AFF1h', 'TP10 RIGHT EAR', 'O1', 'P2', 'F10', 'CP4', 'T8', 'FFT9h', 'Cz', 'PPO2h', 'POO10h', 'FTT10h', 'O10', 'FTT9h', 'AFF6h', 'TP8', 'TTP7h', 'Oz', 'TPP9h', 'CCP1h', 'FFC6h', 'PO7', 'CCP5h', 'FCC5h', 'CP1', 'TPP10h', 'FC4', 'Fp1', 'FC1', 'P8', 'F7', 'FFC1h', 'P6', 'PPO1h', 'F3', 'FT7', 'OI2h', 'CPP4h', 'PPO10h', 'FFC5h', 'C4', 'POO2', 'TP9 LEFT EAR', 'P9', 'CCP2h', 'C6', 'F1', 'CPz', 'PO4', 'AFp2', 'CPP2h', 'FFT10h', 'O2', 'CP2', 'FC6', 'FFC3h', 'AFF2h', 'CCP3h', 'P4', 'F9', 'PPO5h', 'F2', 'FT8', 'O9', 'FC3', 'TP7', 'FCC2h', 'AF7', 'PO3', 'F4', 'FC5', 'CPP6h', 'CCP6h', 'Pz', 'C2', 'FFT8h', 'T7']
# ✔ Step 3: Notch @ 50 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 123 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 122 components
# Fitting ICA took 1492.3s.
# Applying ICA to Raw instance
#     Transforming to ICA space (122 components)
#     Zeroing out 20 ICA components
#     Projecting back using 123 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 7, 8, 15, 25, 26, 27, 29, 31, 33, 35, 39, 48, 59, 71, 72, 73, 83]
# ✔ Step 8: Resampled to 200 Hz
#
# Start epoching file sub-42_task-msit_eeg.vhdr making X, y...
# Current sampling frequency: 200.0 Hz
# File sub-42_task-msit_eeg.vhdr epoch into trial X shape: (397, 300, 123), y shape: (397, 3)
# ------------------------------------------------
#
# NSERP/sub-42\eeg/
# NSERP/sub-42\eeg/sub-42_task-oddball_eeg.vhdr
# Extracting parameters from NSERP/sub-42\eeg/sub-42_task-oddball_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 1321579  =      0.000 ...  1321.579 secs...
# ✔ Cleaned: Removed 'boundary' or 'segment' annotations
# ✔ Step 2: Picked common channels (127): ['AFz', 'AF3', 'TTP8h', 'FFT7h', 'AFp1', 'CPP3h', 'F5', 'POz', 'CPP5h', 'FTT7h', 'PO10', 'FT9', 'P10', 'CCP4h', 'P3', 'POO9h', 'AF8', 'OI1h', 'FCC1h', 'FC2', 'C5', 'PPO6h', 'C3', 'CPP1h', 'Fz', 'P5', 'PO9', 'Fp2', 'FCC6h', 'FFC2h', 'FT10', 'P1', 'FCC4h', 'FCC3h', 'F6', 'C1', 'AFF5h', 'CP3', 'TPP8h', 'CP6', 'PO8', 'CP5', 'AF4', 'TPP7h', 'FFC4h', 'FTT8h', 'PPO9h', 'F8', 'POO1', 'P7', 'AFF1h', 'TP10 RIGHT EAR', 'O1', 'P2', 'F10', 'CP4', 'T8', 'FFT9h', 'Cz', 'PPO2h', 'POO10h', 'FTT10h', 'O10', 'FTT9h', 'AFF6h', 'TP8', 'TTP7h', 'Oz', 'TPP9h', 'CCP1h', 'FFC6h', 'PO7', 'CCP5h', 'FCC5h', 'CP1', 'TPP10h', 'FC4', 'Fp1', 'FC1', 'P8', 'F7', 'FFC1h', 'P6', 'PPO1h', 'F3', 'FT7', 'OI2h', 'CPP4h', 'PPO10h', 'FFC5h', 'C4', 'POO2', 'TP9 LEFT EAR', 'P9', 'CCP2h', 'C6', 'F1', 'CPz', 'PO4', 'AFp2', 'CPP2h', 'FFT10h', 'O2', 'CP2', 'FC6', 'FFC3h', 'AFF2h', 'CCP3h', 'P4', 'F9', 'PPO5h', 'F2', 'FT8', 'O9', 'FC3', 'TP7', 'FCC2h', 'AF7', 'PO3', 'F4', 'FC5', 'CPP6h', 'CCP6h', 'Pz', 'C2', 'FFT8h', 'T7']
# ✔ Step 3: Notch @ 50 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 123 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 122 components
# Fitting ICA took 1057.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (122 components)
#     Zeroing out 23 ICA components
#     Projecting back using 123 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 12, 14, 15, 18, 19, 27, 29, 32, 33, 34, 35, 36, 39, 43, 55, 56, 58, 67, 69, 77]
# ✔ Step 8: Resampled to 200 Hz
#
# Start epoching file sub-42_task-oddball_eeg.vhdr making X, y...
# Current sampling frequency: 200.0 Hz
# File sub-42_task-oddball_eeg.vhdr epoch into trial X shape: (660, 300, 123), y shape: (660, 3)
# ------------------------------------------------

# %% [markdown]
# ## Load and check the processed data

# %%
# Test the saved npy file
# example
feature_path = MSIT_feature_path   
label_path = MSIT_label_path

print(f"Loading MIST+ trials:\n")
total_samples = 0
for feature_file, label_file in zip(os.listdir(feature_path), os.listdir(label_path)):
    sub_id = int(re.search(r'\d+', feature_file).group())
    feature_file_path = os.path.join(feature_path, feature_file)
    label_file_path = os.path.join(label_path, label_file)
    X = np.load(feature_file_path)
    y = np.load(label_file_path)
    print(f"Subject {sub_id}: X shape: {X.shape}, y shape: {y.shape}")
    if X.shape[0] != y.shape[0]:
        raise(f"Subject {sub_id} data and label length mismatch: " 
                f"{X.shape[0]} vs {y.shape[0]}")
    total_samples += np.load(feature_file_path).shape[0]
    sub_id += 1
print("\nTotal number of trials:", total_samples)
# Out:
# Loading MIST+ trials:
#
# Subject 1: X shape: (406, 300, 123), y shape: (406, 3)
# Subject 2: X shape: (397, 300, 123), y shape: (397, 3)
# Subject 3: X shape: (402, 300, 123), y shape: (402, 3)
# Subject 4: X shape: (403, 300, 123), y shape: (403, 3)
# Subject 5: X shape: (406, 300, 123), y shape: (406, 3)
# Subject 6: X shape: (393, 300, 123), y shape: (393, 3)
# Subject 7: X shape: (397, 300, 123), y shape: (397, 3)
# Subject 8: X shape: (404, 300, 123), y shape: (404, 3)
# Subject 9: X shape: (386, 300, 123), y shape: (386, 3)
# Subject 10: X shape: (400, 300, 123), y shape: (400, 3)
# Subject 11: X shape: (401, 300, 123), y shape: (401, 3)
# Subject 12: X shape: (393, 300, 123), y shape: (393, 3)
# Subject 13: X shape: (395, 300, 123), y shape: (395, 3)
# Subject 14: X shape: (401, 300, 123), y shape: (401, 3)
# Subject 15: X shape: (388, 300, 123), y shape: (388, 3)
# Subject 16: X shape: (392, 300, 123), y shape: (392, 3)
# Subject 17: X shape: (388, 300, 123), y shape: (388, 3)
# Subject 18: X shape: (396, 300, 123), y shape: (396, 3)
# Subject 19: X shape: (396, 300, 123), y shape: (396, 3)
# Subject 20: X shape: (397, 300, 123), y shape: (397, 3)
# Subject 21: X shape: (305, 300, 123), y shape: (305, 3)
# Subject 22: X shape: (394, 300, 123), y shape: (394, 3)
# Subject 23: X shape: (439, 300, 123), y shape: (439, 3)
# Subject 24: X shape: (405, 300, 123), y shape: (405, 3)
# Subject 25: X shape: (391, 300, 123), y shape: (391, 3)
# Subject 26: X shape: (403, 300, 123), y shape: (403, 3)
# Subject 27: X shape: (397, 300, 123), y shape: (397, 3)
# Subject 28: X shape: (406, 300, 123), y shape: (406, 3)
# Subject 29: X shape: (431, 300, 123), y shape: (431, 3)
# Subject 30: X shape: (402, 300, 123), y shape: (402, 3)
# Subject 31: X shape: (392, 300, 123), y shape: (392, 3)
# Subject 32: X shape: (401, 300, 123), y shape: (401, 3)
# Subject 33: X shape: (410, 300, 123), y shape: (410, 3)
# Subject 34: X shape: (400, 300, 123), y shape: (400, 3)
# Subject 35: X shape: (394, 300, 123), y shape: (394, 3)
# Subject 36: X shape: (402, 300, 123), y shape: (402, 3)
# Subject 37: X shape: (407, 300, 123), y shape: (407, 3)
# Subject 38: X shape: (405, 300, 123), y shape: (405, 3)
# Subject 39: X shape: (396, 300, 123), y shape: (396, 3)
# Subject 40: X shape: (405, 300, 123), y shape: (405, 3)
# Subject 41: X shape: (406, 300, 123), y shape: (406, 3)
# Subject 42: X shape: (397, 300, 123), y shape: (397, 3)
#
# Total number of trials: 16729

# %%
# Test the saved npy file
# example
feature_path = ODD_feature_path   
label_path = ODD_label_path

print(f"Loading oddball trials:\n")
total_samples = 0
for feature_file, label_file in zip(os.listdir(feature_path), os.listdir(label_path)):
    sub_id = int(re.search(r'\d+', feature_file).group())
    feature_file_path = os.path.join(feature_path, feature_file)
    label_file_path = os.path.join(label_path, label_file)
    X = np.load(feature_file_path)
    y = np.load(label_file_path)
    print(f"Subject {sub_id}: X shape: {X.shape}, y shape: {y.shape}")
    if X.shape[0] != y.shape[0]:
        raise(f"Subject {sub_id} data and label length mismatch: " 
                f"{X.shape[0]} vs {y.shape[0]}")
    total_samples += np.load(feature_file_path).shape[0]
    sub_id += 1
print("\nTotal number of trials:", total_samples)
# Out:
# Loading oddball trials:
#
# Subject 1: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 2: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 3: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 4: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 5: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 6: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 7: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 8: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 9: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 10: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 11: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 12: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 13: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 14: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 15: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 16: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 17: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 18: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 19: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 20: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 21: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 22: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 23: X shape: (692, 300, 123), y shape: (692, 3)
# Subject 24: X shape: (659, 300, 123), y shape: (659, 3)
# Subject 25: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 26: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 27: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 28: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 29: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 30: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 31: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 32: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 33: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 34: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 35: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 36: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 37: X shape: (659, 300, 123), y shape: (659, 3)
# Subject 38: X shape: (775, 300, 123), y shape: (775, 3)
# Subject 39: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 40: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 41: X shape: (660, 300, 123), y shape: (660, 3)
# Subject 42: X shape: (660, 300, 123), y shape: (660, 3)
#
# Total number of trials: 27865
