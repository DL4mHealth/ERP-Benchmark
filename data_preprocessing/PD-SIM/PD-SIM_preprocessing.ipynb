# %%
import os
import numpy as np
import h5py
import pandas as pd
from scipy.signal import resample
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
import mne
from mne.preprocessing import ICA
try:
    from mne_icalabel import label_components
except Exception:
    label_components = None

# %%
SAMPLE_RATE = 200  # fs
# SAMPLE_LEN = 1.0   # sample seconds
# OVERLAPPING = 0.8  # overlapping seconds
sub_folder_path = str(SAMPLE_RATE) + 'Hz'
sub_folder_path
# Out:
# '200Hz'

# %% [markdown]
# ## Load participants.tsv file

# %%
# root dir
root = 'PD-SIM/'
participants_path = os.path.join(root, 'participants.tsv')
participants = pd.read_csv(participants_path, sep='\t')
participants
# Out:
#     participant_id    GROUP    ID          EEG  \
# 0          sub-001       PD  1003       PD1003
# 1          sub-002       PD  1013       PD1013
# 2          sub-003       PD  1023       PD1023
# 3          sub-004       PD  1033       PD1033
# 4          sub-005       PD  1043       PD1043
# ..             ...      ...   ...          ...
# 142        sub-143  Control  1453  Control1453
# 143        sub-144  Control  1463  Control1463
# 144        sub-145  Control  1473  Control1473
# 145        sub-146  Control  1483  Control1483
# 146        sub-147  Control  1493  Control1493
#
#                             BEHAVIOR  AGE GENDER  MOCA  UPDRS  TYPE
# 0    Subject_1001_10-Oct-2017_10.26h   80      M    19   28.0     1
# 1     Subject_1002_17-Oct-2017_13.5h   81      M    17   25.0     1
# 2    Subject_1003_27-Oct-2017_10.47h   68      F    26   10.0     1
# 3     Subject_1004_31-Oct-2017_15.3h   80      M    22   10.0     1
# 4     Subject_1005_07-Nov-2017_12.3h   56      M    21   13.0     1
# ..                               ...  ...    ...   ...    ...   ...
# 142  Subject_2046_03-Feb-2021_11.46h   64      F    27    NaN     0
# 143  Subject_2047_03-Mar-2021_14.33h   71      M    30    NaN     0
# 144  Subject_2048_04-Mar-2021_10.43h   78      M    27    NaN     0
# 145  Subject_2049_08-Mar-2021_14.59h   68      F    27    NaN     0
# 146  Subject_2050_09-Mar-2021_14.55h   52      F    27    NaN     0
#
# [147 rows x 10 columns]

# %% [markdown]
# ## Find if there are bad channels, check sampling frequency and data shape to avoid inconsistency

# %%
# Test for bad channels, sampling freq and shape
bad_channel_list, sampling_freq_list, data_shape_list = [], [], []
for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub, 'eeg/')
        # print(sub_path)
        for file in os.listdir(sub_path):
            if '.set' in file:
                file_path = os.path.join(sub_path, file)
                raw = mne.io.read_raw_eeglab(file_path, preload=True)
                # get bad channels
                bad_channel = raw.info['bads']
                bad_channel_list.append(bad_channel)
                # get sampling frequency
                sampling_freq = raw.info['sfreq']
                sampling_freq_list.append(sampling_freq)
                # get eeg data
                data = raw.get_data()
                data_shape = data.shape
                data_shape_list.append(data_shape)
# Out:
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-001\eeg\sub-001_task-Simon_eeg.fdt
# Reading 0 ... 476079  =      0.000 ...   952.158 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-002\eeg\sub-002_task-Simon_eeg.fdt
# Reading 0 ... 577699  =      0.000 ...  1155.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-003\eeg\sub-003_task-Simon_eeg.fdt
# Reading 0 ... 489439  =      0.000 ...   978.878 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-004\eeg\sub-004_task-Simon_eeg.fdt
# Reading 0 ... 460929  =      0.000 ...   921.858 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-005\eeg\sub-005_task-Simon_eeg.fdt
# Reading 0 ... 426349  =      0.000 ...   852.698 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-006\eeg\sub-006_task-Simon_eeg.fdt
# Reading 0 ... 430269  =      0.000 ...   860.538 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-007\eeg\sub-007_task-Simon_eeg.fdt
# Reading 0 ... 443999  =      0.000 ...   887.998 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-008\eeg\sub-008_task-Simon_eeg.fdt
# Reading 0 ... 465739  =      0.000 ...   931.478 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-009\eeg\sub-009_task-Simon_eeg.fdt
# Reading 0 ... 426119  =      0.000 ...   852.238 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub
718 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-131\eeg\sub-131_task-Simon_eeg.fdt
# Reading 0 ... 449329  =      0.000 ...   898.658 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-132\eeg\sub-132_task-Simon_eeg.fdt
# Reading 0 ... 568529  =      0.000 ...  1137.058 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-133\eeg\sub-133_task-Simon_eeg.fdt
# Reading 0 ... 397459  =      0.000 ...   794.918 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-134\eeg\sub-134_task-Simon_eeg.fdt
# Reading 0 ... 449019  =      0.000 ...   898.038 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-135\eeg\sub-135_task-Simon_eeg.fdt
# Reading 0 ... 438369  =      0.000 ...   876.738 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-136\eeg\sub-136_task-Simon_eeg.fdt
# Reading 0 ... 451849  =      0.000 ...   903.698 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-137\eeg\sub-137_task-Simon_eeg.fdt
# Reading 0 ... 423869  =      0.000 ...   847.738 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-138\eeg\sub-138_task-Simon_eeg.fdt
# Reading 0 ... 427129  =      0.000 ...   854.258 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-139\eeg\sub-139_task-Simon_eeg.fdt
# Reading 0 ... 442569  =      0.000 ...   885.138 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-140\eeg\sub-140_task-Simon_eeg.fdt
# Reading 0 ... 427209  =      0.000 ...   854.418 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-141\eeg\sub-141_task-Simon_eeg.fdt
# Reading 0 ... 426549  =      0.000 ...   853.098 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-142\eeg\sub-142_task-Simon_eeg.fdt
# Reading 0 ... 452279  =      0.000 ...   904.558 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-143\eeg\sub-143_task-Simon_eeg.fdt
# Reading 0 ... 439199  =      0.000 ...   878.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-144\eeg\sub-144_task-Simon_eeg.fdt
# Reading 0 ... 431789  =      0.000 ...   863.578 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-145\eeg\sub-145_task-Simon_eeg.fdt
# Reading 0 ... 419799  =      0.000 ...   839.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-146\eeg\sub-146_task-Simon_eeg.fdt
# Reading 0 ... 441029  =      0.000 ...   882.058 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-147\eeg\sub-147_task-Simon_eeg.fdt
# Reading 0 ... 459299  =      0.000 ...   918.598 secs...

# %%
from collections import Counter

print(bad_channel_list)
print(data_shape_list[0])
print("Channel number counter:", Counter(i[0] for i in data_shape_list))
print("Sampling rate counter:", Counter(sampling_freq_list))
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# (63, 476080)
# Channel number counter: Counter({63: 118, 64: 28, 66: 1})
# Sampling rate counter: Counter({500.0: 147})

# %% [markdown]
# ## Pick common channels

# %%
# channel number not consistent, take the common channels
common_channels = []
for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub, 'eeg/')
        # print(sub_path)
        for file in os.listdir(sub_path):
            if '.set' in file:
                file_path = os.path.join(sub_path, file)
                raw = mne.io.read_raw_eeglab(file_path, preload=True)
                current_channels = set(raw.info['ch_names'])
                if not common_channels:
                    common_channels = current_channels
                else:
                    common_channels &= current_channels
common_channels = list(common_channels)
print(common_channels)
print("Common channels number: ", len(common_channels))
# Out:
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-001\eeg\sub-001_task-Simon_eeg.fdt
# Reading 0 ... 476079  =      0.000 ...   952.158 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-002\eeg\sub-002_task-Simon_eeg.fdt
# Reading 0 ... 577699  =      0.000 ...  1155.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-003\eeg\sub-003_task-Simon_eeg.fdt
# Reading 0 ... 489439  =      0.000 ...   978.878 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-004\eeg\sub-004_task-Simon_eeg.fdt
# Reading 0 ... 460929  =      0.000 ...   921.858 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-005\eeg\sub-005_task-Simon_eeg.fdt
# Reading 0 ... 426349  =      0.000 ...   852.698 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-006\eeg\sub-006_task-Simon_eeg.fdt
# Reading 0 ... 430269  =      0.000 ...   860.538 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub
secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-127\eeg\sub-127_task-Simon_eeg.fdt
# Reading 0 ... 418599  =      0.000 ...   837.198 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-128\eeg\sub-128_task-Simon_eeg.fdt
# Reading 0 ... 484519  =      0.000 ...   969.038 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-129\eeg\sub-129_task-Simon_eeg.fdt
# Reading 0 ... 443339  =      0.000 ...   886.678 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-130\eeg\sub-130_task-Simon_eeg.fdt
# Reading 0 ... 422859  =      0.000 ...   845.718 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-131\eeg\sub-131_task-Simon_eeg.fdt
# Reading 0 ... 449329  =      0.000 ...   898.658 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-132\eeg\sub-132_task-Simon_eeg.fdt
# Reading 0 ... 568529  =      0.000 ...  1137.058 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-133\eeg\sub-133_task-Simon_eeg.fdt
# Reading 0 ... 397459  =      0.000 ...   794.918 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-134\eeg\sub-134_task-Simon_eeg.fdt
# Reading 0 ... 449019  =      0.000 ...   898.038 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-135\eeg\sub-135_task-Simon_eeg.fdt
# Reading 0 ... 438369  =      0.000 ...   876.738 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-136\eeg\sub-136_task-Simon_eeg.fdt
# Reading 0 ... 451849  =      0.000 ...   903.698 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-137\eeg\sub-137_task-Simon_eeg.fdt
# Reading 0 ... 423869  =      0.000 ...   847.738 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-138\eeg\sub-138_task-Simon_eeg.fdt
# Reading 0 ... 427129  =      0.000 ...   854.258 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-139\eeg\sub-139_task-Simon_eeg.fdt
# Reading 0 ... 442569  =      0.000 ...   885.138 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-140\eeg\sub-140_task-Simon_eeg.fdt
# Reading 0 ... 427209  =      0.000 ...   854.418 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-141\eeg\sub-141_task-Simon_eeg.fdt
# Reading 0 ... 426549  =      0.000 ...   853.098 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-142\eeg\sub-142_task-Simon_eeg.fdt
# Reading 0 ... 452279  =      0.000 ...   904.558 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-143\eeg\sub-143_task-Simon_eeg.fdt
# Reading 0 ... 439199  =      0.000 ...   878.398 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-144\eeg\sub-144_task-Simon_eeg.fdt
# Reading 0 ... 431789  =      0.000 ...   863.578 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-145\eeg\sub-145_task-Simon_eeg.fdt
# Reading 0 ... 419799  =      0.000 ...   839.598 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-146\eeg\sub-146_task-Simon_eeg.fdt
# Reading 0 ... 441029  =      0.000 ...   882.058 secs...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-147\eeg\sub-147_task-Simon_eeg.fdt
# Reading 0 ... 459299  =      0.000 ...   918.598 secs...
# ['PO8', 'CP3', 'C2', 'FCz', 'AF8', 'AF4', 'Cz', 'F6', 'POz', 'P4', 'P1', 'FC6', 'C6', 'F2', 'FC1', 'FT7', 'Fp2', 'FT10', 'AF3', 'C1', 'CP5', 'FC5', 'C4', 'TP8', 'CP1', 'AF7', 'FT8', 'TP9', 'CP2', 'F3', 'P2', 'Oz', 'Fz', 'FC4', 'T8', 'P3', 'TP7', 'PO7', 'F7', 'P8', 'O1', 'CP6', 'F8', 'F5', 'C5', 'O2', 'CPz', 'C3', 'TP10', 'P5', 'T7', 'P6', 'Fp1', 'FC2', 'AFz', 'FC3', 'CP4', 'F4', 'F1', 'P7']
# Common channels number:  60

# %%
common_channels = ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']

# %% [markdown]
# ## Data preprocessing and segmentation

# %%
feature_path = 'Processed/' + sub_folder_path + '/PD-SIM/Feature'
if not os.path.exists(feature_path):
    os.makedirs(feature_path)
    
label_path = 'Processed/' + sub_folder_path + '/PD-SIM/Label'
if not os.path.exists(label_path):
    os.makedirs(label_path)

# %%
def data_preprocessing(
    raw: mne.io.Raw,
    common_channels: list,
    sample_rate: int = 250,
    notch_freq: float = 60.0,
    l_freq: float = 0.5,
    h_freq: float = 40.0,
    do_bad_interp: bool = True,
    verbose: bool = True,
):
    """
    Preprocessing steps ：
      1) choose common channels and reorder
      2) Set Montage 
      3) 60 Hz Notch（before band pass）
      4) bandpass filter（default 0.5–40 Hz）
      5) interpolate bad channels（if do_bad_interp is True）
      6) re-reference to average
      7) ICA（在 1 Hz 高通的副本上拟合，自动剔除眼动/肌电等分量，需 mne-icalabel）
      8) downsample to 250 Hz
    """
    
    # 1. select common channels and reorder to given order
    keep = [ch for ch in common_channels if ch in raw.ch_names]
    raw.pick_channels(keep)
    raw.reorder_channels(keep)
    if verbose:
        print(f"✔ Step 2: Picked common channels ({len(keep)}): {keep}")
        
    # 2. Set Montage
    raw.set_montage(mne.channels.make_standard_montage('standard_1020'))
    if verbose:
        print("✔ Step 1, Montage set: 'standard_1020'.")
        
    # 3. Notch（工频）
    if notch_freq is not None:
        raw.notch_filter(freqs=[notch_freq], picks="eeg", verbose=False)
        if verbose:
            print(f"✔ Step 3: Notch @ {notch_freq} Hz")
        
    # 4. Bandpass Filter (0.5–40 Hz)
    raw.filter(l_freq=l_freq, h_freq=h_freq, picks="eeg", verbose=False)
    if verbose:
        print(f"✔ Step 4: Band-pass {l_freq}–{h_freq} Hz")
        
    # 5. Interpolate bad channels
    if do_bad_interp and raw.info.get("bads"):
        raw.interpolate_bads(reset_bads=True, verbose=False)
        if verbose:
            print(f"✔ Step 5: Interpolated bads: {raw.info.get('bads', [])}")
    else:
        if verbose:
            print("ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)")
            
    # 6) Re-reference to average
    raw.set_eeg_reference("average", verbose=False)
    if verbose:
        print("✔ Step 6: Average reference")
    
    print()
    # 7) ICA (fit ICLabel on 1 Hz high-pass filtered copy, then apply to original)
    raw_for_ica = raw.copy().filter(l_freq=1.0, h_freq=None, picks="eeg", verbose=False)
    ica = ICA(n_components=0.999, method="fastica", random_state=97, max_iter="auto")
    ica.fit(raw_for_ica)

    excluded = []
    if label_components is not None:
        try:
            ic_labels = label_components(raw_for_ica, ica, method="iclabel")
            labels = ic_labels["labels"]
            probs = ic_labels["y_pred_proba"]  # (n_comp, n_classes)
            thresholds = {
                "eye blink": 0.7,
                "muscle artifact": 0.6,
                "heart beat": 0.5,
                "line noise": 0.8,
                "channel noise": 0.9,
            }
            for i, lab in enumerate(labels):
                if lab in thresholds:
                    if probs is not None:
                        p = probs[i].max()
                    else:
                        p = 1.0
                    if p >= thresholds[lab]:
                        excluded.append(i)
        except Exception as e:
            if verbose:
                print(f"⚠ ICLabel failed ({e}). Skipping auto exclusion.")
    else:
        if verbose:
            print("ℹ ICLabel not available; fitted ICA but no auto component exclusion.")

    if excluded:
        ica.exclude = sorted(set(excluded))
        raw = ica.apply(raw.copy())
        if verbose:
            print(f"✔ Step 7: ICA applied. Excluded comps: {ica.exclude}")
    else:
        if verbose:
            print("ℹ Step 7: No ICA components excluded.")

    # 8) downsample to 250 Hz
    if raw.info["sfreq"] != sample_rate:
        raw.resample(sample_rate, npad="auto", verbose=False)
    if verbose:
        print(f"✔ Step 8: Resampled to {sample_rate} Hz")
        
    return raw

# %%
def epoch_and_make_xy(
    raw: mne.io.Raw,
    events_tsv_path: str,
    beh_tsv_path: str,
    tmin: float = -0.5,
    tmax: float = 1.5,
    baseline=(-0.5, 0),               # e.g, (-0.5, 0)   baseline correction from -0.5 to 0 s
    task_id: int = 1,            # assigned task ID, here are all Simon Conflict tasks, set to 1
    subject_id: int = 1,
    disease_id: int = 1,            # assigned disease ID, e.g, 0 for healthy control, 1 for pakinson's disease
):
    """
    - from events.tsv, take S 1 cue as lock, S 1 is the cue event; S 2 is the response event
    - match with beh.tsv file's trial information, only select accuracy==1 (response correct)
    - segment [-0.5, 1.0] s of S1 cue event, get X: (N, 375(1.5s), C); Y: (N, 5)=[task_id, congruentcondition, accuracy, subject_id, disease_id]
    """
    # read events and select S 1 cue events
    ev = pd.read_csv(events_tsv_path, sep="\t")
    ev = ev[ev["value"].astype(str).str.match(r"^S\s*\d+$")].copy()  # select S 1, S 2, etc.
    ev["code"] = ev["value"].str.extract(r"(\d+)").astype(int)
    s1 = ev[ev["code"] == 1].reset_index(drop=True)

    # read behavior data and match with S1 events
    beh = pd.read_csv(beh_tsv_path, sep="\t")
    print(len(beh), "trials in behavior data")
    print(len(s1), "S1 events in events data")
    n = min(len(beh), len(s1))
    print(f"Using the first {n} trials from behavior data and S1 events to avoid mismatch.")
    beh = beh.iloc[:n].reset_index(drop=True)
    s1 = s1.iloc[:n].reset_index(drop=True)

    # only keep correct responses
    """mask = (beh["accuracy"] == 1).to_numpy()  # accuracy==1 correct, 2 incorrect, 99 no response (I guess)
    beh_ok = beh.iloc[mask]            
    s1_ok  = s1.iloc[mask]"""   # Let's keep all trials for now, and add accuracy to y later

    # from onset second to timestamp under current sampling frequency
    sfreq = raw.info["sfreq"]
    print(f"Current sampling frequency: {sfreq} Hz")
    s1_samples = np.round(s1["onset"].values * sfreq).astype(int)
    # (n_events, 3) array, first column is sample index, second column is 0 (previous event), third column is 1 (current event)
    # later we use cue=1 to epoch
    events = np.c_[s1_samples, np.zeros_like(s1_samples), np.ones_like(s1_samples).astype(int)]

    # segment epoch
    picks = mne.pick_types(raw.info, eeg=True, eog=False, exclude="bads")
    epochs = mne.Epochs(
        raw, events, event_id=dict(cue=1),
        tmin=tmin, tmax=tmax,
        baseline=baseline, picks=picks,
        proj=False, preload=True, reject=None, verbose=False
    )

    # guarantee int((tmax - tmin) * sfreq) timestamps 
    target_len = int((tmax - tmin) * sfreq)
    data = epochs.get_data()  # (N, C, T)
    if data.shape[-1] > target_len:
        data = data[..., :target_len]
    elif data.shape[-1] < target_len:
        pad = target_len - data.shape[-1]
        data = np.pad(data, ((0, 0), (0, 0), (0, pad)), mode="edge")

    # convert to (N, int((tmax - tmin) * sfreq), C)
    X = np.transpose(data, (0, 2, 1))

    # generate to Y: [task_id, congruentcondition, accuracy, subject_id, disease_id]
    congruentcondition = beh["congruentcondition"].values.astype(int)
    accuracy = beh["accuracy"].values.astype(int)  # 1 for correct, 2 for incorrect, 99 for no response
    y = np.column_stack([
        np.full_like(congruentcondition, task_id),
        congruentcondition,
        accuracy,
        np.full_like(congruentcondition, subject_id),
        np.full_like(congruentcondition, disease_id)
    ])
    
    sel = epochs.selection  # it may drop some trials during epoch segmenting due to trial out of bound
    y = y[sel]  # y align with X to avoid mismatch

    return X, y

# %%
for sub in os.listdir(root):
    if 'sub-' in sub:
        print("Current subject: ", sub)
        eeg_path = os.path.join(root, sub, 'eeg/')
        beh_path = os.path.join(root, sub, 'beh/')
        # print(sub_path)
        # look for set, events, and beh file, set file is the EEG data, events and beh file is the erp information
        set_file_path, events_file_path, beh_file_path = None, None, None
        for file in os.listdir(eeg_path):
            if '.set' in file:
                set_file_path = os.path.join(eeg_path, file)
            if 'events.tsv' in file:
                events_file_path = os.path.join(eeg_path, file)
        for file in os.listdir(beh_path):
            if 'beh.tsv' in file:
                beh_file_path = os.path.join(beh_path, file)
        if set_file_path is None:
            raise FileNotFoundError(f".set file not found in: {eeg_path}")
        if events_file_path is None:
            raise FileNotFoundError(f"events .tsv not found in: {eeg_path}")
        if beh_file_path is None:
            raise FileNotFoundError(f"beh .tsv not found in: {beh_path}")
        
        # load eeg data and preprocess
        print("Start preprocessing EEG data...")
        raw = mne.io.read_raw_eeglab(set_file_path, preload=True)
        raw = data_preprocessing(raw, common_channels, SAMPLE_RATE, notch_freq=60, l_freq=0.5, h_freq=40, verbose=True)
        
        print()
        
        # segment and make X, y
        subject_id = int((sub.split('-')[-1]).split('.')[0])
        disease_id = participants[participants['participant_id'] == sub]['GROUP'].values[0]
        if disease_id == 'Control':
            disease_id = 0
        elif disease_id == 'PD':
            disease_id = 1
            
        print(f"Subject ID: {subject_id}, Disease ID: {disease_id}")
        print("Start epoching and making X, y...")
        X, y = epoch_and_make_xy(
            raw, events_file_path, beh_file_path,
            tmin=-0.5, tmax=1.0, baseline=(-0.3, -0.2),
            task_id=1, subject_id=subject_id, disease_id=disease_id
        )
        print(f"X shape: {X.shape}, y shape: {y.shape}")  # X: (N, SAMPLE_RATE * (tmax - tmin), C), y: (N, 5), [task_id, congruentcondition, accuracy, subject_id, disease_id]
        # save X, y to npy files
        np.save(feature_path + '/feature_{:03d}.npy'.format(subject_id), X)
        np.save(label_path + '/label_{:03d}.npy'.format(subject_id), y)
        
        print("------------------------------------------------\n")
# Out:
# Current subject:  sub-001
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-001\eeg\sub-001_task-Simon_eeg.fdt
# Reading 0 ... 476079  =      0.000 ...   952.158 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 49 components
# Fitting ICA took 24.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (49 components)
#     Zeroing out 21 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 3, 6, 8, 9, 12, 13, 14, 15, 16, 18, 20, 21, 23, 24, 26, 28, 29, 31]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 1, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-002
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-002\eeg\sub-002_task-Simon_eeg.fdt
# Reading 0 ... 577699  =      0.000 ...  1155.398 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 4 components
# Fitting ICA took 2.7s.
# ℹ Step 7: No ICA components excluded.
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 2, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 370 S1 events in events data
# Using the first 370 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (370, 300, 60), y shape: (370, 5)
# ------------------------------------------------
#
# Current subject:  sub-003
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-003\eeg\sub-003_task-Simon_eeg.fdt
# Reading 0 ... 489439  =      0.000 ...   978.878 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 42 components
# Fitting ICA took 12.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (42 components)
#     Zeroing out 10 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 5, 6, 9, 10, 15, 18, 19, 21, 30]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 3, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-004
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-004\eeg\sub-004_task-Simon_eeg.fdt
# Reading 0 ... 460929  =      0.000 ...   921.858 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 39 components
# Fitting ICA took 10.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (39 components)
#     Zeroing out 8 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 5, 21, 23, 24, 25, 26, 32]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 4, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-005
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-005\eeg\sub-005_task-Simon_eeg.fdt
# Reading 0 ... 426349  =      0.000 ...   852.698 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 51 components
# Fitting ICA took 15.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (51 components)
#     Zeroing out 7 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 8, 13, 22, 32]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 5, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-006
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-006\eeg\sub-006_task-Simon_eeg.fdt
# Reading 0 ... 430269  =      0.000 ...   860.538 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 50 components
# Fitting ICA took 11.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (50 components)
#     Zeroing out 15 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 6, 13, 15, 16, 17, 20, 21, 23, 27, 30, 33, 36, 37, 38]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 6, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 381 S1 events in events data
# Using the first 381 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (381, 300, 60), y shape: (381, 5)
# ------------------------------------------------
#
# Current subject:  sub-007
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-007\eeg\sub-007_task-Simon_eeg.fdt
# Reading 0 ... 443999  =      0.000 ...   887.998 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 37 components
# Fitting ICA took 11.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (37 components)
#     Zeroing out 5 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 3, 16, 22]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 7, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-008
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-008\eeg\sub-008_task-Simon_eeg.fdt
# Reading 0 ... 465739  =      0.000 ...   931.478 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 44 components
# Fitting ICA took 17.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (44 components)
#     Zeroing out 9 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 2, 3, 4, 5, 11, 15, 20, 23]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 8, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-009
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-009\eeg\sub-009_task-Simon_eeg.fdt
# Reading 0 ... 426119  =      0.000 ...   852.238 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 43 components
# Fitting ICA took 15.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (43 components)
#     Zeroing out 13 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 7, 8, 14, 15, 17, 19, 22, 28, 30, 35, 39]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 9, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-010
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-010\eeg\sub-010_task-Simon_eeg.fdt
# Reading 0 ... 448249  =      0.000 ...   896.498 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 45 components
# Fitting ICA took 12.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (45 components)
#     Zeroing out 11 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [2, 4, 20, 28, 29, 30, 31, 34, 35, 36, 37]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 10, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 383 S1 events in events data
# Using the first 383 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (383, 300, 60), y shape: (383, 5)
# ------------------------------------------------
#
# Current subject:  sub-011
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-011\eeg\sub-011_task-Simon_eeg.fdt
# Reading 0 ... 418899  =      0.000 ...   837.798 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 36 components
# Fitting ICA took 8.3s.
# Applying ICA to Raw instance
#     Transforming to ICA space (36 components)
#     Zeroing out 8 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [1, 2, 10, 18, 19, 21, 23, 28]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 11, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 381 S1 events in events data
# Using the first 381 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (381, 300, 60), y shape: (381, 5)
# ------------------------------------------------
#
# Current subject:  sub-012
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-012\eeg\sub-012_task-Simon_eeg.fdt
# Reading 0 ... 512709  =      0.000 ...  1025.418 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 47 components
# Fitting ICA took 13.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (47 components)
#     Zeroing out 13 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [1, 4, 6, 11, 13, 16, 17, 20, 21, 22, 28, 32, 40]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 12, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 382 S1 events in events data
# Using the first 382 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (382, 300, 60), y shape: (382, 5)
# ------------------------------------------------
#
# Current subject:  sub-013
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-013\eeg\sub-013_task-Simon_eeg.fdt
# Reading 0 ... 430229  =      0.000 ...   860.458 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 45 components
# Fitting ICA took 13.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (45 components)
#     Zeroing out 17 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 3, 7, 10, 13, 17, 20, 21, 23, 25, 26, 27, 29, 31, 33, 34, 40]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 13, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 383 S1 events in events data
# Using the first 383 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (383, 300, 60), y shape: (383, 5)
# ------------------------------------------------
#
# Current subject:  sub-014
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-014\eeg\sub-014_task-Simon_eeg.fdt
# Reading 0 ... 527549  =      0.000 ...  1055.098 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 34 components
# Fitting ICA took 12.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (34 components)
#     Zeroing out 8 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 3, 10, 21, 23, 25, 26, 31]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 14, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-015
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-015\eeg\sub-015_task-Simon_eeg.fdt
# Reading 0 ... 443969  =      0.000 ...   887.938 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 51 components
# Fitting ICA took 20.3s.
# Applying ICA to Raw instance
#     Transforming to ICA space (51 components)
#     Zeroing out 11 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 5, 6, 7, 13, 16, 20, 23, 28, 39]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 15, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-016
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-016\eeg\sub-016_task-Simon_eeg.fdt
# Reading 0 ... 197179  =      0.000 ...   394.358 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 52 components
# Fitting ICA took 9.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (52 components)
#     Zeroing out 10 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [4, 23, 24, 26, 27, 32, 35, 40, 41, 45]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 16, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 192 S1 events in events data
# Using the first 192 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (192, 300, 60), y shape: (192, 5)
# ------------------------------------------------
#
# Current subject:  sub-017
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-017\eeg\sub-017_task-Simon_eeg.fdt
# Reading 0 ... 439309  =      0.000 ...   878.618 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 41 components
# Fitting ICA took 14.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (41 components)
#     Zeroing out 20 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 3, 6, 7, 12, 13, 15, 16, 17, 20, 21, 24, 25, 27, 30, 31, 33, 38, 39]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 17, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 382 S1 events in events data
# Using the first 382 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (382, 300, 60), y shape: (382, 5)
# ------------------------------------------------
#
# Current subject:  sub-018
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-018\eeg\sub-018_task-Simon_eeg.fdt
# Reading 0 ... 392589  =      0.000 ...   785.178 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 28 components
# Fitting ICA took 6.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (28 components)
#     Zeroing out 16 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 3, 4, 5, 6, 8, 10, 11, 13, 14, 15, 18, 19, 26]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 18, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-019
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-019\eeg\sub-019_task-Simon_eeg.fdt
# Reading 0 ... 488829  =      0.000 ...   977.658 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 28 components
# Fitting ICA took 5.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (28 components)
#     Zeroing out 3 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 4, 9]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 19, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-020
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-020\eeg\sub-020_task-Simon_eeg.fdt
# Reading 0 ... 408189  =      0.000 ...   816.378 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 38 components
# Fitting ICA took 9.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (38 components)
#     Zeroing out 4 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 3, 16, 19]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 20, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-021
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-021\eeg\sub-021_task-Simon_eeg.fdt
# Reading 0 ... 423299  =      0.000 ...   846.598 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 25 components
# Fitting ICA took 6.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (25 components)
#     Zeroing out 3 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 4]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 21, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 381 S1 events in events data
# Using the first 381 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (381, 300, 60), y shape: (381, 5)
# ------------------------------------------------
#
# Current subject:  sub-022
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-022\eeg\sub-022_task-Simon_eeg.fdt
# Reading 0 ... 446879  =      0.000 ...   893.758 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 28 components
# Fitting ICA took 5.3s.
# Applying ICA to Raw instance
#     Transforming to ICA space (28 components)
#     Zeroing out 6 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 12, 13, 16, 19]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 22, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 382 S1 events in events data
# Using the first 382 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (382, 300, 60), y shape: (382, 5)
# ------------------------------------------------
#
# Current subject:  sub-023
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-023\eeg\sub-023_task-Simon_eeg.fdt
# Reading 0 ... 444199  =      0.000 ...   888.398 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 32 components
# Fitting ICA took 5.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (32 components)
#     Zeroing out 11 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 3, 4, 5, 7, 9, 10, 11, 13, 16]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 23, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 382 S1 events in events data
# Using the first 382 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (382, 300, 60), y shape: (382, 5)
# ------------------------------------------------
#
# Current subject:  sub-024
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-024\eeg\sub-024_task-Simon_eeg.fdt
# Reading 0 ... 430149  =      0.000 ...   860.298 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 41 components
# Fitting ICA took 7.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (41 components)
#     Zeroing out 7 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 3, 5, 13, 29, 37]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 24, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-025
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-025\eeg\sub-025_task-Simon_eeg.fdt
# Reading 0 ... 370129  =      0.000 ...   740.258 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 46 components
# Fitting ICA took 10.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (46 components)
#     Zeroing out 7 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [5, 6, 19, 20, 29, 34, 38]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 25, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 379 S1 events in events data
# Using the first 379 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (379, 300, 60), y shape: (379, 5)
# ------------------------------------------------
#
# Current subject:  sub-026
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-026\eeg\sub-026_task-Simon_eeg.fdt
# Reading 0 ... 419509  =      0.000 ...   839.018 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 40 components
# Fitting ICA took 9.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (40 components)
#     Zeroing out 11 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [6, 8, 14, 17, 23, 24, 25, 26, 28, 29, 34]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 26, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 380 S1 events in events data
# Using the first 380 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (380, 300, 60), y shape: (380, 5)
# ------------------------------------------------
#
# Current subject:  sub-027
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-027\eeg\sub-027_task-Simon_eeg.fdt
# Reading 0 ... 417499  =      0.000 ...   834.998 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 36 components
# Fitting ICA took 6.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (36 components)
#     Zeroing out 10 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 2, 4, 7, 12, 13, 14, 18, 35]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 27, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 380 S1 events in events data
# Using the first 380 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (380, 300, 60), y shape: (380, 5)
# ------------------------------------------------
#
# Current subject:  sub-028
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-028\eeg\sub-028_task-Simon_eeg.fdt
# Reading 0 ... 415019  =      0.000 ...   830.038 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 33 components
# Fitting ICA took 9.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (33 components)
#     Zeroing out 7 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 11, 16, 19, 20, 21, 22]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 28, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-029
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-029\eeg\sub-029_task-Simon_eeg.fdt
# Reading 0 ... 466919  =      0.000 ...   933.838 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 49 components
# Fitting ICA took 23.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (49 components)
#     Zeroing out 9 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 9, 13, 19, 21, 22, 24, 33]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 29, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 382 S1 events in events data
# Using the first 382 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (382, 300, 60), y shape: (382, 5)
# ------------------------------------------------
#
# Current subject:  sub-030
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-030\eeg\sub-030_task-Simon_eeg.fdt
# Reading 0 ... 473749  =      0.000 ...   947.498 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 44 components
# Fitting ICA took 10.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (44 components)
#     Zeroing out 19 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [2, 3, 4, 5, 6, 9, 13, 15, 17, 18, 21, 23, 25, 26, 33, 35, 37, 39, 43]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 30, Disease ID: 1
# Start epoching and making X, y...
# 384 trials in behavior data
# 382 S1 events in events data
# Using the first 382 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (382, 300, 60), y shape: (382, 5)
# ------------------------------------------------
#
# Current subject:  sub-031
# Start preprocessing EEG data...
# ...
# X shape: (383, 300, 60), y shape: (383, 5)
# ------------------------------------------------
#
# Current subject:  sub-138
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-138\eeg\sub-138_task-Simon_eeg.fdt
# Reading 0 ... 427129  =      0.000 ...   854.258 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 22 components
# Fitting ICA took 9.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (22 components)
#     Zeroing out 5 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [3, 5, 11, 13, 17]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 138, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-139
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-139\eeg\sub-139_task-Simon_eeg.fdt
# Reading 0 ... 442569  =      0.000 ...   885.138 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 40 components
# Fitting ICA took 16.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (40 components)
#     Zeroing out 5 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 7, 9, 27]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 139, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-140
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-140\eeg\sub-140_task-Simon_eeg.fdt
# Reading 0 ... 427209  =      0.000 ...   854.418 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 53 components
# Fitting ICA took 21.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (53 components)
#     Zeroing out 6 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [1, 2, 4, 11, 23, 26]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 140, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-141
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-141\eeg\sub-141_task-Simon_eeg.fdt
# Reading 0 ... 426549  =      0.000 ...   853.098 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 25 components
# Fitting ICA took 13.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (25 components)
#     Zeroing out 5 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 10, 16, 20]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 141, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-142
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-142\eeg\sub-142_task-Simon_eeg.fdt
# Reading 0 ... 452279  =      0.000 ...   904.558 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 27 components
# Fitting ICA took 10.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (27 components)
#     Zeroing out 12 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 3, 4, 5, 6, 8, 9, 13, 14, 19, 20, 21]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 142, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-143
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-143\eeg\sub-143_task-Simon_eeg.fdt
# Reading 0 ... 439199  =      0.000 ...   878.398 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 25 components
# Fitting ICA took 7.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (25 components)
#     Zeroing out 4 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 2, 13, 23]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 143, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-144
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-144\eeg\sub-144_task-Simon_eeg.fdt
# Reading 0 ... 431789  =      0.000 ...   863.578 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 39 components
# Fitting ICA took 13.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (39 components)
#     Zeroing out 14 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 3, 5, 8, 9, 11, 12, 15, 16, 18, 19, 23, 27, 32]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 144, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-145
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-145\eeg\sub-145_task-Simon_eeg.fdt
# Reading 0 ... 419799  =      0.000 ...   839.598 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 31 components
# Fitting ICA took 11.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (31 components)
#     Zeroing out 11 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 5, 8, 15, 16, 20, 21, 26, 27, 30]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 145, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-146
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-146\eeg\sub-146_task-Simon_eeg.fdt
# Reading 0 ... 441029  =      0.000 ...   882.058 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 23 components
# Fitting ICA took 8.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (23 components)
#     Zeroing out 5 ICA components
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0, 1, 7, 9, 11]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 146, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------
#
# Current subject:  sub-147
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\PD-SIM\PD-SIM\sub-147\eeg\sub-147_task-Simon_eeg.fdt
# Reading 0 ... 459299  =      0.000 ...   918.598 secs...
# ✔ Step 2: Picked common channels (60): ['FT7', 'Fz', 'P7', 'P8', 'POz', 'F7', 'FT8', 'AF8', 'TP7', 'Cz', 'CP1', 'FC4', 'FC1', 'T7', 'Oz', 'AF7', 'CP6', 'C4', 'C2', 'C3', 'P4', 'F4', 'F6', 'P1', 'TP10', 'P3', 'O2', 'T8', 'CP5', 'Fp1', 'AF3', 'P5', 'P2', 'F2', 'Fp2', 'CPz', 'O1', 'CP3', 'F5', 'FCz', 'PO7', 'TP9', 'PO8', 'P6', 'C1', 'TP8', 'CP4', 'FT10', 'F3', 'F8', 'FC2', 'C6', 'C5', 'CP2', 'AFz', 'FC5', 'AF4', 'FC6', 'F1', 'FC3']
# ✔ Step 1, Montage set: 'standard_1020'.
# ✔ Step 3: Notch @ 60 Hz
# ✔ Step 4: Band-pass 0.5–40 Hz
# ℹ Step 5: No bads to interpolate (set raw.info['bads'] first if needed)
# ✔ Step 6: Average reference
#
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 43 components
# Fitting ICA took 241.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (43 components)
#     Zeroing out 1 ICA component
#     Projecting back using 60 PCA components
# ✔ Step 7: ICA applied. Excluded comps: [0]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 147, Disease ID: 0
# Start epoching and making X, y...
# 384 trials in behavior data
# 384 S1 events in events data
# Using the first 384 trials from behavior data and S1 events to avoid mismatch.
# Current sampling frequency: 200.0 Hz
# X shape: (384, 300, 60), y shape: (384, 5)
# ------------------------------------------------

# %% [markdown]
# ## Load and check the processed data

# %%
# Test the saved npy file
# example

total_samples = 0
sub_id = 1
for feature_file, label_file in zip(os.listdir(feature_path), os.listdir(label_path)):
    feature_file_path = os.path.join(feature_path, feature_file)
    label_file_path = os.path.join(label_path, label_file)
    X = np.load(feature_file_path)
    y = np.load(label_file_path)
    print(f"Subject {sub_id}: X shape: {X.shape}, y shape: {y.shape}")
    if X.shape[0] != y.shape[0]:
        raise(f"Subject {sub_id} data and label length mismatch: " 
                f"{X.shape[0]} vs {y.shape[0]}")
    total_samples += np.load(feature_file_path).shape[0]
    sub_id += 1
print("\nTotal number of samples:", total_samples)
# Out:
# Subject 1: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 2: X shape: (370, 300, 60), y shape: (370, 5)
# Subject 3: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 4: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 5: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 6: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 7: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 8: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 9: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 10: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 11: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 12: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 13: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 14: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 15: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 16: X shape: (192, 300, 60), y shape: (192, 5)
# Subject 17: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 18: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 19: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 20: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 21: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 22: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 23: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 24: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 25: X shape: (379, 300, 60), y shape: (379, 5)
# Subject 26: X shape: (380, 300, 60), y shape: (380, 5)
# Subject 27: X shape: (380, 300, 60), y shape: (380, 5)
# Subject 28: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 29: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 30: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 31: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 32: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 33: X shape: (380, 300, 60), y shape: (380, 5)
# Subject 34: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 35: X shape: (378, 300, 60), y shape: (378, 5)
# Subject 36: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 37: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 38: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 39: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 40: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 41: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 42: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 43: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 44: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 45: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 46: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 47: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 48: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 49: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 50: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 51: X shape: (380, 300, 60), y shape: (380, 5)
# Subject 52: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 53: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 54: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 55: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 56: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 57: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 58: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 59: X shape: (379, 300, 60), y shape: (379, 5)
# Subject 60: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 61: X shape: (192, 300, 60), y shape: (192, 5)
# Subject 62: X shape: (380, 300, 60), y shape: (380, 5)
# Subject 63: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 64: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 65: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 66: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 67: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 68: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 69: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 70: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 71: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 72: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 73: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 74: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 75: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 76: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 77: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 78: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 79: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 80: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 81: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 82: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 83: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 84: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 85: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 86: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 87: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 88: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 89: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 90: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 91: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 92: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 93: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 94: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 95: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 96: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 97: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 98: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 99: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 100: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 101: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 102: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 103: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 104: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 105: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 106: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 107: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 108: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 109: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 110: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 111: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 112: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 113: X shape: (382, 300, 60), y shape: (382, 5)
# Subject 114: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 115: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 116: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 117: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 118: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 119: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 120: X shape: (378, 300, 60), y shape: (378, 5)
# Subject 121: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 122: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 123: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 124: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 125: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 126: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 127: X shape: (380, 300, 60), y shape: (380, 5)
# Subject 128: X shape: (381, 300, 60), y shape: (381, 5)
# Subject 129: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 130: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 131: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 132: X shape: (377, 300, 60), y shape: (377, 5)
# Subject 133: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 134: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 135: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 136: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 137: X shape: (383, 300, 60), y shape: (383, 5)
# Subject 138: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 139: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 140: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 141: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 142: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 143: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 144: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 145: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 146: X shape: (384, 300, 60), y shape: (384, 5)
# Subject 147: X shape: (384, 300, 60), y shape: (384, 5)
#
# Total number of samples: 55921
