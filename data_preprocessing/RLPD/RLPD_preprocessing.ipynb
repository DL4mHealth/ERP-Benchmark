# %%
import os
import numpy as np
import h5py
import pandas as pd
from scipy.signal import resample
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
import mne
from mne.preprocessing import ICA
try:
    from mne_icalabel import label_components
except Exception:
    label_components = None

# %%
SAMPLE_RATE = 200  # fs
# SAMPLE_LEN = 1.0   # sample seconds
# OVERLAPPING = 0.8  # overlapping seconds
sub_folder_path = str(SAMPLE_RATE) + 'Hz'
sub_folder_path
# Out:
# '200Hz'

# %%
## Load participants.tsv file
# root dir
root = "RLPD/"
participants_path = os.path.join(root, "participants.tsv")
participants = pd.read_csv(participants_path, sep="\t")
participants
# Out:
#    participant_id  Original_ID Group sess1_Med sess2_Med     sex  age
# 0         sub-001         8010   CTL       NaN     no s2  Female   61
# 1         sub-002          801    PD        ON       OFF  Female   60
# 2         sub-003          802    PD       OFF        ON    Male   75
# 3         sub-004          803    PD       OFF        ON  Female   76
# 4         sub-005          804    PD        ON       OFF    Male   75
# 5         sub-006          805    PD        ON       OFF    Male   79
# 6         sub-007         8060   CTL       NaN     no s2  Female   83
# 7         sub-008          806    PD       OFF        ON  Female   79
# 8         sub-009         8070   CTL       NaN     no s2  Female   67
# 9         sub-010          807    PD       OFF        ON  Female   72
# 10        sub-011          808    PD       OFF        ON    Male   68
# 11        sub-012          809    PD        ON       OFF    Male   71
# 12        sub-013          810    PD        ON       OFF    Male   68
# 13        sub-014          811    PD        ON       OFF    Male   68
# 14        sub-015          813    PD       OFF        ON    Male   83
# 15        sub-016          814    PD        ON       OFF    Male   61
# 16        sub-017          815    PD        ON       OFF    Male   55
# 17        sub-018          816    PD       OFF        ON  Female   49
# 18        sub-019          817    PD       OFF        ON    Male   71
# 19        sub-020          818    PD        ON       OFF  Female   74
# 20        sub-021          819    PD       OFF        ON    Male   76
# 21        sub-022          820    PD        ON       OFF    Male   72
# 22        sub-023          821    PD        ON       OFF  Female   49
# 23        sub-024          822    PD        ON       OFF    Male   70
# 24        sub-025          823    PD       OFF        ON  Female   64
# 25        sub-026          824    PD       OFF        ON    Male   78
# 26        sub-027          825    PD        ON       OFF  Female   77
# 27        sub-028          826    PD        ON       OFF    Male   66
# 28        sub-029          827    PD       OFF        ON    Male   68
# 29        sub-030          828    PD       OFF        ON  Female   76
# 30        sub-031          829    PD       OFF        ON  Female   73
# 31        sub-032          890   CTL       NaN     no s2  Female   66
# 32        sub-033          891   CTL       NaN     no s2    Male   80
# 33        sub-034          892   CTL       NaN     no s2  Female   64
# 34        sub-035          893   CTL       NaN     no s2  Female   64
# 35        sub-036          894   CTL       NaN     no s2  Female   69
# 36        sub-037          895   CTL       NaN     no s2    Male   69
# 37        sub-038          896   CTL       NaN     no s2    Male   58
# 38        sub-039          897   CTL       NaN     no s2    Male   70
# 39        sub-040          898   CTL       NaN     no s2    Male   64
# 40        sub-041          899   CTL       NaN     no s2    Male   52
# 41        sub-042          900   CTL       NaN     no s2    Male   84
# 42        sub-043          901   CTL       NaN     no s2  Female   69
# 43        sub-044          902   CTL       NaN     no s2    Male   83
# 44        sub-045          903   CTL       NaN     no s2    Male   83
# 45        sub-046          904   CTL       NaN     no s2    Male   73
# 46        sub-047          905   CTL       NaN     no s2  Female   58
# 47        sub-048          906   CTL       NaN     no s2    Male   77
# 48        sub-049          907   CTL       NaN     no s2  Female   65
# 49        sub-050          908   CTL       NaN     no s2    Male   75
# 50        sub-051          909   CTL       NaN     no s2    Male   64
# 51        sub-052          910   CTL       NaN     no s2    Male   75
# 52        sub-053          911   CTL       NaN     no s2    Male   73
# 53        sub-054          912   CTL       NaN     no s2    Male   75
# 54        sub-055          913   CTL       NaN     no s2    Male   69
# 55        sub-056          914   CTL       NaN     no s2  Female   48

# %%
# Test for bad channels, sampling freq and shape
bad_channel_list, sampling_freq_list, data_shape_list = [], [], []
for sub in os.listdir(root):
    if sub.startswith("sub-"):   # Confirm it is a subject directory
        sub_path = os.path.join(root, sub)
        for ses in os.listdir(sub_path):
            ses_path = os.path.join(sub_path, ses, "eeg")
            if os.path.exists(ses_path):
                for file in os.listdir(ses_path):
                    if file.endswith(".set"):
                        file_path = os.path.join(ses_path, file)
                        print(f"Reading in progress: {file_path}")
                        
                        try:
                            # Try loading raw first
                            raw = mne.io.read_raw_eeglab(file_path, preload=True)
                            bad_channel_list.append(raw.info['bads'])
                            sampling_freq_list.append(raw.info['sfreq'])
                            data_shape_list.append(raw.get_data().shape)
                        except Exception as e1:
                            print(f"  -> If raw fails, try epochs: {e1}")
                            try:
                                epochs = mne.read_epochs_eeglab(file_path)
                                epochs.load_data()
                                bad_channel_list.append(epochs.info['bads'])
                                sampling_freq_list.append(epochs.info['sfreq'])
                                data_shape_list.append(epochs.get_data().shape)
                            except Exception as e2:
                                print(f"  -> Failed to load epochs as well: {e2}")
# Out:
# Reading in progress: RLPD/sub-001\ses-01\eeg\sub-001_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-001\ses-01\eeg\sub-001_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 704899  =      0.000 ...  1409.798 secs...
# Reading in progress: RLPD/sub-002\ses-01\eeg\sub-002_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-002\ses-01\eeg\sub-002_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 960124  =      0.000 ...  1920.248 secs...
# Reading in progress: RLPD/sub-002\ses-02\eeg\sub-002_ses-02_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-002\ses-02\eeg\sub-002_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 312124  =      0.000 ...   624.248 secs...
# Reading in progress: RLPD/sub-003\ses-01\eeg\sub-003_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-003\ses-01\eeg\sub-003_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 761424  =      0.000 ...  1522.848 secs...
# Reading in progress: RLPD/sub-003\ses-02\eeg\sub-003_ses-02_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-003\ses-02\eeg\sub-003_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 913074  =      0.000 ...  1826.148 secs...
# Reading in progress: RLPD/sub-004\ses-01\eeg\sub-004_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-004\ses-01\eeg\sub-004_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 817849  =      0.000 ...  1635.698 secs...
# Reading in progress: RLPD/sub-004\ses-02\eeg\sub-004_ses-02_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-004\ses-02\eeg\sub-004_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 643574  =      0.000 ...  1287.148 secs...
# Reading in progress: RLPD/sub-005\ses-01\eeg\sub-005_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-005\ses-01\eeg\sub-005_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 760374  =      0.000 ...  1520.748 secs...
# Reading in progress: RLPD/sub-005\ses-02\eeg\sub-005_ses-02_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-005\ses-02\eeg\sub-005_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 731849  =      0.000 ...  1463.698 secs...
# Reading in progress: RLPD/sub-006\ses-01\eeg\sub-006_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-006\ses-01\eeg\sub-006_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 759949  =      0.000 ...  1519.898 secs...
# Reading in progress: RLPD/sub-006\ses-02\eeg\sub-006_ses-02_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-006\ses-02\eeg\sub-006_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 784124  =      0.000 ...  1568.248 secs...
# Reading in progress: RLPD/sub-007\ses-01\eeg\sub-007_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-007\ses-01\eeg\sub-007_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ...
ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 769124  =      0.000 ...  1538.248 secs...
# Reading in progress: RLPD/sub-049\ses-01\eeg\sub-049_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-049\ses-01\eeg\sub-049_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 839874  =      0.000 ...  1679.748 secs...
# Reading in progress: RLPD/sub-050\ses-01\eeg\sub-050_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-050\ses-01\eeg\sub-050_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 671874  =      0.000 ...  1343.748 secs...
# Reading in progress: RLPD/sub-051\ses-01\eeg\sub-051_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-051\ses-01\eeg\sub-051_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 760124  =      0.000 ...  1520.248 secs...
# Reading in progress: RLPD/sub-052\ses-01\eeg\sub-052_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-052\ses-01\eeg\sub-052_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 688624  =      0.000 ...  1377.248 secs...
# Reading in progress: RLPD/sub-053\ses-01\eeg\sub-053_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-053\ses-01\eeg\sub-053_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 687699  =      0.000 ...  1375.398 secs...
# Reading in progress: RLPD/sub-054\ses-01\eeg\sub-054_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-054\ses-01\eeg\sub-054_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 651549  =      0.000 ...  1303.098 secs...
# Reading in progress: RLPD/sub-055\ses-01\eeg\sub-055_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-055\ses-01\eeg\sub-055_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 794999  =      0.000 ...  1589.998 secs...
# Reading in progress: RLPD/sub-056\ses-01\eeg\sub-056_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-056\ses-01\eeg\sub-056_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 635524  =      0.000 ...  1271.048 secs...

# %%
from collections import Counter

print(bad_channel_list)
print(data_shape_list[0])
print("Channel number counter:", Counter(i[0] for i in data_shape_list))
print("Sampling rate counter:", Counter(sampling_freq_list))
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# (67, 704900)
# Channel number counter: Counter({67: 84})
# Sampling rate counter: Counter({500.0: 84})

# %%
common_channels = []
for sub in os.listdir(root):
    if sub.startswith("sub-"):   # Only process subject directories
        sub_path = os.path.join(root, sub)
        for ses in os.listdir(sub_path):  # Iterate over ses-xx directories
            ses_path = os.path.join(sub_path, ses, "eeg")
            if os.path.exists(ses_path):
                for file in os.listdir(ses_path):
                    if file.endswith(".set"):
                        file_path = os.path.join(ses_path, file)
                        print(f"Reading in progress: {file_path}")
                        
                        # Try loading raw data first, fallback to epochs if raw fails
                        try:
                            raw = mne.io.read_raw_eeglab(file_path, preload=True)
                            current_channels = set(raw.info['ch_names'])
                        except Exception as e1:
                            print(f"  -> Raw read failed, fallback to epochs: {e1}")
                            try:
                                epochs = mne.read_epochs_eeglab(file_path)
                                epochs.load_data()
                                current_channels = set(epochs.info['ch_names'])
                            except Exception as e2:
                                print(f"  -> Failed to read epochs as well: {e2}")
                                continue  # Skip this file
                        
                        # Find common channels
                        if not common_channels:
                            common_channels = current_channels
                        else:
                            common_channels &= current_channels

common_channels = list(common_channels)
print(f"Common channels ({len(common_channels)}):", common_channels)
# Out:
# Reading in progress: RLPD/sub-001\ses-01\eeg\sub-001_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-001\ses-01\eeg\sub-001_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 704899  =      0.000 ...  1409.798 secs...
# Reading in progress: RLPD/sub-002\ses-01\eeg\sub-002_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-002\ses-01\eeg\sub-002_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 960124  =      0.000 ...  1920.248 secs...
# Reading in progress: RLPD/sub-002\ses-02\eeg\sub-002_ses-02_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-002\ses-02\eeg\sub-002_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 312124  =      0.000 ...   624.248 secs...
# Reading in progress: RLPD/sub-003\ses-01\eeg\sub-003_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-003\ses-01\eeg\sub-003_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ...
ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 791049  =      0.000 ...  1582.098 secs...
# Reading in progress: RLPD/sub-041\ses-01\eeg\sub-041_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-041\ses-01\eeg\sub-041_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 1065599  =      0.000 ...  2131.198 secs...
# Reading in progress: RLPD/sub-042\ses-01\eeg\sub-042_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-042\ses-01\eeg\sub-042_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 872099  =      0.000 ...  1744.198 secs...
# Reading in progress: RLPD/sub-043\ses-01\eeg\sub-043_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-043\ses-01\eeg\sub-043_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 773724  =      0.000 ...  1547.448 secs...
# Reading in progress: RLPD/sub-044\ses-01\eeg\sub-044_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-044\ses-01\eeg\sub-044_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 717874  =      0.000 ...  1435.748 secs...
# Reading in progress: RLPD/sub-045\ses-01\eeg\sub-045_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-045\ses-01\eeg\sub-045_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 736474  =      0.000 ...  1472.948 secs...
# Reading in progress: RLPD/sub-046\ses-01\eeg\sub-046_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-046\ses-01\eeg\sub-046_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 876374  =      0.000 ...  1752.748 secs...
# Reading in progress: RLPD/sub-047\ses-01\eeg\sub-047_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-047\ses-01\eeg\sub-047_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 759124  =      0.000 ...  1518.248 secs...
# Reading in progress: RLPD/sub-048\ses-01\eeg\sub-048_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-048\ses-01\eeg\sub-048_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 769124  =      0.000 ...  1538.248 secs...
# Reading in progress: RLPD/sub-049\ses-01\eeg\sub-049_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-049\ses-01\eeg\sub-049_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 839874  =      0.000 ...  1679.748 secs...
# Reading in progress: RLPD/sub-050\ses-01\eeg\sub-050_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-050\ses-01\eeg\sub-050_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 671874  =      0.000 ...  1343.748 secs...
# Reading in progress: RLPD/sub-051\ses-01\eeg\sub-051_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-051\ses-01\eeg\sub-051_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 760124  =      0.000 ...  1520.248 secs...
# Reading in progress: RLPD/sub-052\ses-01\eeg\sub-052_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-052\ses-01\eeg\sub-052_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 688624  =      0.000 ...  1377.248 secs...
# Reading in progress: RLPD/sub-053\ses-01\eeg\sub-053_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-053\ses-01\eeg\sub-053_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 687699  =      0.000 ...  1375.398 secs...
# Reading in progress: RLPD/sub-054\ses-01\eeg\sub-054_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-054\ses-01\eeg\sub-054_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 651549  =      0.000 ...  1303.098 secs...
# Reading in progress: RLPD/sub-055\ses-01\eeg\sub-055_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-055\ses-01\eeg\sub-055_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 794999  =      0.000 ...  1589.998 secs...
# Reading in progress: RLPD/sub-056\ses-01\eeg\sub-056_ses-01_task-ReinforcementLearning_eeg.set
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-056\ses-01\eeg\sub-056_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 635524  =      0.000 ...  1271.048 secs...
# Common channels (67): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FT9', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FT10', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'TP10', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'TP9', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']

# %%
## Data preprocessing and segmentation
feature_path = 'Processed/' + sub_folder_path + '/RLPD/Feature'
if not os.path.exists(feature_path):
    os.makedirs(feature_path)

label_path = 'Processed/' + sub_folder_path + '/RLPD/Label'
if not os.path.exists(label_path):
    os.makedirs(label_path)

# %%
def data_preprocessing(
        input_data,
        common_channels: list,
        sample_rate: int = 250,
        notch_freq: float = 60.0,
        l_freq: float = 0.1,
        h_freq: float = 20.0,
        do_bad_interp: bool = True,
        verbose: bool = True,
):
    """
    Simon Conflict Task EEG Preprocessing:
      1) Select common channels, remove unreliable ones (FT9, FT10, TP9, TP10), reorder
      2) Set Montage
      3) 60 Hz Notch filter
      4) Bandpass filter (0.1–20 Hz)
      5) Interpolate bad channels (if enabled)
      6) Re-reference to average
      7) ICA removal (fit on 1 Hz copy + ICLabel)
      8) Downsample to 250 Hz (if needed)
    """

    raw = input_data
    # 1. Remove unreliable electrodes
    bad_electrodes = {"FT9", "FT10", "TP9", "TP10"}
    keep = [ch for ch in common_channels if ch in raw.ch_names and ch not in bad_electrodes]
    raw.pick_channels(keep)
    raw.reorder_channels(keep)
    if verbose:
        print(f"✔ Step 1: Picked & reordered channels (excluding {bad_electrodes}): {keep}")

    # 2. Set Montage
    raw.drop_channels(['X', 'Y', 'Z', 'VEOG'])

    raw.set_montage(mne.channels.make_standard_montage('standard_1020'))
    if verbose:
        print("✔ Step 2: Montage set to 'standard_1020'.")

    # 3. Notch filter (60 Hz)
    if notch_freq is not None:
        raw.notch_filter(freqs=[notch_freq], picks="eeg", verbose=False)
        if verbose:
            print(f"✔ Step 3: Notch filtered at {notch_freq} Hz")

    # 4. Bandpass filter (0.1–20 Hz)
    raw.filter(l_freq=l_freq, h_freq=h_freq, picks="eeg", verbose=False)
    if verbose:
        print(f"✔ Step 4: Band-pass filtered from {l_freq}–{h_freq} Hz")

    # 5. Interpolate bad channels
    if do_bad_interp and raw.info.get("bads"):
        raw.interpolate_bads(reset_bads=True, verbose=False)
        if verbose:
            print(f"✔ Step 5: Interpolated bad channels: {raw.info.get('bads', [])}")
    else:
        if verbose:
            print("ℹ Step 5: No bad channels to interpolate.")

    # 6. Re-reference to average
    raw.set_eeg_reference("average", verbose=False)
    if verbose:
        print("✔ Step 6: EEG re-referenced to average")

    # 7. ICA
    raw_for_ica = raw.copy().filter(l_freq=1.0, h_freq=None, picks="eeg", verbose=False)
    ica = ICA(n_components=None, method="fastica", random_state=97, max_iter="auto")

    ica.fit(raw_for_ica)

    excluded = []
    if label_components is not None:
        try:
            ic_labels = label_components(raw_for_ica, ica, method="iclabel")
            labels = ic_labels["labels"]
            probs = ic_labels["y_pred_proba"]
            thresholds = {
                "eye blink": 0.7,
                "muscle artifact": 0.6,
                "heart beat": 0.5,
                "line noise": 0.8,
                "channel noise": 0.9,
            }
            for i, lab in enumerate(labels):
                if lab in thresholds:
                    p = probs[i].max() if probs is not None else 1.0
                    if p >= thresholds[lab]:
                        excluded.append(i)
        except Exception as e:
            if verbose:
                print(f"⚠ ICLabel failed: {e}")
    else:
        if verbose:
            print("ℹ ICLabel not available; ICA fitted but no auto exclusion")

    if excluded:
        ica.exclude = sorted(set(excluded))
        raw = ica.apply(raw.copy())
        if verbose:
            print(f"✔ Step 7: ICA applied. Excluded components: {ica.exclude}")
    else:
        if verbose:
            print("ℹ Step 7: No ICA components excluded.")

    # 8. Downsample (if not already 250 Hz)
    if raw.info["sfreq"] != sample_rate:
        raw.resample(sample_rate, npad="auto", verbose=False)
        if verbose:
            print(f"✔ Step 8: Resampled to {sample_rate} Hz")

    return raw

# %%
def epoch_and_make_xy(
    raw: mne.io.Raw,
    events_tsv_path: str,
    tmin: float = -0.5,
    tmax: float = 1.0,
    baseline=(-0.3, -0.2),  # Change 1: Update baseline setting
    task_id: int = 1,
    subject_id: int = 1,
    disease_id: int = 1,
):
    """
    Epoch Simon Conflict data using cue-lock strategy.
    - Use 'Test Stim: ...' as cue-lock events.
    - Extract accuracy from events.tsv directly. (congruent info is unclear in Test Stim)
    """

    # Extract stimulus events (cues) from events.tsv
    ev = pd.read_csv(events_tsv_path, sep="\t")
    ev = ev.reset_index(drop=True)

    stim_mask = ev["trial_type"].astype(str).str.contains("Button", na=False)
    test_response_ev = ev[stim_mask].reset_index()

    # Construct response-locked events using onset times from events.tsv
    sfreq = raw.info["sfreq"]
    print(f"Current sampling frequency: {sfreq} Hz")
    s1_samples = np.round(test_response_ev["onset"].values * sfreq).astype(int)
    events = np.c_[s1_samples, np.zeros_like(s1_samples), np.ones_like(s1_samples)]

    # Construct epochs
    picks = mne.pick_types(raw.info, eeg=True, eog=False, exclude="bads")
    epochs = mne.Epochs(
        raw, events, event_id=dict(cue=1),
        tmin=tmin, tmax=tmax,
        baseline=baseline, picks=picks,
        proj=False, preload=True, reject=None, verbose=False
    )

    # Ensure shape is correct: (N, T, C)
    target_len = int((tmax - tmin) * sfreq)
    data = epochs.get_data()  # (N, C, T)
    if data.shape[-1] > target_len:
        data = data[..., :target_len]
    elif data.shape[-1] < target_len:
        pad = target_len - data.shape[-1]
        data = np.pad(data, ((0, 0), (0, 0), (0, pad)), mode="edge")
    X = np.transpose(data, (0, 2, 1))  # → (N, T, C)

    # Modification 2: derive y from events.tsv
    # [task_id, subject_id, disease_id]
    y = np.column_stack([
        np.full_like(s1_samples, task_id),
        np.full_like(s1_samples, subject_id),
        np.full_like(s1_samples, disease_id)
    ])

    return X, y

# %%
for sub in os.listdir(root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub)
        for ses in os.listdir(sub_path):
            if 'ses-' in ses:
                print(f"Current subject/session: {sub} / {ses}")
                eeg_path = os.path.join(sub_path, ses, 'eeg/')

                # Initialize file paths
                set_file_path, events_file_path = None, None

                # Traverse the eeg folder to find files
                for file in os.listdir(eeg_path):
                    if file.endswith('.set'):
                        set_file_path = os.path.join(eeg_path, file)
                    if 'events.tsv' in file:
                        events_file_path = os.path.join(eeg_path, file)

                # Error checking
                if set_file_path is None:
                    raise FileNotFoundError(f".set file not found in: {eeg_path}")
                if events_file_path is None:
                    raise FileNotFoundError(f"events.tsv not found in: {eeg_path}")

                # Load EEG data and preprocess
                print("Start preprocessing EEG data...")
                raw = mne.io.read_raw_eeglab(set_file_path, preload=True)
                raw = data_preprocessing(raw, common_channels, SAMPLE_RATE, notch_freq=60, l_freq=0.5, h_freq=40, verbose=True)
                print()


                # # Extract subject_id and disease_id

                subject_id = int(sub.split('-')[-1])
                disease_id = participants[participants['participant_id'] == sub]['Group'].values[0]
                if disease_id == 'CTL':
                    disease_id = 0
                elif disease_id == 'PD':
                    disease_id = 1

                print(f"Subject ID: {subject_id}, Disease ID: {disease_id}")
                print("Start epoching and making X, y...")

                # Remove beh_file_path, keep other parameters unchanged
                X, y = epoch_and_make_xy(
                    raw, events_file_path,
                    tmin=-2.0, tmax=1.0, baseline=(-0.2, 0.0),   # baseline correction according to paper, tmim tmas was observed from the data
                    task_id=1, subject_id=subject_id, disease_id=disease_id
                )

                print(f"X shape: {X.shape}, y shape: {y.shape}")
                np.save(os.path.join(feature_path, 'feature_{:03d}.npy'.format(subject_id)), X)
                np.save(os.path.join(label_path, 'label_{:03d}.npy'.format(subject_id)), y)

                print("------------------------------------------------\n")
# Out:
# Current subject/session: sub-001 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-001\ses-01\eeg\sub-001_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 704899  =      0.000 ...  1409.798 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 39.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 13 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 5, 6, 11, 16, 20, 24, 31, 32, 38, 44]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 1, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (252, 600, 59), y shape: (252, 3)
# ------------------------------------------------
#
# Current subject/session: sub-002 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-002\ses-01\eeg\sub-002_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 960124  =      0.000 ...  1920.248 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 49.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 21 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 5, 7, 8, 10, 11, 12, 13, 17, 18, 19, 20, 23, 25, 32, 37, 42, 46]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 2, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (351, 600, 59), y shape: (351, 3)
# ------------------------------------------------
#
# Current subject/session: sub-002 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-002\ses-02\eeg\sub-002_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 312124  =      0.000 ...   624.248 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 241.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 10 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 5, 9, 13, 14, 15, 19, 20, 26]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 2, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (86, 600, 59), y shape: (86, 3)
# ------------------------------------------------
#
# Current subject/session: sub-003 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-003\ses-01\eeg\sub-003_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 761424  =      0.000 ...  1522.848 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 26.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 12 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 3, 8, 12, 14, 15, 16, 20, 24, 26, 50]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 3, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (256, 600, 59), y shape: (256, 3)
# ------------------------------------------------
#
# Current subject/session: sub-003 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-003\ses-02\eeg\sub-003_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 913074  =      0.000 ...  1826.148 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 54 components
# Fitting ICA took 56.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (54 components)
#     Zeroing out 2 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [16, 47]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 3, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (262, 600, 59), y shape: (262, 3)
# ------------------------------------------------
#
# Current subject/session: sub-004 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-004\ses-01\eeg\sub-004_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 817849  =      0.000 ...  1635.698 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 60.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 7 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 3, 6, 9, 24, 28]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 4, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-004 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-004\ses-02\eeg\sub-004_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 643574  =      0.000 ...  1287.148 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 483.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 4, 6, 9, 12, 14, 20, 23, 28, 31]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 4, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-005 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-005\ses-01\eeg\sub-005_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 760374  =      0.000 ...  1520.748 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 34.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 13 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 3, 4, 12, 13, 14, 22, 23, 24, 25, 37, 38]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 5, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-005 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-005\ses-02\eeg\sub-005_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 731849  =      0.000 ...  1463.698 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 21.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 17 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 5, 8, 9, 12, 13, 16, 18, 19, 20, 21, 25, 26, 37, 55]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 5, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-006 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-006\ses-01\eeg\sub-006_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 759949  =      0.000 ...  1519.898 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 28.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 10 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [1, 5, 17, 21, 22, 24, 28, 30, 38, 41]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 6, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (256, 600, 59), y shape: (256, 3)
# ------------------------------------------------
#
# Current subject/session: sub-006 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-006\ses-02\eeg\sub-006_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 784124  =      0.000 ...  1568.248 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 32.3s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 16 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 11, 14, 15, 17, 18, 19, 21, 25, 26, 28, 34, 37, 38, 45]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 6, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (256, 600, 59), y shape: (256, 3)
# ------------------------------------------------
#
# Current subject/session: sub-007 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-007\ses-01\eeg\sub-007_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 752424  =      0.000 ...  1504.848 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 51.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 8 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 10, 15, 18, 19, 26]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 7, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (257, 600, 59), y shape: (257, 3)
# ------------------------------------------------
#
# Current subject/session: sub-008 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-008\ses-01\eeg\sub-008_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 806724  =      0.000 ...  1613.448 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 56 components
# Fitting ICA took 66.1s.
# ℹ Step 7: No ICA components excluded.
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 8, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (252, 600, 59), y shape: (252, 3)
# ------------------------------------------------
#
# Current subject/session: sub-008 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-008\ses-02\eeg\sub-008_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 682074  =      0.000 ...  1364.148 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 559.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 8 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 9, 16, 22, 33, 36, 38]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 8, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (256, 600, 59), y shape: (256, 3)
# ------------------------------------------------
#
# Current subject/session: sub-009 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-009\ses-01\eeg\sub-009_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 738099  =      0.000 ...  1476.198 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 38.3s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 14 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 3, 4, 8, 15, 16, 19, 23, 25, 27, 30, 36, 51]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 9, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-010 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-010\ses-01\eeg\sub-010_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 807149  =      0.000 ...  1614.298 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 21.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 10 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 13, 15, 20, 21, 28, 34, 48]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 10, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-010 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-010\ses-02\eeg\sub-010_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 685849  =      0.000 ...  1371.698 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 56.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 10, 11, 12, 14, 16, 17, 22, 24]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 10, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-011 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-011\ses-01\eeg\sub-011_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 700124  =      0.000 ...  1400.248 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 206.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 13 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 5, 15, 17, 19, 20, 22, 25, 28, 29, 30, 37]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 11, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (256, 600, 59), y shape: (256, 3)
# ------------------------------------------------
#
# Current subject/session: sub-011 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-011\ses-02\eeg\sub-011_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 993199  =      0.000 ...  1986.398 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 54 components
# Fitting ICA took 66.9s.
# ℹ Step 7: No ICA components excluded.
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 11, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (334, 600, 59), y shape: (334, 3)
# ------------------------------------------------
#
# Current subject/session: sub-012 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-012\ses-01\eeg\sub-012_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 737349  =      0.000 ...  1474.698 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 70.0s.
# ℹ Step 7: No ICA components excluded.
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 12, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-012 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-012\ses-02\eeg\sub-012_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 649699  =      0.000 ...  1299.398 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 29.4s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 12 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 3, 5, 7, 13, 22, 31, 35, 44, 49, 52]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 12, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-013 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-013\ses-01\eeg\sub-013_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 777399  =      0.000 ...  1554.798 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 56 components
# Fitting ICA took 88.7s.
# ℹ Step 7: No ICA components excluded.
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 13, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-013 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-013\ses-02\eeg\sub-013_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 690199  =      0.000 ...  1380.398 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 54.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 10 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 10, 13, 15, 26, 28, 31, 42, 44]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 13, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-014 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-014\ses-01\eeg\sub-014_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 680249  =      0.000 ...  1360.498 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 504.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 14 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 8, 16, 20, 25, 27, 28, 29, 31, 32, 41, 44, 47]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 14, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-014 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-014\ses-02\eeg\sub-014_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 679999  =      0.000 ...  1359.998 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 32.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 19 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 11, 22, 23, 24, 25, 26, 27, 28, 30, 31, 33, 34, 35, 36, 38, 39, 43]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 14, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-015 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-015\ses-01\eeg\sub-015_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 642949  =      0.000 ...  1285.898 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 44 components
# Fitting ICA took 28.5s.
# Applying ICA to Raw instance
#     Transforming to ICA space (44 components)
#     Zeroing out 3 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [31, 34, 43]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 15, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (245, 600, 59), y shape: (245, 3)
# ------------------------------------------------
#
# Current subject/session: sub-015 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-015\ses-02\eeg\sub-015_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 883974  =      0.000 ...  1767.948 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 40.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 8, 13, 14, 16, 18, 30, 33, 42]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 15, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-016 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-016\ses-01\eeg\sub-016_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 718174  =      0.000 ...  1436.348 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 33.3s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 11 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 12, 13, 20, 21, 23, 24, 35, 42]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 16, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-016 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-016\ses-02\eeg\sub-016_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 638874  =      0.000 ...  1277.748 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 30.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 10 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 11, 17, 18, 21, 22, 25, 28, 31]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 16, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-017 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-017\ses-01\eeg\sub-017_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 764924  =      0.000 ...  1529.848 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 26.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 7 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 2, 13, 14, 18, 37, 55]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 17, Disease ID: 1
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (257, 600, 59), y shape: (257, 3)
# ------------------------------------------------
#
# Current subject/session: sub-017 / ses-02
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-017\ses-02\eeg\sub-017_ses-02_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 743849  =      0.000 ...  1487.698 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 23.0s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
# ...
#
# Current subject/session: sub-047 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-047\ses-01\eeg\sub-047_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 759124  =      0.000 ...  1518.248 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 38.1s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 16 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [1, 2, 4, 10, 13, 16, 23, 24, 25, 26, 27, 28, 29, 30, 36, 43]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 47, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-048 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-048\ses-01\eeg\sub-048_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 769124  =      0.000 ...  1538.248 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 34.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 17 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 4, 5, 8, 15, 16, 17, 19, 24, 26, 29, 36, 37, 39]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 48, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (253, 600, 59), y shape: (253, 3)
# ------------------------------------------------
#
# Current subject/session: sub-049 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-049\ses-01\eeg\sub-049_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 839874  =      0.000 ...  1679.748 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 55 components
# Fitting ICA took 70.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (55 components)
#     Zeroing out 1 ICA component
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [53]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 49, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-050 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-050\ses-01\eeg\sub-050_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 671874  =      0.000 ...  1343.748 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 28.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 13 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 4, 7, 13, 14, 16, 18, 19, 21, 22, 23, 32]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 50, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-051 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-051\ses-01\eeg\sub-051_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 760124  =      0.000 ...  1520.248 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 52 components
# Fitting ICA took 42.9s.
# Applying ICA to Raw instance
#     Transforming to ICA space (52 components)
#     Zeroing out 15 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 13, 14, 18, 19, 20, 21, 34, 37, 38, 40, 47]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 51, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (256, 600, 59), y shape: (256, 3)
# ------------------------------------------------
#
# Current subject/session: sub-052 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-052\ses-01\eeg\sub-052_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 688624  =      0.000 ...  1377.248 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 49.8s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 26 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 12, 14, 15, 16, 18, 20, 23, 25, 27, 28, 29, 30, 31, 37, 40, 42]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 52, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-053 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-053\ses-01\eeg\sub-053_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 687699  =      0.000 ...  1375.398 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 18.6s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 16 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 3, 4, 5, 6, 7, 8, 11, 16, 17, 26, 32, 33, 45]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 53, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (255, 600, 59), y shape: (255, 3)
# ------------------------------------------------
#
# Current subject/session: sub-054 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-054\ses-01\eeg\sub-054_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 651549  =      0.000 ...  1303.098 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 26.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 16 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 5, 12, 13, 15, 17, 20, 21, 23, 26, 27, 32, 36, 42, 46]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 54, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------
#
# Current subject/session: sub-055 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-055\ses-01\eeg\sub-055_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 794999  =      0.000 ...  1589.998 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 35.2s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 13 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 5, 6, 14, 15, 19, 22, 23, 36, 47, 50]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 55, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (292, 600, 59), y shape: (292, 3)
# ------------------------------------------------
#
# Current subject/session: sub-056 / ses-01
# Start preprocessing EEG data...
# Reading D:\PycharmPorjects\DataProcessingLocalDisk\ERP-Benchmark\RLPD\RLPD\sub-056\ses-01\eeg\sub-056_ses-01_task-ReinforcementLearning_eeg.fdt
# Reading 0 ... 635524  =      0.000 ...  1271.048 secs...
# ✔ Step 1: Picked & reordered channels (excluding {'TP9', 'TP10', 'FT10', 'FT9'}): ['AF7', 'P4', 'F8', 'X', 'CP5', 'F1', 'AFz', 'Fz', 'CP3', 'O2', 'PO4', 'FC6', 'F5', 'PO8', 'AF3', 'FC1', 'FC2', 'FC3', 'O1', 'CP6', 'Fp1', 'F4', 'P5', 'PO3', 'F2', 'FC4', 'Y', 'P7', 'Pz', 'P8', 'FT7', 'P1', 'T7', 'P6', 'CP4', 'F6', 'VEOG', 'C3', 'C4', 'PO7', 'C6', 'CP2', 'P2', 'C5', 'POz', 'FT8', 'FCz', 'Oz', 'Fp2', 'F3', 'AF4', 'FC5', 'C2', 'Cz', 'AF8', 'TP8', 'Z', 'T8', 'TP7', 'F7', 'CP1', 'P3', 'C1']
# ✔ Step 2: Montage set to 'standard_1020'.
# ✔ Step 3: Notch filtered at 60 Hz
# ✔ Step 4: Band-pass filtered from 0.5–40 Hz
# ℹ Step 5: No bad channels to interpolate.
# ✔ Step 6: EEG re-referenced to average
# Fitting ICA to data using 59 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 58 components
# Fitting ICA took 28.7s.
# Applying ICA to Raw instance
#     Transforming to ICA space (58 components)
#     Zeroing out 9 ICA components
#     Projecting back using 59 PCA components
# ✔ Step 7: ICA applied. Excluded components: [0, 1, 2, 11, 17, 18, 35, 39, 42]
# ✔ Step 8: Resampled to 200 Hz
#
# Subject ID: 56, Disease ID: 0
# Start epoching and making X, y...
# Current sampling frequency: 200.0 Hz
# X shape: (254, 600, 59), y shape: (254, 3)
# ------------------------------------------------

# %% [markdown]
# ## Load and check the processed data

# %%
# Test the saved npy file
# example

total_samples = 0
sub_id = 1
for feature_file, label_file in zip(os.listdir(feature_path), os.listdir(label_path)):
    feature_file_path = os.path.join(feature_path, feature_file)
    label_file_path = os.path.join(label_path, label_file)
    X = np.load(feature_file_path)
    y = np.load(label_file_path)
    print(f"Subject {sub_id}: X shape: {X.shape}, y shape: {y.shape}")
    if X.shape[0] != y.shape[0]:
        print(f"Subject {sub_id} data and label length mismatch: " 
                f"{X.shape[0]} vs {y.shape[0]}")
    total_samples += np.load(feature_file_path).shape[0]
    sub_id += 1
print("\nTotal number of samples:", total_samples)
# Out:
# Subject 1: X shape: (252, 600, 59), y shape: (252, 3)
# Subject 2: X shape: (86, 600, 59), y shape: (86, 3)
# Subject 3: X shape: (262, 600, 59), y shape: (262, 3)
# Subject 4: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 5: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 6: X shape: (256, 600, 59), y shape: (256, 3)
# Subject 7: X shape: (257, 600, 59), y shape: (257, 3)
# Subject 8: X shape: (256, 600, 59), y shape: (256, 3)
# Subject 9: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 10: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 11: X shape: (334, 600, 59), y shape: (334, 3)
# Subject 12: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 13: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 14: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 15: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 16: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 17: X shape: (258, 600, 59), y shape: (258, 3)
# Subject 18: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 19: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 20: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 21: X shape: (86, 600, 59), y shape: (86, 3)
# Subject 22: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 23: X shape: (336, 600, 59), y shape: (336, 3)
# Subject 24: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 25: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 26: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 27: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 28: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 29: X shape: (335, 600, 59), y shape: (335, 3)
# Subject 30: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 31: X shape: (257, 600, 59), y shape: (257, 3)
# Subject 32: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 33: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 34: X shape: (86, 600, 59), y shape: (86, 3)
# Subject 35: X shape: (304, 600, 59), y shape: (304, 3)
# Subject 36: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 37: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 38: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 39: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 40: X shape: (294, 600, 59), y shape: (294, 3)
# Subject 41: X shape: (334, 600, 59), y shape: (334, 3)
# Subject 42: X shape: (333, 600, 59), y shape: (333, 3)
# Subject 43: X shape: (253, 600, 59), y shape: (253, 3)
# Subject 44: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 45: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 46: X shape: (295, 600, 59), y shape: (295, 3)
# Subject 47: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 48: X shape: (253, 600, 59), y shape: (253, 3)
# Subject 49: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 50: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 51: X shape: (256, 600, 59), y shape: (256, 3)
# Subject 52: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 53: X shape: (255, 600, 59), y shape: (255, 3)
# Subject 54: X shape: (254, 600, 59), y shape: (254, 3)
# Subject 55: X shape: (292, 600, 59), y shape: (292, 3)
# Subject 56: X shape: (254, 600, 59), y shape: (254, 3)
#
# Total number of samples: 14325
